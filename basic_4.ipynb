# %% [markdown]
# ## Attention models : 4

# %% [markdown]
# ### Data prep

# %%
import pandas as pd
import numpy as np

# %%
path = 'fra.txt'
eng_texts, fra_texts = [], []
num_samples = 10000

# %%
with open(path, 'r', encoding = 'UTF-8') as f : 
    lines = f.read().split('\n')

    for line in lines[:num_samples] : 
        eng_words, fra_words = line.split('\t')[:2]

        fra_words = '\t' + fra_words + '\n'

        eng_texts.append(eng_words)
        fra_texts.append(fra_words)

# %%
max_eng_word = max([len(word) for word in eng_texts])
max_fra_word = max([len(words) for words in fra_texts])
print(f"{max_eng_word} :: {max_fra_word}")
# Out:
# 14 :: 59

# %% [markdown]
# ### tokenizers

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ### eng tokenizer

# %%
eng_token = Tokenizer(filters = ' ', lower = True)
eng_token.fit_on_texts(eng_texts)
eng_sequences = eng_token.texts_to_sequences(eng_texts)

# %%
encoder_input_data = pad_sequences(eng_sequences, maxlen = max_eng_word, padding = 'pre')

# %%
encoder_input_data.shape
# Out:
# (10000, 14)

# %% [markdown]
# ### fra tokenizer

# %%
fra_token = Tokenizer(filters = ' ', lower = True)
fra_token.fit_on_texts(fra_texts)
decoder_input_data = fra_token.texts_to_sequences(fra_texts)

# %%
decoder_input_data = pad_sequences(decoder_input_data, maxlen = max_fra_word, padding = 'pre')

# %%
decoder_input_data.shape
# Out:
# (10000, 59)

# %%
decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[:, 1:]

# %%
decoder_target_data.shape
# Out:
# (10000, 59)

# %%
decoder_input_data
# Out:
# array([[   0,    0,    0, ...,    0,   92,    2],
#        [   0,    0,    0, ...,    0,    0,  991],
#        [   0,    0,    0, ...,  145,  334,    2],
#        ...,
#        [   0,    0,    0, ...,   20, 5804,  380],
#        [   0,    0,    0, ...,   20, 5805,  380],
#        [   0,    0,    0, ..., 2286,  893,  456]])

# %%
decoder_target_data
# Out:
# array([[   0,    0,    0, ...,   92,    2,    0],
#        [   0,    0,    0, ...,    0,  991,    0],
#        [   0,    0,    0, ...,  334,    2,    0],
#        ...,
#        [   0,    0,    0, ..., 5804,  380,    0],
#        [   0,    0,    0, ..., 5805,  380,    0],
#        [   0,    0,    0, ...,  893,  456,    0]])

# %% [markdown]
# ### vocabs

# %%
eng_vocab = len(eng_token.word_index) + 1
fra_vocab = len(fra_token.word_index) + 1
print(f"{eng_vocab} :: {fra_vocab}")
# Out:
# 2707 :: 5806

# %% [markdown]
# ### building the encoders

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding

# %%
latent_dim = 256

# %%
enc_inputs = Input(shape = (max_eng_word, ))
enc_emb = Embedding(eng_vocab, latent_dim)(enc_inputs)
enc_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)
enc_outputs, state_h, state_c = enc_lstm(enc_emb)

# %% [markdown]
# ### decoders

# %%
dec_inputs = Input(shape = (max_fra_word, ))
dec_emb_layer = Embedding(fra_vocab, latent_dim)
dec_emb = dec_emb_layer(dec_inputs)
dec_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)

# %% [markdown]
# ### Bahdanau class

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Layer, Concatenate

# %%
class BahdanauAttention(Layer) : 
    def __init__(self, units) : 
        super(BahdanauAttention, self).__init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, query, values) : 
        query_with_time_axis = tensorflow.expand_dims(query, 1)
        score = self.V(tensorflow.nn.tanh(self.W1(values)) + self.W2(query_with_time_axis))
        attention_weights = tensorflow.nn.softmax(score, 1)
        context_vector = attention_weights * score
        context_vector = tensorflow.reduce_sum(context_vector, 1)

        return context_vector, attention_weights

# %%
attention = BahdanauAttention(latent_dim)
all_outputs = []
decoder_state_h, decoder_state_c = state_h, state_c
for t in range(max_fra_word) : 
    context_vector, _ = attention(decoder_state_h, decoder_state_c)
    X = tensorflow.expand_dims(dec_emb[:, t], 1)
    X = Concatenate(axis = -1)([context_vector[:, None, :], X])
    outputs, decoder_state_h, decoder_state_c = dec_lstm(X, initial_state = [decoder_state_h, decoder_state_c])
    outputs = Dense(fra_vocab, activation = 'softmax')(outputs)

    all_outputs.append(outputs)

decoder_outputs = tensorflow.concat(all_outputs, axis = 1)

# %% [markdown]
# ### final model

# %%
model = Model()

# %%
model = Model([enc_inputs, dec_inputs], decoder_outputs)
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 14)]         0           []
#
#  embedding_2 (Embedding)        (None, 14, 256)      692992      ['input_3[0][0]']
#
#  input_4 (InputLayer)           [(None, 59)]         0           []
#
#  lstm_2 (LSTM)                  [(None, 14, 256),    525312      ['embedding_2[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_3 (Embedding)        (None, 59, 256)      1486336     ['input_4[0][0]']
#
#  bahdanau_attention_1 (Bahdanau  ((None, 1),         131841      ['lstm_2[0][1]',
#  Attention)                      (None, None, 1))                 'lstm_2[0][2]',
#                                                                   'lstm_3[1][1]',
#                                                                   'lstm_3[1][2]',
#                                                                   'lstm_3[2][1]',
#                                                                   'lstm_3[2][2]',
#                                                                   'lstm_3[3][1]',
#                                                                   'lstm_3[3][2]',
#                                                                   'lstm_3[4][1]',
#                                                                   'lstm_3[4][2]',
#                                                                   'lstm_3[5][1]',
#                                                                   'lstm_3[5][2]',
#                                                                   'lstm_3[6][1]',
#                                                                   'lstm_3[6][2]',
#                                                                   'lstm_3[7][1]',
#                                                                   'lstm_3[7][2]',
#                                                                   'lstm_3[8][1]',
#                                                                   'lstm_3[8][2]',
#                                                                   'lstm_3[9][1]',
#                                                                   'lstm_3[9][2]',
#                                                                   'lstm_3[10][1]',
#                                                                   'lstm_3[10][2]',
#                                                                   'lstm_3[11][1]',
#                                                                   'lstm_3[11][2]',
#                                                                   'lstm_3[12][1]',
#                                                                   'lstm_3[12][2]',
#                                                                   'lstm_3[13][1]',
#                                                                   'lstm_3[13][2]',
#                                                                   'lstm_3[14][1]',
#                                                                   'lstm_3[14][2]',
#                                                                   'lstm_3[15][1]',
#                                                                   'lstm_3[15][2]',
#                                                                   'lstm_3[16][1]',
#                                                                   'lstm_3[16][2]',
#                                                                   'lstm_3[17][1]',
#                                                                   'lstm_3[17][2]',
#                                                                   'lstm_3[18][1]',
#                                                                   'lstm_3[18][2]',
#                                                                   'lstm_3[19][1]',
#                                                                   'lstm_3[19][2]',
#                                                                   'lstm_3[20][1]',
#                                                                   'lstm_3[20][2]',
#                                                                   'lstm_3[21][1]',
#                                                                   'lstm_3[21][2]',
#                                                                   'lstm_3[22][1]',
#                                                                   'lstm_3[22][2]',
#                                                                   'lstm_3[23][1]',
#                                                                   'lstm_3[23][2]',
#                                                                   'lstm_3[24][1]',
#                                                                   'lstm_3[24][2]',
#                                                                   'lstm_3[25][1]',
#                                                                   'lstm_3[25][2]',
#                                                                   'lstm_3[26][1]',
#                                                                   'lstm_3[26][2]',
#                                                                   'lstm_3[27][1]',
#                                                                   'lstm_3[27][2]',
#                                                                   'lstm_3[28][1]',
#                                                                   'lstm_3[28][2]',
#                                                                   'lstm_3[29][1]',
#                                                                   'lstm_3[29][2]',
#                                                                   'lstm_3[30][1]',
#                                                                   'lstm_3[30][2]',
#                                                                   'lstm_3[31][1]',
#                                                                   'lstm_3[31][2]',
#                                                                   'lstm_3[32][1]',
#                                                                   'lstm_3[32][2]',
#                                                                   'lstm_3[33][1]',
#                                                                   'lstm_3[33][2]',
#                                                                   'lstm_3[34][1]',
#                                                                   'lstm_3[34][2]',
#                                                                   'lstm_3[35][1]',
#                                                                   'lstm_3[35][2]',
#                                                                   'lstm_3[36][1]',
#                                                                   'lstm_3[36][2]',
#                                                                   'lstm_3[37][1]',
#                                                                   'lstm_3[37][2]',
#                                                                   'lstm_3[38][1]',
#                                                                   'lstm_3[38][2]',
#                                                                   'lstm_3[39][1]',
#                                                                   'lstm_3[39][2]',
#                                                                   'lstm_3[40][1]',
#                                                                   'lstm_3[40][2]',
#                                                                   'lstm_3[41][1]',
#                                                                   'lstm_3[41][2]',
#                                                                   'lstm_3[42][1]',
#                                                                   'lstm_3[42][2]',
#                                                                   'lstm_3[43][1]',
#                                                                   'lstm_3[43][2]',
#                                                                   'lstm_3[44][1]',
#                                                                   'lstm_3[44][2]',
#                                                                   'lstm_3[45][1]',
#                                                                   'lstm_3[45][2]',
#                                                                   'lstm_3[46][1]',
#                                                                   'lstm_3[46][2]',
#                                                                   'lstm_3[47][1]',
#                                                                   'lstm_3[47][2]',
#                                                                   'lstm_3[48][1]',
#                                                                   'lstm_3[48][2]',
#                                                                   'lstm_3[49][1]',
#                                                                   'lstm_3[49][2]',
#                                                                   'lstm_3[50][1]',
#                                                                   'lstm_3[50][2]',
#                                                                   'lstm_3[51][1]',
#                                                                   'lstm_3[51][2]',
#                                                                   'lstm_3[52][1]',
#                                                                   'lstm_3[52][2]',
#                                                                   'lstm_3[53][1]',
#                                                                   'lstm_3[53][2]',
#                                                                   'lstm_3[54][1]',
#                                                                   'lstm_3[54][2]',
#                                                                   'lstm_3[55][1]',
#                                                                   'lstm_3[55][2]',
#                                                                   'lstm_3[56][1]',
#                                                                   'lstm_3[56][2]',
#                                                                   'lstm_3[57][1]',
#                                                                   'lstm_3[57][2]',
#                                                                   'lstm_3[58][1]',
#                                                                   'lstm_3[58][2]']
#
#  tf.__operators__.getitem_2 (Sl  (None, 256)         0           ['embedding_3[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None, 1, 1)        0           ['bahdanau_attention_1[0][0]']
#  icingOpLambda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  concatenate_1 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_1[0][0]']
#
#  lstm_3 (LSTM)                  [(None, 1, 256),     526336      ['concatenate_1[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'lstm_3[1][1]',
#                                                                   'lstm_3[1][2]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'lstm_3[2][1]',
#                                                                   'lstm_3[2][2]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'lstm_3[3][1]',
#                                                                   'lstm_3[3][2]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'lstm_3[4][1]',
#                                                                   'lstm_3[4][2]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'lstm_3[5][1]',
#                                                                   'lstm_3[5][2]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'lstm_3[6][1]',
#                                                                   'lstm_3[6][2]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'lstm_3[7][1]',
#                                                                   'lstm_3[7][2]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'lstm_3[8][1]',
#                                                                   'lstm_3[8][2]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'lstm_3[9][1]',
#                                                                   'lstm_3[9][2]',
#                                                                   'concatenate_11[0][0]',
#                                                                   'lstm_3[10][1]',
#                                                                   'lstm_3[10][2]',
#                                                                   'concatenate_12[0][0]',
#                                                                   'lstm_3[11][1]',
#                                                                   'lstm_3[11][2]',
#                                                                   'concatenate_13[0][0]',
#                                                                   'lstm_3[12][1]',
#                                                                   'lstm_3[12][2]',
#                                                                   'concatenate_14[0][0]',
#                                                                   'lstm_3[13][1]',
#                                                                   'lstm_3[13][2]',
#                                                                   'concatenate_15[0][0]',
#                                                                   'lstm_3[14][1]',
#                                                                   'lstm_3[14][2]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'lstm_3[15][1]',
#                                                                   'lstm_3[15][2]',
#                                                                   'concatenate_17[0][0]',
#                                                                   'lstm_3[16][1]',
#                                                                   'lstm_3[16][2]',
#                                                                   'concatenate_18[0][0]',
#                                                                   'lstm_3[17][1]',
#                                                                   'lstm_3[17][2]',
#                                                                   'concatenate_19[0][0]',
#                                                                   'lstm_3[18][1]',
#                                                                   'lstm_3[18][2]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'lstm_3[19][1]',
#                                                                   'lstm_3[19][2]',
#                                                                   'concatenate_21[0][0]',
#                                                                   'lstm_3[20][1]',
#                                                                   'lstm_3[20][2]',
#                                                                   'concatenate_22[0][0]',
#                                                                   'lstm_3[21][1]',
#                                                                   'lstm_3[21][2]',
#                                                                   'concatenate_23[0][0]',
#                                                                   'lstm_3[22][1]',
#                                                                   'lstm_3[22][2]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'lstm_3[23][1]',
#                                                                   'lstm_3[23][2]',
#                                                                   'concatenate_25[0][0]',
#                                                                   'lstm_3[24][1]',
#                                                                   'lstm_3[24][2]',
#                                                                   'concatenate_26[0][0]',
#                                                                   'lstm_3[25][1]',
#                                                                   'lstm_3[25][2]',
#                                                                   'concatenate_27[0][0]',
#                                                                   'lstm_3[26][1]',
#                                                                   'lstm_3[26][2]',
#                                                                   'concatenate_28[0][0]',
#                                                                   'lstm_3[27][1]',
#                                                                   'lstm_3[27][2]',
#                                                                   'concatenate_29[0][0]',
#                                                                   'lstm_3[28][1]',
#                                                                   'lstm_3[28][2]',
#                                                                   'concatenate_30[0][0]',
#                                                                   'lstm_3[29][1]',
#                                                                   'lstm_3[29][2]',
#                                                                   'concatenate_31[0][0]',
#                                                                   'lstm_3[30][1]',
#                                                                   'lstm_3[30][2]',
#                                                                   'concatenate_32[0][0]',
#                                                                   'lstm_3[31][1]',
#                                                                   'lstm_3[31][2]',
#                                                                   'concatenate_33[0][0]',
#                                                                   'lstm_3[32][1]',
#                                                                   'lstm_3[32][2]',
#                                                                   'concatenate_34[0][0]',
#                                                                   'lstm_3[33][1]',
#                                                                   'lstm_3[33][2]',
#                                                                   'concatenate_35[0][0]',
#                                                                   'lstm_3[34][1]',
#                                                                   'lstm_3[34][2]',
#                                                                   'concatenate_36[0][0]',
#                                                                   'lstm_3[35][1]',
#                                                                   'lstm_3[35][2]',
#                                                                   'concatenate_37[0][0]',
#                                                                   'lstm_3[36][1]',
#                                                                   'lstm_3[36][2]',
#                                                                   'concatenate_38[0][0]',
#                                                                   'lstm_3[37][1]',
#                                                                   'lstm_3[37][2]',
#                                                                   'concatenate_39[0][0]',
#                                                                   'lstm_3[38][1]',
#                                                                   'lstm_3[38][2]',
#                                                                   'concatenate_40[0][0]',
#                                                                   'lstm_3[39][1]',
#                                                                   'lstm_3[39][2]',
#                                                                   'concatenate_41[0][0]',
#                                                                   'lstm_3[40][1]',
#                                                                   'lstm_3[40][2]',
#                                                                   'concatenate_42[0][0]',
#                                                                   'lstm_3[41][1]',
#                                                                   'lstm_3[41][2]',
#                                                                   'concatenate_43[0][0]',
#                                                                   'lstm_3[42][1]',
#                                                                   'lstm_3[42][2]',
#                                                                   'concatenate_44[0][0]',
#                                                                   'lstm_3[43][1]',
#                                                                   'lstm_3[43][2]',
#                                                                   'concatenate_45[0][0]',
#                                                                   'lstm_3[44][1]',
#                                                                   'lstm_3[44][2]',
#                                                                   'concatenate_46[0][0]',
#                                                                   'lstm_3[45][1]',
#                                                                   'lstm_3[45][2]',
#                                                                   'concatenate_47[0][0]',
#                                                                   'lstm_3[46][1]',
#                                                                   'lstm_3[46][2]',
#                                                                   'concatenate_48[0][0]',
#                                                                   'lstm_3[47][1]',
#                                                                   'lstm_3[47][2]',
#                                                                   'concatenate_49[0][0]',
#                                                                   'lstm_3[48][1]',
#                                                                   'lstm_3[48][2]',
#                                                                   'concatenate_50[0][0]',
#                                                                   'lstm_3[49][1]',
#                                                                   'lstm_3[49][2]',
#                                                                   'concatenate_51[0][0]',
#                                                                   'lstm_3[50][1]',
#                                                                   'lstm_3[50][2]',
#                                                                   'concatenate_52[0][0]',
#                                                                   'lstm_3[51][1]',
#                                                                   'lstm_3[51][2]',
#                                                                   'concatenate_53[0][0]',
#                                                                   'lstm_3[52][1]',
#                                                                   'lstm_3[52][2]',
#                                                                   'concatenate_54[0][0]',
#                                                                   'lstm_3[53][1]',
#                                                                   'lstm_3[53][2]',
#                                                                   'concatenate_55[0][0]',
#                                                                   'lstm_3[54][1]',
#                                                                   'lstm_3[54][2]',
#                                                                   'concatenate_56[0][0]',
#                                                                   'lstm_3[55][1]',
#                                                                   'lstm_3[55][2]',
#                                                                   'concatenate_57[0][0]',
#                                                                   'lstm_3[56][1]',
#                                                                   'lstm_3[56][2]',
#                                                                   'concatenate_58[0][0]',
#                                                                   'lstm_3[57][1]',
#                                                                   'lstm_3[57][2]',
#                                                                   'concatenate_59[0][0]',
#                                                                   'lstm_3[58][1]',
#                                                                   'lstm_3[58][2]']
#
#  tf.__operators__.getitem_4 (Sl  (None, 256)         0           ['embedding_3[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  (None, 1, 1)        0           ['bahdanau_attention_1[1][0]']
#  icingOpLambda)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  concatenate_2 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_2[0][0]']
#
#  tf.__operators__.getitem_6 (Sl  (None, 256)         0           ['embedding_3[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, 1, 1)        0           ['bahdanau_attention_1[2][0]']
#  icingOpLambda)
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  concatenate_3 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_7[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_3[0][0]']
#
#  tf.__operators__.getitem_8 (Sl  (None, 256)         0           ['embedding_3[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_9 (Sl  (None, 1, 1)        0           ['bahdanau_attention_1[3][0]']
#  icingOpLambda)
#
#  tf.expand_dims_4 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  concatenate_4 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_9[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_4[0][0]']
#
#  tf.__operators__.getitem_10 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None, 1, 1)        0           ['bahdanau_attention_1[4][0]']
#  licingOpLambda)
#
#  tf.expand_dims_5 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  concatenate_5 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_11[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_5[0][0]']
#
#  tf.__operators__.getitem_12 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  (None, 1, 1)        0           ['bahdanau_attention_1[5][0]']
#  licingOpLambda)
#
#  tf.expand_dims_6 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  concatenate_6 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_13[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_6[0][0]']
#
#  tf.__operators__.getitem_14 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_15 (S  (None, 1, 1)        0           ['bahdanau_attention_1[6][0]']
#  licingOpLambda)
#
#  tf.expand_dims_7 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_14[0][
#                                                                  0]']
#
#  concatenate_7 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_15[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_7[0][0]']
#
#  tf.__operators__.getitem_16 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_17 (S  (None, 1, 1)        0           ['bahdanau_attention_1[7][0]']
#  licingOpLambda)
#
#  tf.expand_dims_8 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_16[0][
#                                                                  0]']
#
#  concatenate_8 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_17[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_8[0][0]']
#
#  tf.__operators__.getitem_18 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_19 (S  (None, 1, 1)        0           ['bahdanau_attention_1[8][0]']
#  licingOpLambda)
#
#  tf.expand_dims_9 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_18[0][
#                                                                  0]']
#
#  concatenate_9 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_19[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_9[0][0]']
#
#  tf.__operators__.getitem_20 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_21 (S  (None, 1, 1)        0           ['bahdanau_attention_1[9][0]']
#  licingOpLambda)
#
#  tf.expand_dims_10 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_20[0][
#                                                                  0]']
#
#  concatenate_10 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_21[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_10[0][0]']
#
#  tf.__operators__.getitem_22 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_23 (S  (None, 1, 1)        0           ['bahdanau_attention_1[10][0]']
#  licingOpLambda)
#
#  tf.expand_dims_11 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_22[0][
#                                                                  0]']
#
#  concatenate_11 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_23[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_11[0][0]']
#
#  tf.__operators__.getitem_24 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_25 (S  (None, 1, 1)        0           ['bahdanau_attention_1[11][0]']
#  licingOpLambda)
#
#  tf.expand_dims_12 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_24[0][
#                                                                  0]']
#
#  concatenate_12 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_25[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_12[0][0]']
#
#  tf.__operators__.getitem_26 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_27 (S  (None, 1, 1)        0           ['bahdanau_attention_1[12][0]']
#  licingOpLambda)
#
#  tf.expand_dims_13 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_26[0][
#                                                                  0]']
#
#  concatenate_13 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_27[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_13[0][0]']
#
#  tf.__operators__.getitem_28 (S  (None, 256)         0           ['embedding_3[0][0]']
#  licingOpLambda)
#
# ...
#  dense_16 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[11][0]']
#
#  dense_17 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[12][0]']
#
#  dense_18 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[13][0]']
#
#  dense_19 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[14][0]']
#
#  dense_20 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[15][0]']
#
#  dense_21 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[16][0]']
#
#  dense_22 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[17][0]']
#
#  dense_23 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[18][0]']
#
#  dense_24 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[19][0]']
#
#  dense_25 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[20][0]']
#
#  dense_26 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[21][0]']
#
#  dense_27 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[22][0]']
#
#  dense_28 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[23][0]']
#
#  dense_29 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[24][0]']
#
#  dense_30 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[25][0]']
#
#  dense_31 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[26][0]']
#
#  dense_32 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[27][0]']
#
#  dense_33 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[28][0]']
#
#  dense_34 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[29][0]']
#
#  dense_35 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[30][0]']
#
#  dense_36 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[31][0]']
#
#  dense_37 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[32][0]']
#
#  dense_38 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[33][0]']
#
#  dense_39 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[34][0]']
#
#  dense_40 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[35][0]']
#
#  dense_41 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[36][0]']
#
#  dense_42 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[37][0]']
#
#  dense_43 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[38][0]']
#
#  dense_44 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[39][0]']
#
#  dense_45 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[40][0]']
#
#  dense_46 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[41][0]']
#
#  dense_47 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[42][0]']
#
#  dense_48 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[43][0]']
#
#  dense_49 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[44][0]']
#
#  dense_50 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[45][0]']
#
#  dense_51 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[46][0]']
#
#  dense_52 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[47][0]']
#
#  dense_53 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[48][0]']
#
#  dense_54 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[49][0]']
#
#  dense_55 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[50][0]']
#
#  dense_56 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[51][0]']
#
#  dense_57 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[52][0]']
#
#  dense_58 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[53][0]']
#
#  dense_59 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[54][0]']
#
#  dense_60 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[55][0]']
#
#  dense_61 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[56][0]']
#
#  dense_62 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[57][0]']
#
#  dense_63 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[58][0]']
#
#  dense_64 (Dense)               (None, 1, 5806)      1492142     ['lstm_3[59][0]']
#
#  tf.concat (TFOpLambda)         (None, 59, 5806)     0           ['dense_6[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_8[0][0]',
#                                                                   'dense_9[0][0]',
#                                                                   'dense_10[0][0]',
#                                                                   'dense_11[0][0]',
#                                                                   'dense_12[0][0]',
#                                                                   'dense_13[0][0]',
#                                                                   'dense_14[0][0]',
#                                                                   'dense_15[0][0]',
#                                                                   'dense_16[0][0]',
#                                                                   'dense_17[0][0]',
#                                                                   'dense_18[0][0]',
#                                                                   'dense_19[0][0]',
#                                                                   'dense_20[0][0]',
#                                                                   'dense_21[0][0]',
#                                                                   'dense_22[0][0]',
#                                                                   'dense_23[0][0]',
#                                                                   'dense_24[0][0]',
#                                                                   'dense_25[0][0]',
#                                                                   'dense_26[0][0]',
#                                                                   'dense_27[0][0]',
#                                                                   'dense_28[0][0]',
#                                                                   'dense_29[0][0]',
#                                                                   'dense_30[0][0]',
#                                                                   'dense_31[0][0]',
#                                                                   'dense_32[0][0]',
#                                                                   'dense_33[0][0]',
#                                                                   'dense_34[0][0]',
#                                                                   'dense_35[0][0]',
#                                                                   'dense_36[0][0]',
#                                                                   'dense_37[0][0]',
#                                                                   'dense_38[0][0]',
#                                                                   'dense_39[0][0]',
#                                                                   'dense_40[0][0]',
#                                                                   'dense_41[0][0]',
#                                                                   'dense_42[0][0]',
#                                                                   'dense_43[0][0]',
#                                                                   'dense_44[0][0]',
#                                                                   'dense_45[0][0]',
#                                                                   'dense_46[0][0]',
#                                                                   'dense_47[0][0]',
#                                                                   'dense_48[0][0]',
#                                                                   'dense_49[0][0]',
#                                                                   'dense_50[0][0]',
#                                                                   'dense_51[0][0]',
#                                                                   'dense_52[0][0]',
#                                                                   'dense_53[0][0]',
#                                                                   'dense_54[0][0]',
#                                                                   'dense_55[0][0]',
#                                                                   'dense_56[0][0]',
#                                                                   'dense_57[0][0]',
#                                                                   'dense_58[0][0]',
#                                                                   'dense_59[0][0]',
#                                                                   'dense_60[0][0]',
#                                                                   'dense_61[0][0]',
#                                                                   'dense_62[0][0]',
#                                                                   'dense_63[0][0]',
#                                                                   'dense_64[0][0]']
#
# ==================================================================================================
# Total params: 91,399,195
# Trainable params: 91,399,195
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### final training

# %%
model.fit(
    [encoder_input_data, decoder_input_data],
    np.expand_dims(decoder_target_data, -1),
    batch_size = 128,
    epochs = 3,
    validation_split = 0.2
)
# Out:
# Epoch 1/3
# 63/63 [==============================] - 265s 3s/step - loss: 0.4597 - accuracy: 0.9803 - val_loss: 0.4280 - val_accuracy: 0.9831
# Epoch 2/3
# 63/63 [==============================] - 186s 3s/step - loss: 0.3469 - accuracy: 0.9814 - val_loss: 0.4320 - val_accuracy: 0.9831
# Epoch 3/3
# 63/63 [==============================] - 185s 3s/step - loss: 0.3452 - accuracy: 0.9822 - val_loss: 0.4392 - val_accuracy: 0.9831
