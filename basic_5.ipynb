# %% [markdown]
# ## Attention models : 5

# %% [markdown]
# ### Data loading

# %%
import pandas as pd
import numpy as np

# %%
path = 'fra.txt'
eng_texts, fra_texts = [], []
num_samples = 10000

# %%
with open(path, 'r', encoding = 'UTF-8') as f :
    lines = f.read().split('\n')

    for line in lines[:num_samples] : 
        eng_words, fra_words = line.split('\t')[:2]

        fra_words = '\t' + fra_words + '\n'

        eng_texts.append(eng_words)
        fra_texts.append(fra_words)

# %% [markdown]
# ### Data prep

# %%
max_eng_word = max([len(word) for word in eng_texts])
max_fra_word = max([len(word) for word in fra_texts])
print(f"{max_eng_word} :: {max_fra_word}")
# Out:
# 14 :: 59

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
eng_tokenizer = Tokenizer(filters = ' ', lower = True)
eng_tokenizer.fit_on_texts(eng_texts)
encoder_input_data = eng_tokenizer.texts_to_sequences(eng_texts)

# %%
encoder_input_data = pad_sequences(encoder_input_data, maxlen = max_eng_word, padding = 'pre')

# %%
encoder_input_data
# Out:
# array([[  0,   0,   0, ...,   0,   0,  30],
#        [  0,   0,   0, ...,   0,   0,  30],
#        [  0,   0,   0, ...,   0,   0,  30],
#        ...,
#        [  0,   0,   0, ...,  10, 207, 436],
#        [  0,   0,   0, ...,  10, 207, 261],
#        [  0,   0,   0, ...,  10, 207, 200]])

# %%
fra_tokenizer = Tokenizer(filters = ' ', lower = True)
fra_tokenizer.fit_on_texts(fra_texts)
decoder_input_data = fra_tokenizer.texts_to_sequences(fra_texts)

# %%
decoder_input_data = pad_sequences(decoder_input_data, maxlen = max_fra_word, padding = 'pre')

# %%
decoder_input_data
# Out:
# array([[   0,    0,    0, ...,    0,   92,    2],
#        [   0,    0,    0, ...,    0,    0,  991],
#        [   0,    0,    0, ...,  145,  334,    2],
#        ...,
#        [   0,    0,    0, ...,   20, 5804,  380],
#        [   0,    0,    0, ...,   20, 5805,  380],
#        [   0,    0,    0, ..., 2286,  893,  456]])

# %%
decoder_input_data.shape
# Out:
# (10000, 59)

# %%
decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[:, 1:]

# %%
decoder_target_data
# Out:
# array([[   0,    0,    0, ...,   92,    2,    0],
#        [   0,    0,    0, ...,    0,  991,    0],
#        [   0,    0,    0, ...,  334,    2,    0],
#        ...,
#        [   0,    0,    0, ..., 5804,  380,    0],
#        [   0,    0,    0, ..., 5805,  380,    0],
#        [   0,    0,    0, ...,  893,  456,    0]])

# %%
decoder_target_data.shape
# Out:
# (10000, 59)

# %% [markdown]
# ### vocabs

# %%
eng_vocabs = len(eng_tokenizer.word_index) + 1
fra_vocabs = len(fra_tokenizer.word_index) + 1
print(f"{eng_vocabs} :: {fra_vocabs}")
# Out:
# 2707 :: 5806

# %% [markdown]
# ### creating the encoders and decoders

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding

# %%
latent_dim = 256

# %%
enc_inputs = Input(shape = (max_eng_word, ))
enc_emb = Embedding(eng_vocabs, latent_dim)(enc_inputs)
enc_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)
enc_outputs, state_h, state_c = enc_lstm(enc_emb)

# %%
dec_inputs = Input(shape = (max_fra_word, ))
dec_emb_layer = Embedding(fra_vocabs, latent_dim)
dec_emb = dec_emb_layer(dec_inputs)
dec_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)

# %% [markdown]
# ### creating the Bahdanau attention model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Dense, Concatenate

# %%
class BahdanauAttention(Layer) : 
    def __init__(self, units) : 
        super(BahdanauAttention, self).__init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, query, values) : 
        query_with_time_axis = tensorflow.expand_dims(query, 1)
        score = self.V(tensorflow.nn.tanh(self.W1(values)) + self.W2(query_with_time_axis))
        attention_weights = tensorflow.nn.softmax(score, 1)
        context_vector = attention_weights * score
        context_vector = tensorflow.reduce_sum(context_vector, 1)

        return context_vector, attention_weights

# %%
attention = BahdanauAttention(latent_dim)
all_outputs = []
decoder_state_h, decoder_state_c = state_h, state_c
for t in range(max_fra_word) : 
    context_vector, _ = attention(decoder_state_h, decoder_state_c)
    X = tensorflow.expand_dims(dec_emb[:, t], 1)
    X = Concatenate(axis = -1)([context_vector[:, None, :], X])
    outputs, decoder_state_h, decoder_state_c = dec_lstm(X, initial_state = [decoder_state_h, decoder_state_c])
    outputs = Dense(fra_vocabs, activation = 'softmax')(outputs)

    all_outputs.append(outputs)

dec_outputs = tensorflow.concat(all_outputs, 1)

# %%
model = Model()

# %%
model = Model([enc_inputs, dec_inputs], dec_outputs)
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  embedding (Embedding)          (None, 14, 256)      692992      ['input_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 59)]         0           []
#
#  lstm (LSTM)                    [(None, 14, 256),    525312      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_1 (Embedding)        (None, 59, 256)      1486336     ['input_2[0][0]']
#
#  bahdanau_attention_1 (Bahdanau  ((None, 1),         131841      ['lstm[0][1]',
#  Attention)                      (None, None, 1))                 'lstm[0][2]',
#                                                                   'lstm_1[59][1]',
#                                                                   'lstm_1[59][2]',
#                                                                   'lstm_1[60][1]',
#                                                                   'lstm_1[60][2]',
#                                                                   'lstm_1[61][1]',
#                                                                   'lstm_1[61][2]',
#                                                                   'lstm_1[62][1]',
#                                                                   'lstm_1[62][2]',
#                                                                   'lstm_1[63][1]',
#                                                                   'lstm_1[63][2]',
#                                                                   'lstm_1[64][1]',
#                                                                   'lstm_1[64][2]',
#                                                                   'lstm_1[65][1]',
#                                                                   'lstm_1[65][2]',
#                                                                   'lstm_1[66][1]',
#                                                                   'lstm_1[66][2]',
#                                                                   'lstm_1[67][1]',
#                                                                   'lstm_1[67][2]',
#                                                                   'lstm_1[68][1]',
#                                                                   'lstm_1[68][2]',
#                                                                   'lstm_1[69][1]',
#                                                                   'lstm_1[69][2]',
#                                                                   'lstm_1[70][1]',
#                                                                   'lstm_1[70][2]',
#                                                                   'lstm_1[71][1]',
#                                                                   'lstm_1[71][2]',
#                                                                   'lstm_1[72][1]',
#                                                                   'lstm_1[72][2]',
#                                                                   'lstm_1[73][1]',
#                                                                   'lstm_1[73][2]',
#                                                                   'lstm_1[74][1]',
#                                                                   'lstm_1[74][2]',
#                                                                   'lstm_1[75][1]',
#                                                                   'lstm_1[75][2]',
#                                                                   'lstm_1[76][1]',
#                                                                   'lstm_1[76][2]',
#                                                                   'lstm_1[77][1]',
#                                                                   'lstm_1[77][2]',
#                                                                   'lstm_1[78][1]',
#                                                                   'lstm_1[78][2]',
#                                                                   'lstm_1[79][1]',
#                                                                   'lstm_1[79][2]',
#                                                                   'lstm_1[80][1]',
#                                                                   'lstm_1[80][2]',
#                                                                   'lstm_1[81][1]',
#                                                                   'lstm_1[81][2]',
#                                                                   'lstm_1[82][1]',
#                                                                   'lstm_1[82][2]',
#                                                                   'lstm_1[83][1]',
#                                                                   'lstm_1[83][2]',
#                                                                   'lstm_1[84][1]',
#                                                                   'lstm_1[84][2]',
#                                                                   'lstm_1[85][1]',
#                                                                   'lstm_1[85][2]',
#                                                                   'lstm_1[86][1]',
#                                                                   'lstm_1[86][2]',
#                                                                   'lstm_1[87][1]',
#                                                                   'lstm_1[87][2]',
#                                                                   'lstm_1[88][1]',
#                                                                   'lstm_1[88][2]',
#                                                                   'lstm_1[89][1]',
#                                                                   'lstm_1[89][2]',
#                                                                   'lstm_1[90][1]',
#                                                                   'lstm_1[90][2]',
#                                                                   'lstm_1[91][1]',
#                                                                   'lstm_1[91][2]',
#                                                                   'lstm_1[92][1]',
#                                                                   'lstm_1[92][2]',
#                                                                   'lstm_1[93][1]',
#                                                                   'lstm_1[93][2]',
#                                                                   'lstm_1[94][1]',
#                                                                   'lstm_1[94][2]',
#                                                                   'lstm_1[95][1]',
#                                                                   'lstm_1[95][2]',
#                                                                   'lstm_1[96][1]',
#                                                                   'lstm_1[96][2]',
#                                                                   'lstm_1[97][1]',
#                                                                   'lstm_1[97][2]',
#                                                                   'lstm_1[98][1]',
#                                                                   'lstm_1[98][2]',
#                                                                   'lstm_1[99][1]',
#                                                                   'lstm_1[99][2]',
#                                                                   'lstm_1[100][1]',
#                                                                   'lstm_1[100][2]',
#                                                                   'lstm_1[101][1]',
#                                                                   'lstm_1[101][2]',
#                                                                   'lstm_1[102][1]',
#                                                                   'lstm_1[102][2]',
#                                                                   'lstm_1[103][1]',
#                                                                   'lstm_1[103][2]',
#                                                                   'lstm_1[104][1]',
#                                                                   'lstm_1[104][2]',
#                                                                   'lstm_1[105][1]',
#                                                                   'lstm_1[105][2]',
#                                                                   'lstm_1[106][1]',
#                                                                   'lstm_1[106][2]',
#                                                                   'lstm_1[107][1]',
#                                                                   'lstm_1[107][2]',
#                                                                   'lstm_1[108][1]',
#                                                                   'lstm_1[108][2]',
#                                                                   'lstm_1[109][1]',
#                                                                   'lstm_1[109][2]',
#                                                                   'lstm_1[110][1]',
#                                                                   'lstm_1[110][2]',
#                                                                   'lstm_1[111][1]',
#                                                                   'lstm_1[111][2]',
#                                                                   'lstm_1[112][1]',
#                                                                   'lstm_1[112][2]',
#                                                                   'lstm_1[113][1]',
#                                                                   'lstm_1[113][2]',
#                                                                   'lstm_1[114][1]',
#                                                                   'lstm_1[114][2]',
#                                                                   'lstm_1[115][1]',
#                                                                   'lstm_1[115][2]',
#                                                                   'lstm_1[116][1]',
#                                                                   'lstm_1[116][2]']
#
#  tf.__operators__.getitem_118 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_119 (  (None, 1, 1)        0           ['bahdanau_attention_1[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_59 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_118[0]
#                                                                  [0]']
#
#  concatenate_59 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_119[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_59[0][0]']
#
#  lstm_1 (LSTM)                  [(None, 1, 256),     526336      ['concatenate_59[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]',
#                                                                   'concatenate_60[0][0]',
#                                                                   'lstm_1[59][1]',
#                                                                   'lstm_1[59][2]',
#                                                                   'concatenate_61[0][0]',
#                                                                   'lstm_1[60][1]',
#                                                                   'lstm_1[60][2]',
#                                                                   'concatenate_62[0][0]',
#                                                                   'lstm_1[61][1]',
#                                                                   'lstm_1[61][2]',
#                                                                   'concatenate_63[0][0]',
#                                                                   'lstm_1[62][1]',
#                                                                   'lstm_1[62][2]',
#                                                                   'concatenate_64[0][0]',
#                                                                   'lstm_1[63][1]',
#                                                                   'lstm_1[63][2]',
#                                                                   'concatenate_65[0][0]',
#                                                                   'lstm_1[64][1]',
#                                                                   'lstm_1[64][2]',
#                                                                   'concatenate_66[0][0]',
#                                                                   'lstm_1[65][1]',
#                                                                   'lstm_1[65][2]',
#                                                                   'concatenate_67[0][0]',
#                                                                   'lstm_1[66][1]',
#                                                                   'lstm_1[66][2]',
#                                                                   'concatenate_68[0][0]',
#                                                                   'lstm_1[67][1]',
#                                                                   'lstm_1[67][2]',
#                                                                   'concatenate_69[0][0]',
#                                                                   'lstm_1[68][1]',
#                                                                   'lstm_1[68][2]',
#                                                                   'concatenate_70[0][0]',
#                                                                   'lstm_1[69][1]',
#                                                                   'lstm_1[69][2]',
#                                                                   'concatenate_71[0][0]',
#                                                                   'lstm_1[70][1]',
#                                                                   'lstm_1[70][2]',
#                                                                   'concatenate_72[0][0]',
#                                                                   'lstm_1[71][1]',
#                                                                   'lstm_1[71][2]',
#                                                                   'concatenate_73[0][0]',
#                                                                   'lstm_1[72][1]',
#                                                                   'lstm_1[72][2]',
#                                                                   'concatenate_74[0][0]',
#                                                                   'lstm_1[73][1]',
#                                                                   'lstm_1[73][2]',
#                                                                   'concatenate_75[0][0]',
#                                                                   'lstm_1[74][1]',
#                                                                   'lstm_1[74][2]',
#                                                                   'concatenate_76[0][0]',
#                                                                   'lstm_1[75][1]',
#                                                                   'lstm_1[75][2]',
#                                                                   'concatenate_77[0][0]',
#                                                                   'lstm_1[76][1]',
#                                                                   'lstm_1[76][2]',
#                                                                   'concatenate_78[0][0]',
#                                                                   'lstm_1[77][1]',
#                                                                   'lstm_1[77][2]',
#                                                                   'concatenate_79[0][0]',
#                                                                   'lstm_1[78][1]',
#                                                                   'lstm_1[78][2]',
#                                                                   'concatenate_80[0][0]',
#                                                                   'lstm_1[79][1]',
#                                                                   'lstm_1[79][2]',
#                                                                   'concatenate_81[0][0]',
#                                                                   'lstm_1[80][1]',
#                                                                   'lstm_1[80][2]',
#                                                                   'concatenate_82[0][0]',
#                                                                   'lstm_1[81][1]',
#                                                                   'lstm_1[81][2]',
#                                                                   'concatenate_83[0][0]',
#                                                                   'lstm_1[82][1]',
#                                                                   'lstm_1[82][2]',
#                                                                   'concatenate_84[0][0]',
#                                                                   'lstm_1[83][1]',
#                                                                   'lstm_1[83][2]',
#                                                                   'concatenate_85[0][0]',
#                                                                   'lstm_1[84][1]',
#                                                                   'lstm_1[84][2]',
#                                                                   'concatenate_86[0][0]',
#                                                                   'lstm_1[85][1]',
#                                                                   'lstm_1[85][2]',
#                                                                   'concatenate_87[0][0]',
#                                                                   'lstm_1[86][1]',
#                                                                   'lstm_1[86][2]',
#                                                                   'concatenate_88[0][0]',
#                                                                   'lstm_1[87][1]',
#                                                                   'lstm_1[87][2]',
#                                                                   'concatenate_89[0][0]',
#                                                                   'lstm_1[88][1]',
#                                                                   'lstm_1[88][2]',
#                                                                   'concatenate_90[0][0]',
#                                                                   'lstm_1[89][1]',
#                                                                   'lstm_1[89][2]',
#                                                                   'concatenate_91[0][0]',
#                                                                   'lstm_1[90][1]',
#                                                                   'lstm_1[90][2]',
#                                                                   'concatenate_92[0][0]',
#                                                                   'lstm_1[91][1]',
#                                                                   'lstm_1[91][2]',
#                                                                   'concatenate_93[0][0]',
#                                                                   'lstm_1[92][1]',
#                                                                   'lstm_1[92][2]',
#                                                                   'concatenate_94[0][0]',
#                                                                   'lstm_1[93][1]',
#                                                                   'lstm_1[93][2]',
#                                                                   'concatenate_95[0][0]',
#                                                                   'lstm_1[94][1]',
#                                                                   'lstm_1[94][2]',
#                                                                   'concatenate_96[0][0]',
#                                                                   'lstm_1[95][1]',
#                                                                   'lstm_1[95][2]',
#                                                                   'concatenate_97[0][0]',
#                                                                   'lstm_1[96][1]',
#                                                                   'lstm_1[96][2]',
#                                                                   'concatenate_98[0][0]',
#                                                                   'lstm_1[97][1]',
#                                                                   'lstm_1[97][2]',
#                                                                   'concatenate_99[0][0]',
#                                                                   'lstm_1[98][1]',
#                                                                   'lstm_1[98][2]',
#                                                                   'concatenate_100[0][0]',
#                                                                   'lstm_1[99][1]',
#                                                                   'lstm_1[99][2]',
#                                                                   'concatenate_101[0][0]',
#                                                                   'lstm_1[100][1]',
#                                                                   'lstm_1[100][2]',
#                                                                   'concatenate_102[0][0]',
#                                                                   'lstm_1[101][1]',
#                                                                   'lstm_1[101][2]',
#                                                                   'concatenate_103[0][0]',
#                                                                   'lstm_1[102][1]',
#                                                                   'lstm_1[102][2]',
#                                                                   'concatenate_104[0][0]',
#                                                                   'lstm_1[103][1]',
#                                                                   'lstm_1[103][2]',
#                                                                   'concatenate_105[0][0]',
#                                                                   'lstm_1[104][1]',
#                                                                   'lstm_1[104][2]',
#                                                                   'concatenate_106[0][0]',
#                                                                   'lstm_1[105][1]',
#                                                                   'lstm_1[105][2]',
#                                                                   'concatenate_107[0][0]',
#                                                                   'lstm_1[106][1]',
#                                                                   'lstm_1[106][2]',
#                                                                   'concatenate_108[0][0]',
#                                                                   'lstm_1[107][1]',
#                                                                   'lstm_1[107][2]',
#                                                                   'concatenate_109[0][0]',
#                                                                   'lstm_1[108][1]',
#                                                                   'lstm_1[108][2]',
#                                                                   'concatenate_110[0][0]',
#                                                                   'lstm_1[109][1]',
#                                                                   'lstm_1[109][2]',
#                                                                   'concatenate_111[0][0]',
#                                                                   'lstm_1[110][1]',
#                                                                   'lstm_1[110][2]',
#                                                                   'concatenate_112[0][0]',
#                                                                   'lstm_1[111][1]',
#                                                                   'lstm_1[111][2]',
#                                                                   'concatenate_113[0][0]',
#                                                                   'lstm_1[112][1]',
#                                                                   'lstm_1[112][2]',
#                                                                   'concatenate_114[0][0]',
#                                                                   'lstm_1[113][1]',
#                                                                   'lstm_1[113][2]',
#                                                                   'concatenate_115[0][0]',
#                                                                   'lstm_1[114][1]',
#                                                                   'lstm_1[114][2]',
#                                                                   'concatenate_116[0][0]',
#                                                                   'lstm_1[115][1]',
#                                                                   'lstm_1[115][2]',
#                                                                   'concatenate_117[0][0]',
#                                                                   'lstm_1[116][1]',
#                                                                   'lstm_1[116][2]']
#
#  tf.__operators__.getitem_120 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_121 (  (None, 1, 1)        0           ['bahdanau_attention_1[1][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_60 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_120[0]
#                                                                  [0]']
#
#  concatenate_60 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_121[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_60[0][0]']
#
#  tf.__operators__.getitem_122 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_123 (  (None, 1, 1)        0           ['bahdanau_attention_1[2][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_61 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_122[0]
#                                                                  [0]']
#
#  concatenate_61 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_123[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_61[0][0]']
#
#  tf.__operators__.getitem_124 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_125 (  (None, 1, 1)        0           ['bahdanau_attention_1[3][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_62 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_124[0]
#                                                                  [0]']
#
#  concatenate_62 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_125[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_62[0][0]']
#
#  tf.__operators__.getitem_126 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_127 (  (None, 1, 1)        0           ['bahdanau_attention_1[4][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_63 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_126[0]
#                                                                  [0]']
#
#  concatenate_63 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_127[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_63[0][0]']
#
#  tf.__operators__.getitem_128 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_129 (  (None, 1, 1)        0           ['bahdanau_attention_1[5][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_64 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_128[0]
#                                                                  [0]']
#
#  concatenate_64 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_129[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_64[0][0]']
#
#  tf.__operators__.getitem_130 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_131 (  (None, 1, 1)        0           ['bahdanau_attention_1[6][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_65 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_130[0]
#                                                                  [0]']
#
#  concatenate_65 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_131[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_65[0][0]']
#
#  tf.__operators__.getitem_132 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_133 (  (None, 1, 1)        0           ['bahdanau_attention_1[7][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_66 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_132[0]
#                                                                  [0]']
#
#  concatenate_66 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_133[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_66[0][0]']
#
#  tf.__operators__.getitem_134 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_135 (  (None, 1, 1)        0           ['bahdanau_attention_1[8][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_67 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_134[0]
#                                                                  [0]']
#
#  concatenate_67 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_135[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_67[0][0]']
#
#  tf.__operators__.getitem_136 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_137 (  (None, 1, 1)        0           ['bahdanau_attention_1[9][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_68 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_136[0]
#                                                                  [0]']
#
#  concatenate_68 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_137[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_68[0][0]']
#
#  tf.__operators__.getitem_138 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_139 (  (None, 1, 1)        0           ['bahdanau_attention_1[10][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_69 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_138[0]
#                                                                  [0]']
#
#  concatenate_69 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_139[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_69[0][0]']
#
#  tf.__operators__.getitem_140 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_141 (  (None, 1, 1)        0           ['bahdanau_attention_1[11][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_70 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_140[0]
#                                                                  [0]']
#
#  concatenate_70 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_141[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_70[0][0]']
#
#  tf.__operators__.getitem_142 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_143 (  (None, 1, 1)        0           ['bahdanau_attention_1[12][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_71 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_142[0]
#                                                                  [0]']
#
#  concatenate_71 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_143[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_71[0][0]']
#
#  tf.__operators__.getitem_144 (  (None, 256)         0           ['embedding_1[0][0]']
#  SlicingOpLambda)
#
# ...
#  dense_75 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[69][0]']
#
#  dense_76 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[70][0]']
#
#  dense_77 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[71][0]']
#
#  dense_78 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[72][0]']
#
#  dense_79 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[73][0]']
#
#  dense_80 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[74][0]']
#
#  dense_81 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[75][0]']
#
#  dense_82 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[76][0]']
#
#  dense_83 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[77][0]']
#
#  dense_84 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[78][0]']
#
#  dense_85 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[79][0]']
#
#  dense_86 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[80][0]']
#
#  dense_87 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[81][0]']
#
#  dense_88 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[82][0]']
#
#  dense_89 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[83][0]']
#
#  dense_90 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[84][0]']
#
#  dense_91 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[85][0]']
#
#  dense_92 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[86][0]']
#
#  dense_93 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[87][0]']
#
#  dense_94 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[88][0]']
#
#  dense_95 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[89][0]']
#
#  dense_96 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[90][0]']
#
#  dense_97 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[91][0]']
#
#  dense_98 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[92][0]']
#
#  dense_99 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[93][0]']
#
#  dense_100 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[94][0]']
#
#  dense_101 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[95][0]']
#
#  dense_102 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[96][0]']
#
#  dense_103 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[97][0]']
#
#  dense_104 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[98][0]']
#
#  dense_105 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[99][0]']
#
#  dense_106 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[100][0]']
#
#  dense_107 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[101][0]']
#
#  dense_108 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[102][0]']
#
#  dense_109 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[103][0]']
#
#  dense_110 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[104][0]']
#
#  dense_111 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[105][0]']
#
#  dense_112 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[106][0]']
#
#  dense_113 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[107][0]']
#
#  dense_114 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[108][0]']
#
#  dense_115 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[109][0]']
#
#  dense_116 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[110][0]']
#
#  dense_117 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[111][0]']
#
#  dense_118 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[112][0]']
#
#  dense_119 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[113][0]']
#
#  dense_120 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[114][0]']
#
#  dense_121 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[115][0]']
#
#  dense_122 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[116][0]']
#
#  dense_123 (Dense)              (None, 1, 5806)      1492142     ['lstm_1[117][0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 59, 5806)     0           ['dense_65[0][0]',
#                                                                   'dense_66[0][0]',
#                                                                   'dense_67[0][0]',
#                                                                   'dense_68[0][0]',
#                                                                   'dense_69[0][0]',
#                                                                   'dense_70[0][0]',
#                                                                   'dense_71[0][0]',
#                                                                   'dense_72[0][0]',
#                                                                   'dense_73[0][0]',
#                                                                   'dense_74[0][0]',
#                                                                   'dense_75[0][0]',
#                                                                   'dense_76[0][0]',
#                                                                   'dense_77[0][0]',
#                                                                   'dense_78[0][0]',
#                                                                   'dense_79[0][0]',
#                                                                   'dense_80[0][0]',
#                                                                   'dense_81[0][0]',
#                                                                   'dense_82[0][0]',
#                                                                   'dense_83[0][0]',
#                                                                   'dense_84[0][0]',
#                                                                   'dense_85[0][0]',
#                                                                   'dense_86[0][0]',
#                                                                   'dense_87[0][0]',
#                                                                   'dense_88[0][0]',
#                                                                   'dense_89[0][0]',
#                                                                   'dense_90[0][0]',
#                                                                   'dense_91[0][0]',
#                                                                   'dense_92[0][0]',
#                                                                   'dense_93[0][0]',
#                                                                   'dense_94[0][0]',
#                                                                   'dense_95[0][0]',
#                                                                   'dense_96[0][0]',
#                                                                   'dense_97[0][0]',
#                                                                   'dense_98[0][0]',
#                                                                   'dense_99[0][0]',
#                                                                   'dense_100[0][0]',
#                                                                   'dense_101[0][0]',
#                                                                   'dense_102[0][0]',
#                                                                   'dense_103[0][0]',
#                                                                   'dense_104[0][0]',
#                                                                   'dense_105[0][0]',
#                                                                   'dense_106[0][0]',
#                                                                   'dense_107[0][0]',
#                                                                   'dense_108[0][0]',
#                                                                   'dense_109[0][0]',
#                                                                   'dense_110[0][0]',
#                                                                   'dense_111[0][0]',
#                                                                   'dense_112[0][0]',
#                                                                   'dense_113[0][0]',
#                                                                   'dense_114[0][0]',
#                                                                   'dense_115[0][0]',
#                                                                   'dense_116[0][0]',
#                                                                   'dense_117[0][0]',
#                                                                   'dense_118[0][0]',
#                                                                   'dense_119[0][0]',
#                                                                   'dense_120[0][0]',
#                                                                   'dense_121[0][0]',
#                                                                   'dense_122[0][0]',
#                                                                   'dense_123[0][0]']
#
# ==================================================================================================
# Total params: 91,399,195
# Trainable params: 91,399,195
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(
    [encoder_input_data, decoder_input_data],
    np.expand_dims(decoder_target_data, -1),
    batch_size = 128,
    epochs = 3,
    validation_split = 0.2
)
# Out:
# Epoch 1/3
# 63/63 [==============================] - 308s 3s/step - loss: 2.5067 - accuracy: 0.8840 - val_loss: 0.4293 - val_accuracy: 0.9420
# Epoch 2/3
# 63/63 [==============================] - 185s 3s/step - loss: 0.3484 - accuracy: 0.9496 - val_loss: 0.4311 - val_accuracy: 0.9420
# Epoch 3/3
# 63/63 [==============================] - 185s 3s/step - loss: 0.3452 - accuracy: 0.9496 - val_loss: 0.4394 - val_accuracy: 0.9420
