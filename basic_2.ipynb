# %% [markdown]
# ## Attention models : 2

# %% [markdown]
# ### data laoding

# %%
import pandas as pd
import numpy as np

# %%
path = 'fra.txt'
english_texts, french_texts = [], []
num_samples = 10000

# %%
with open(path, 'r', encoding = 'UTF-8') as f : 
    lines = f.read().split('\n')

    for line in lines[:num_samples] : 
        english_words, french_words = line.split('\t')[:2]

        french_words = '\t' + french_words + '\n'

        english_texts.append(english_words)
        french_texts.append(french_words)

# %%
max_eng_word = max([len(words) for words in english_texts])
max_fra_word = max([len(words) for words in french_texts])
print(f"{max_eng_word} :: {max_fra_word}")
# Out:
# 14 :: 59

# %% [markdown]
# ### data prep : tokenizer and pad_sequences

# %%
import tensorflow
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
eng_tokenizer = Tokenizer(filters = ' ', lower = True)
eng_tokenizer.fit_on_texts(english_texts)
english_texts = eng_tokenizer.texts_to_sequences(english_texts)

# %%
english_texts
# Out:
# [[30],
#  [30],
#  [30],
#  [30],
#  [492],
#  [492],
#  [445],
#  [445],
#  [445],
#  [445],
#  [445],
#  [445],
#  [445],
#  [445],
#  [144],
#  [144],
#  [144],
#  [144],
#  [144],
#  [144],
#  [144],
#  [144],
#  [1232],
#  [961],
#  [961],
#  [961],
#  [962],
#  [962],
#  [962],
#  [1233],
#  [1822],
#  [643],
#  [643],
#  [963],
#  [1234],
#  [644],
#  [644],
#  [644],
#  [964],
#  [964],
#  [964],
#  [145],
#  [145],
#  [145],
#  [145],
#  [768],
#  [768],
#  [21, 114],
#  [21, 114],
#  [21, 114],
#  [1235],
#  [1235],
#  [645],
#  [645],
#  [645],
#  [645],
#  [1, 210],
#  [1, 210],
#  [1, 153],
#  [1, 769],
#  [1, 769],
#  [1, 118],
#  [1823, 1824],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [181],
#  [770],
#  [770],
#  [355],
#  [355],
#  [355],
#  [1825],
#  [771],
#  [771],
#  [771],
#  [771],
#  [194, 8],
#  [194, 8],
#  [194, 8],
#  [194, 8],
#  [772],
#  [772],
#  [772],
#  [772],
#  [159, 8],
#  [159, 8],
#  [1826],
#  [16, 23],
#  [16, 23],
#  [16, 23],
#  [21, 112],
#  [21, 112],
#  [21, 112],
#  [36, 89],
#  [36, 89],
#  [36, 89],
#  [36, 71],
#  [36, 71],
#  [36, 71],
#  [1236, 72],
#  [1236, 72],
#  [493, 15],
#  [493, 15],
#  [1, 646],
#  [1, 646],
#  [1, 1827],
#  [1, 1828],
#  [1, 1829],
#  [1, 139],
#  [1, 154],
#  [1, 154],
#  [1, 154],
#  [1, 154],
#  [1, 647],
#  [1, 76],
#  [1, 648],
#  [1, 648],
#  [1, 648],
#  [1, 773],
#  [1, 241],
#  [1, 241],
#  [1, 261],
#  [2, 1830],
#  [2, 103],
#  [2, 103],
#  [1831],
#  [774],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [47, 286],
#  [494],
#  [494],
#  [494],
#  [494],
#  [494],
#  [1832],
#  [356],
#  [356],
#  [356],
#  [80, 8],
#  [80, 8],
#  [80, 8],
#  [10, 153],
#  [10, 118],
#  [10, 118],
#  [10, 118],
#  [10, 118],
#  [10, 118],
#  [110, 20],
#  [110, 57],
#  [965],
#  [965],
#  [965],
#  [558],
#  [12, 160],
#  [12, 160],
#  [12, 160],
#  [12, 146],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 161],
#  [12, 324],
#  [12, 195],
#  [12, 195],
#  [12, 195],
#  [12, 195],
#  [12, 195],
#  [12, 195],
#  [155, 89],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [155, 8],
#  [559, 8],
#  [559, 8],
#  [559, 8],
#  [559, 8],
#  [775, 8],
#  [775, 8],
#  [775, 8],
#  [775, 8],
#  [140, 15],
#  [140, 15],
#  [140, 63],
#  [140, 63],
#  [46, 72],
#  [46, 72],
#  [46, 72],
#  [46, 72],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 299],
#  [46, 114],
#  [46, 114],
#  [46, 114],
#  [242, 89],
#  [242, 89],
#  [242, 89],
#  [242, 89],
#  [776, 8],
#  [776, 8],
#  [776, 8],
#  [776, 8],
#  [16, 20],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 86],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [16, 69],
#  [21, 113],
#  [21, 113],
#  [21, 113],
#  [21, 113],
#  [21, 113],
#  [21, 113],
#  [21, 113],
#  [21, 113],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 100],
#  [21, 84],
#  [21, 78],
#  [21, 78],
#  [21, 78],
#  [21, 78],
#  [21, 777],
#  [21, 777],
#  [966],
#  [966],
#  [966],
#  [967],
#  [196, 299],
#  [196, 299],
#  [196, 299],
#  [196, 114],
#  [196, 114],
#  [196, 114],
#  [14, 154],
#  [14, 1237],
#  [104, 162],
#  [104, 15],
#  [104, 15],
#  [104, 15],
#  [104, 15],
#  [104, 63],
#  [104, 63],
#  [778, 15],
#  [778, 15],
#  [778, 15],
#  [778, 15],
#  [122, 89],
#  [122, 89],
#  [122, 89],
#  [122, 89],
#  [122, 114],
#  [122, 114],
#  [122, 114],
#  [122, 114],
#  [122, 114],
#  [122, 23],
#  [122, 23],
#  [62, 1833],
#  [493, 20],
#  [1, 446],
#  [1, 402],
#  [1, 1238],
#  [1, 1238],
#  [1, 403],
#  [1, 1834],
#  [1, 287],
#  [1, 1239],
#  [1, 1239],
#  [1, 649],
#  [1, 968],
#  [1, 779],
#  [1, 1240],
#  [1, 1240],
#  [1, 1241],
#  [1, 1241],
#  [1, 357],
#  [1, 357],
#  [1, 357],
#  [1, 1242],
#  [26, 30],
#  [2, 20],
#  [2, 211],
#  [2, 211],
#  [2, 1243],
#  [2, 1244],
#  [2, 1244],
#  [2, 404],
#  [2, 163],
#  [2, 163],
#  [2, 163],
#  [2, 96],
#  [2, 96],
#  [2, 96],
#  [2, 325],
#  [2, 560],
#  [2, 560],
#  [9, 162],
#  [405, 15],
#  [405, 63],
#  [405, 63],
#  [35, 8],
#  [35, 8],
#  [1245, 8],
#  [1245, 8],
#  [288, 8],
#  [288, 8],
#  [288, 8],
#  [288, 8],
#  [969, 15],
#  [969, 15],
#  [447, 970],
#  [447, 970],
#  [289, 8],
#  [289, 8],
#  [289, 8],
#  [289, 8],
#  [68, 23],
#  [68, 23],
#  [650, 225],
#  [650, 225],
#  [358, 114],
#  [358, 114],
#  [212, 8],
#  [212, 8],
#  [212, 8],
#  [212, 8],
#  [212, 23],
#  [212, 23],
#  [1835, 23],
#  [971],
#  [971],
#  [971],
#  [651, 8],
#  [651, 8],
#  [243, 8],
#  [243, 8],
#  [243, 8],
#  [243, 8],
#  [243, 8],
#  [77, 326],
#  [77, 326],
#  [77, 326],
#  [77, 326],
#  [77, 17],
#  [77, 17],
#  [300, 15],
#  [300, 15],
#  [213, 131],
#  [213, 131],
#  [213, 131],
#  [213, 131],
#  [213, 131],
#  [213, 131],
#  [213, 131],
#  [213, 131],
#  [495, 23],
#  [495, 23],
#  [1246, 8],
#  [1246, 8],
#  [97, 652],
#  [27, 8],
#  [27, 8],
#  [27, 8],
#  [27, 8],
#  [27, 8],
#  [27, 8],
#  [226, 15],
#  [226, 15],
#  [3, 118],
#  [262, 131],
#  [262, 131],
#  [262, 131],
#  [262, 23],
#  [262, 23],
#  [1247, 23],
#  [1247, 23],
#  [10, 182],
#  [10, 139],
#  [10, 139],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [10, 76],
#  [1248],
#  [1248],
#  [52, 1836],
#  [52, 1249],
#  [52, 1249],
#  [7, 144],
#  [7, 132],
#  [780, 781],
#  [780, 781],
#  [48, 1, 972],
#  [48, 1, 972],
#  [110, 91],
#  [110, 91],
#  [214, 496],
#  [214, 496],
#  [214, 496],
#  [214, 263],
#  [214, 263],
#  [214, 263],
#  [214, 263],
#  [214, 263],
#  [12, 5, 653],
#  [12, 5, 653],
#  [12, 359],
#  [12, 406],
#  [12, 406],
#  [12, 406],
#  [12, 406],
#  [12, 406],
#  [12, 406],
#  [12, 136],
#  [12, 133],
#  [12, 133],
#  [12, 133],
#  [1837, 263],
#  [140, 20],
#  [140, 20],
#  [24, 1, 126],
#  [1250, 131],
#  [1250, 23],
#  [973, 496],
#  [782, 15],
#  [1838, 57],
#  [407, 114],
#  [407, 114],
#  [407, 114],
#  [407, 114],
#  [290, 20],
#  [290, 20],
#  [360, 56],
#  [360, 56],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 113],
#  [16, 100],
#  [16, 100],
#  [16, 264],
#  [16, 264],
#  [16, 264],
#  [16, 264],
#  [16, 82],
#  [16, 82],
#  [16, 82],
#  [16, 82],
#  [16, 82],
#  [16, 82],
#  [16, 82],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 361],
#  [16, 76],
#  [16, 76],
#  [16, 76],
#  [16, 76],
#  [16, 76],
#  [16, 76],
#  [16, 76],
#  [16, 1251],
#  [16, 1251],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 265],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [21, 197],
#  [215, 783],
#  [215, 783],
#  [215, 783],
#  [215, 783],
#  [169, 20],
#  [169, 20],
#  [169, 57],
#  [169, 57],
#  [169, 57],
#  [33, 123],
#  [33, 123],
#  [33, 123],
#  [33, 123],
#  [14, 497],
#  [14, 497],
#  [14, 497],
#  [14, 974],
#  [54, 560],
#  [104, 20],
#  [104, 20],
#  [104, 20],
#  [1839, 1840],
#  [448, 84],
#  [448, 84],
#  [62, 975],
#  [62, 975],
#  [62, 975],
#  [62, 1841],
#  [62, 654],
#  [62, 654],
#  [62, 654],
#  [62, 654],
#  [62, 654],
#  [62, 1252],
#  [62, 1252],
#  [62, 1842],
#  [362, 23],
#  [362, 23],
#  [362, 23],
#  [362, 23],
#  [362, 23],
#  [362, 23],
#  [1, 48, 20],
#  [1, 1843],
#  [1, 42, 103],
#  [1, 42, 103],
#  [1, 42, 8],
#  [1, 42, 8],
#  [1, 784],
#  [1, 785],
#  [1, 16, 8],
#  [1, 786],
#  [1, 786],
#  [1, 786],
#  [1, 36, 8],
#  [1, 36, 8],
#  [1, 655],
#  [1, 1253],
#  [1, 976],
#  [1, 1254],
#  [1, 1255],
#  [1, 656],
#  [1, 1256],
#  [1, 1256],
#  [1, 787],
#  [1, 787],
#  [1, 498],
#  [1, 498],
#  [1, 58, 8],
#  [1, 58, 8],
#  [1, 1257],
#  [1, 449],
#  [1, 977],
#  [1, 977],
#  [1, 450],
#  [1, 244, 8],
#  [1, 244, 8],
#  [1, 244, 8],
#  [26, 408],
#  [26, 408],
#  [26, 153],
#  [26, 153],
#  [2, 84],
#  [2, 84],
#  [2, 978],
#  [2, 116],
#  [2, 116],
#  [2, 160],
#  [2, 216],
#  [2, 146],
#  [2, 146],
#  [2, 561],
#  [2, 561],
#  [2, 227],
#  [2, 161],
#  [2, 161],
#  [2, 161],
#  [2, 245],
#  [2, 266],
#  [2, 266],
#  [2, 266],
#  [2, 1844],
#  [2, 183],
#  [2, 183],
#  [2, 657],
#  [2, 657],
#  [2, 1258],
#  [2, 1258],
#  [2, 658],
#  [2, 101],
#  [2, 101],
#  [2, 78],
#  [2, 164],
#  [2, 156],
#  [2, 156],
#  [2, 156],
#  [2, 156],
#  [2, 76],
#  [2, 76],
#  [2, 979],
#  [2, 979],
#  [2, 246],
#  [2, 92],
#  [2, 217],
#  [2, 363],
#  [2, 363],
#  [2, 363],
#  [2, 363],
#  [2, 562],
#  [2, 451],
#  [2, 1259],
#  [2, 1259],
#  [2, 327],
#  [2, 327],
#  [2, 327],
#  [2, 228],
#  [2, 147],
#  [2, 147],
#  [117, 118],
#  [117, 118],
#  [6, 1845],
#  [6, 328],
#  [6, 563],
#  [6, 563],
#  [9, 20],
#  [9, 123],
#  [9, 123],
#  [9, 499],
#  [9, 499],
#  [9, 229],
#  [9, 364],
#  [9, 364],
#  [9, 500],
#  [9, 788],
#  [9, 96],
#  [35, 86],
#  [35, 69],
#  [288, 20],
#  [288, 20],
#  [969, 20],
#  [137, 8],
#  [137, 8],
#  [137, 8],
#  [137, 8],
#  [137, 8],
#  [137, 15],
#  [137, 63],
#  [137, 63],
#  [50, 230],
#  [50, 230],
#  [50, 230],
#  [50, 30],
#  [50, 30],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [68, 86],
#  [1260, 15],
#  [1260, 15],
#  [93, 1, 126],
#  [93, 1, 126],
#  [93, 1, 126],
#  [501, 153],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [301],
#  [170, 644],
#  [170, 644],
#  [980, 8],
#  [980, 8],
#  [247, 100],
#  [247, 100],
#  [247, 100],
#  [247, 100],
#  [502, 20],
#  [502, 20],
#  [267, 1261],
#  [49, 365],
#  [49, 268],
#  [49, 154],
#  [49, 1237],
#  [165, 264],
#  [165, 264],
#  [165, 264],
#  [165, 82],
#  [165, 82],
#  [165, 59],
#  [165, 59],
#  [269, 131],
#  [269, 131],
#  [269, 131],
#  [1262, 23],
#  [1262, 23],
#  [166, 23],
#  [55, 20],
#  [55, 20],
#  [27, 20],
#  [503, 8],
#  [503, 8],
#  [503, 8],
#  [503, 8],
#  [226, 20],
#  [226, 20],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [22, 118],
#  [22, 118],
#  [22, 118],
#  [22, 118],
#  [3, 365],
#  [3, 268],
#  [3, 789],
#  [3, 154],
#  [3, 154],
#  [3, 647],
#  [3, 1846],
#  [3, 76],
#  [3, 648],
#  [3, 648],
#  [3, 1263],
#  [43, 23],
#  [119, 164],
#  [790, 8],
#  [790, 8],
#  [790, 8],
#  [790, 8],
#  [127, 162],
#  [127, 15],
#  [127, 15],
#  [127, 15],
#  [127, 15],
#  [80, 452],
#  [80, 452],
#  [80, 452],
#  [80, 56],
#  [80, 56],
#  [80, 56],
#  [244, 56],
#  [244, 56],
#  [244, 56],
#  [244, 56],
#  [981, 20],
#  [981, 20],
#  [198, 15],
#  [198, 15],
#  [198, 63],
#  [198, 63],
#  [10, 446],
#  [102, 30],
#  [40, 103],
#  [67, 982],
#  [67, 982],
#  [67, 1264],
#  [67, 1264],
#  [52, 48, 791],
#  [52, 1847],
#  [52, 1265],
#  [52, 1848],
#  [52, 302],
#  [52, 1266],
#  [52, 1266],
#  [52, 1849],
#  [231, 366],
#  [409, 15],
#  [409, 15],
#  [7, 76],
#  [7, 76],
#  [7, 76],
#  [329, 17],
#  [329, 17],
#  [329, 17],
#  [329, 17],
#  [1850, 1233],
#  [48, 1, 659],
#  [48, 1, 1851],
#  [983, 15],
#  [12, 660],
#  [12, 660],
#  [12, 660],
#  [12, 270],
#  [12, 270],
#  [12, 270],
#  [12, 367],
#  [1267, 984],
#  [661, 17],
#  [140, 1852],
#  [564, 264],
#  [564, 264],
#  [564, 264],
#  [564, 82],
#  [564, 82],
#  [564, 82],
#  [24, 10, 126],
#  [24, 10, 126],
#  [24, 10, 126],
#  [504, 20],
#  [504, 20],
#  [504, 57],
#  [504, 57],
#  [504, 57],
#  [1268, 69],
#  [1268, 69],
#  [792, 15],
#  [46, 84],
#  [46, 84],
#  [46, 59],
#  [46, 59],
#  [46, 120],
#  [46, 120],
#  [46, 120],
#  [46, 120],
#  [46, 120],
#  [46, 793],
#  [46, 793],
#  [973, 82],
#  [42, 1, 453],
#  [42, 1, 453],
#  [42, 1, 453],
#  [25, 6, 112],
#  [794, 1269],
#  [794, 1269],
#  [18, 985],
#  [18, 303],
#  [18, 184],
#  [18, 184],
#  [18, 565],
#  [18, 565],
#  [18, 144],
#  [18, 144],
#  [454, 15],
#  [454, 15],
#  [454, 15],
#  [454, 128],
#  [454, 128],
#  [454, 128],
#  [454, 128],
#  [454, 128],
#  [986],
#  [986],
#  [986],
#  ...]

# %%
fra_tokenizer = Tokenizer(filters = ' ', lower = True)
fra_tokenizer.fit_on_texts(french_texts)
french_texts = fra_tokenizer.texts_to_sequences(french_texts)
french_texts
# Out:
# [[92, 2],
#  [991],
#  [145, 334, 2],
#  [335, 2],
#  [753, 2],
#  [1417],
#  [1418],
#  [1419],
#  [100, 251, 617, 14, 251, 992, 2],
#  [754, 2],
#  [993, 2],
#  [994, 2],
#  [1420, 2],
#  [1421, 2],
#  [1418],
#  [1419],
#  [100, 251, 617, 14, 251, 992, 2],
#  [754, 2],
#  [993, 2],
#  [994, 2],
#  [1420, 2],
#  [1421, 2],
#  [41, 5],
#  [33, 2547],
#  [2548],
#  [2549],
#  [106, 2550],
#  [2551],
#  [2552],
#  [301, 755, 2],
#  [106, 1422, 2],
#  [2553],
#  [2554],
#  [995],
#  [995],
#  [33, 1423],
#  [2555],
#  [618, 2],
#  [192, 2],
#  [237, 2],
#  [619],
#  [192, 2],
#  [237, 2],
#  [1424],
#  [619],
#  [1425],
#  [1426],
#  [2556],
#  [2557],
#  [2558],
#  [996, 2],
#  [753, 2],
#  [996, 2],
#  [753, 2],
#  [1427],
#  [1417],
#  [1, 1428],
#  [2559],
#  [1429],
#  [10, 302, 2],
#  [1, 59, 513, 2],
#  [86, 188],
#  [2560, 336, 2],
#  [997],
#  [998],
#  [999],
#  [1430, 1431],
#  [1432, 1433],
#  [176, 756],
#  [1000, 2],
#  [620, 2],
#  [1434],
#  [757, 2],
#  [176, 122],
#  [252],
#  [1435, 2],
#  [1436, 2],
#  [2561],
#  [2562, 163, 17, 2563],
#  [2564],
#  [1001, 5],
#  [2565, 2],
#  [2566, 2],
#  [106, 2567, 2],
#  [106, 2568],
#  [2569, 2],
#  [2570, 2],
#  [2571, 2],
#  [2572, 2],
#  [1437, 2],
#  [106, 135, 2573, 2],
#  [238, 2],
#  [2574, 2],
#  [2575],
#  [2576],
#  [2577],
#  [1438],
#  [2578, 2],
#  [2579],
#  [2580, 130],
#  [621, 130],
#  [622, 130],
#  [10, 2581, 2],
#  [2582, 2],
#  [2583, 2],
#  [2584],
#  [2585],
#  [1439, 2586],
#  [2587],
#  [2588],
#  [514, 152, 337, 758, 2],
#  [623, 152, 251, 758, 2],
#  [1, 3, 1002],
#  [1, 3, 1003],
#  [10, 2589],
#  [1, 2590],
#  [1, 1440],
#  [1, 759],
#  [1, 3, 253],
#  [1, 3, 1004],
#  [1, 760],
#  [1, 2591],
#  [10, 388],
#  [10, 146],
#  [1, 2592],
#  [1, 2593],
#  [86, 1005],
#  [1, 1441],
#  [2594],
#  [10, 1442],
#  [1, 2595],
#  [10, 2596, 389],
#  [1, 87, 53],
#  [33, 624],
#  [1443],
#  [1444, 2],
#  [6, 11, 1006],
#  [2597],
#  [1007, 8, 2598],
#  [145, 2599, 1445],
#  [515, 2600],
#  [303, 2601],
#  [6, 2602, 8, 1008, 2],
#  [9, 338, 7, 11, 1008, 2],
#  [6, 2603, 2],
#  [145, 339, 2604, 2],
#  [1007, 8, 1008, 2],
#  [515, 443, 2],
#  [1009],
#  [1010, 5],
#  [390, 202, 5],
#  [390, 391, 5],
#  [1011, 5],
#  [238, 2],
#  [1, 46, 625],
#  [238, 2],
#  [1446],
#  [1012],
#  [2605],
#  [2606],
#  [54, 761],
#  [12, 66, 188],
#  [12, 2607],
#  [12, 392, 626],
#  [12, 2608],
#  [54, 16, 188],
#  [277, 14, 22],
#  [2609],
#  [1013],
#  [762, 2],
#  [763, 2610, 2],
#  [2611],
#  [50, 444, 2],
#  [34, 444, 2],
#  [34, 1447, 2],
#  [50, 2612, 2],
#  [50, 181, 2],
#  [34, 181, 2],
#  [34, 2613, 2],
#  [50, 1448, 2],
#  [34, 1448, 2],
#  [34, 2614, 2],
#  [50, 764],
#  [50, 627],
#  [34, 1014],
#  [50, 254],
#  [50, 628, 2],
#  [50, 1449, 2],
#  [34, 628, 2],
#  [34, 1449, 2],
#  [34, 2615, 2],
#  [34, 2616, 2],
#  [2617],
#  [92, 46, 139, 1450, 2],
#  [445],
#  [629],
#  [340, 2],
#  [2618, 13, 446, 2],
#  [1015, 13, 446, 2],
#  [340, 516],
#  [1016],
#  [630, 2],
#  [447, 13, 393],
#  [1451, 8, 131],
#  [2619, 8, 131],
#  [1017, 2],
#  [1018],
#  [447, 13, 446, 516],
#  [448],
#  [335, 2],
#  [341, 2],
#  [2620],
#  [2621],
#  [2622],
#  [2623],
#  [2624],
#  [2625],
#  [2626],
#  [2627],
#  [2628, 2],
#  [2629],
#  [2630, 2],
#  [2631, 2],
#  [1452],
#  [765],
#  [1453, 2],
#  [2632, 2],
#  [1019],
#  [145, 1454],
#  [766, 2],
#  [6, 11, 2633, 631, 2],
#  [1455],
#  [1456],
#  [2634, 2],
#  [2635, 2],
#  [1020, 1457, 51, 2636],
#  [140, 2],
#  [1455],
#  [1456],
#  [153, 394, 2],
#  [203, 394, 2],
#  [395, 394, 2],
#  [517, 394, 2],
#  [2637],
#  [2638],
#  [2639],
#  [2640],
#  [92, 215, 22],
#  [767],
#  [1458],
#  [445],
#  [1459],
#  [629],
#  [1460, 2],
#  [1461, 2],
#  [1021, 2],
#  [1022, 2],
#  [630, 2],
#  [176, 2641, 2],
#  [447, 13, 393],
#  [1017, 2],
#  [1462, 2642, 2],
#  [1023, 13, 446, 2],
#  [1024],
#  [449, 2],
#  [341, 2],
#  [767],
#  [1458],
#  [445],
#  [1459],
#  [629],
#  [1460, 2],
#  [1461, 2],
#  [1021, 2],
#  [630, 2],
#  [447, 13, 393],
#  [1017, 2],
#  [1024],
#  [335, 2],
#  [449, 2],
#  [341, 2],
#  [445],
#  [340, 2],
#  [1463],
#  [448],
#  [450],
#  [335, 2],
#  [449, 2],
#  [341, 2],
#  [92, 46, 139, 1450, 2],
#  [340, 2],
#  [1022, 2],
#  [1015, 13, 446, 2],
#  [340, 516],
#  [1016],
#  [630, 2],
#  [448],
#  [450],
#  [335, 2],
#  [449, 2],
#  [341, 2],
#  [2643],
#  [1464],
#  [1465, 14, 17, 147],
#  [768, 14, 17, 147],
#  [768, 94, 116],
#  [1465, 94, 148],
#  [92, 1466, 2],
#  [140, 1466, 2],
#  [2644, 2],
#  [106, 17, 2645],
#  [769],
#  [769],
#  [192, 18, 518, 2],
#  [237, 18, 518, 2],
#  [619],
#  [342, 202, 2],
#  [632, 202, 2],
#  [619],
#  [9, 7, 253],
#  [9, 633],
#  [770, 2],
#  [106, 1422, 2],
#  [2646],
#  [2647],
#  [770, 2],
#  [2648, 2],
#  [2649, 2],
#  [2650],
#  [2651],
#  [2652],
#  [2653],
#  [26, 519, 132, 2],
#  [26, 634, 132, 2],
#  [57, 1025, 21, 38, 2],
#  [619],
#  [26, 1467, 36],
#  [1424],
#  [26, 771, 11, 2],
#  [772, 2],
#  [2654, 2],
#  [342, 154],
#  [632, 154],
#  [155, 73, 114],
#  [93, 18, 1468, 14, 22],
#  [1, 3, 48, 2655, 2656],
#  [10, 343],
#  [1, 15, 3, 2657],
#  [1, 15, 3, 2658],
#  [1, 1026],
#  [1, 2659],
#  [10, 1469],
#  [1, 15, 3, 2660],
#  [1, 15, 3, 2661],
#  [1, 2662],
#  [1, 1470],
#  [1, 451],
#  [1, 15, 3, 2663, 204],
#  [1, 15, 3, 1027, 204],
#  [86, 452],
#  [86, 1471],
#  [2664],
#  [10, 304],
#  [10, 1028],
#  [86, 35, 1029],
#  [1030],
#  [1, 3, 22],
#  [1, 3, 1031],
#  [1, 3, 255],
#  [1, 3, 19, 2665],
#  [1, 3, 1472, 2],
#  [1, 3, 2666, 2],
#  [1, 3, 156],
#  [1, 3, 170],
#  [1, 3, 635],
#  [1, 3, 19, 256],
#  [1, 3, 114],
#  [10, 18, 193, 8, 1473],
#  [1, 3, 636],
#  [1, 3, 305],
#  [1, 3, 773],
#  [1, 3, 2667],
#  [6, 1474],
#  [2668],
#  [2669],
#  [1475, 14, 171],
#  [1476, 2],
#  [2670, 2],
#  [1477, 18, 193, 8, 520],
#  [2671, 18, 193, 8, 520],
#  [2672],
#  [2673],
#  [2674],
#  [2675],
#  [2676],
#  [2677],
#  [106, 1032, 2],
#  [301, 1033, 2],
#  [2678],
#  [2679],
#  [2680],
#  [2681],
#  [2682, 28, 194],
#  [2683, 28, 194],
#  [774, 521],
#  [106, 117, 521],
#  [2684, 14, 1034, 1035],
#  [775, 14, 1034, 1035],
#  [1478],
#  [2685],
#  [2686],
#  [1479],
#  [2687],
#  [2688],
#  [111, 1480],
#  [2689],
#  [1481],
#  [2690, 2],
#  [1436, 229],
#  [1435, 229],
#  [2691, 229],
#  [2692],
#  [2693],
#  [2694],
#  [2695],
#  [106, 132, 1482],
#  [106, 776, 2],
#  [106, 17, 2696, 2],
#  [769],
#  [106, 278],
#  [769],
#  [1483, 2],
#  [1484, 2],
#  [2697],
#  [2698],
#  [2699, 2],
#  [2700, 2],
#  [98, 2701, 2],
#  [1485, 2],
#  [2702],
#  [2703],
#  [2704],
#  [2705],
#  [153, 205],
#  [239, 1036],
#  [106, 132, 1482],
#  [2706],
#  [2707],
#  [2708, 2],
#  [2709, 2],
#  [1037],
#  [1486],
#  [2710, 2],
#  [2711, 2],
#  [4, 16, 188],
#  [2712],
#  [1487, 2],
#  [1488, 2],
#  [1487, 2],
#  [1488, 2],
#  [2713, 2],
#  [2714, 2],
#  [12, 31, 19, 2715],
#  [12, 2716],
#  [54, 396],
#  [12, 2717],
#  [12, 66, 146],
#  [12, 777, 1489],
#  [12, 777, 1490],
#  [12, 777, 1491],
#  [12, 777, 1492],
#  [12, 66, 44, 1491],
#  [12, 66, 44, 1492],
#  [12, 66, 44, 1489],
#  [12, 66, 44, 1490],
#  [2718],
#  [34, 13, 1038, 2],
#  [41, 2719],
#  [41, 16, 302, 5],
#  [41, 99, 513, 5],
#  [24, 1493],
#  [23, 164, 188],
#  [1494, 397],
#  [1495, 397],
#  [118, 778, 5],
#  [118, 2720, 5],
#  [2721],
#  [2722],
#  [1039],
#  [1040],
#  [450],
#  [1039],
#  [1040],
#  [2723],
#  [2724],
#  [450],
#  [50, 18, 1496, 2],
#  [34, 18, 1496, 2],
#  [34, 2725, 2],
#  [34, 637],
#  [50, 637],
#  [50, 522],
#  [34, 522],
#  [34, 2726],
#  [34, 2727],
#  [453, 1497],
#  [50, 444, 2],
#  [34, 444, 2],
#  [34, 1447, 2],
#  [629],
#  [454, 22],
#  [1041, 22],
#  [1, 63, 51, 1498],
#  [1499],
#  [1499],
#  [998],
#  [2728],
#  [2729],
#  [523, 2],
#  [779, 2],
#  [149, 14, 780, 2],
#  [133, 14, 780, 2],
#  [524, 22],
#  [781, 22],
#  [1500, 123],
#  [1501, 42],
#  [445],
#  [629],
#  [340, 2],
#  [1022, 2],
#  [1015, 13, 446, 2],
#  [340, 516],
#  [1016],
#  [1502, 2],
#  [630, 2],
#  [1463],
#  [447, 13, 393],
#  [1451, 8, 131],
#  [1018],
#  [1503, 2],
#  [2730, 115, 446, 2731, 2],
#  [1023, 13, 393],
#  [448],
#  [450],
#  [2732],
#  [1504],
#  [2733, 2],
#  [335, 2],
#  [449, 2],
#  [341, 2],
#  [24, 631, 2734, 2735],
#  [2736],
#  [2737],
#  [1505, 2],
#  [106, 1032, 2],
#  [301, 1033, 2],
#  [782],
#  [2738, 2],
#  [2739, 2],
#  [1505, 2],
#  [2740, 2],
#  [106, 1032, 2],
#  [301, 1033, 2],
#  [782],
#  [92, 257, 2741, 216, 1506, 2742],
#  [445],
#  [92, 88, 2743, 2],
#  [448],
#  [450],
#  [335, 2],
#  [449, 2],
#  [341, 2],
#  [92, 46, 139, 2744],
#  [92, 46, 139, 2745],
#  [447, 13, 393],
#  [1023, 13, 393],
#  [448],
#  [450],
#  [335, 2],
#  [449, 2],
#  [341, 2],
#  [50, 1507, 2],
#  [24, 2746],
#  [1019],
#  [783],
#  [145, 1454],
#  [92, 2],
#  [1042, 2],
#  [1508, 2],
#  [775, 1509, 2],
#  [622, 2],
#  [621, 2],
#  [133, 2],
#  [149, 2],
#  [140, 2],
#  [523, 2],
#  [145, 2747],
#  [1019],
#  [783],
#  [92, 2],
#  [1042, 2],
#  [1508, 2],
#  [775, 1509, 2],
#  [622, 2],
#  [621, 2],
#  [133, 2],
#  [149, 2],
#  [140, 2],
#  [523, 2],
#  [145, 334, 2],
#  [525, 1510],
#  [638, 2748],
#  [2749, 1511],
#  [784, 2],
#  [398, 22],
#  [455, 22],
#  [2750],
#  [2751],
#  [2752, 17, 344, 2753, 2],
#  [1043, 83, 2],
#  [1512, 83, 2],
#  [1043, 53],
#  [1512, 53],
#  [9, 16, 456],
#  [9, 16, 177, 17, 2754],
#  [9, 69, 2755],
#  [9, 761],
#  [9, 7, 773],
#  [2756, 22],
#  [1044, 22],
#  [1044, 47, 2],
#  [2757, 28, 2758, 2],
#  [1513],
#  [1514],
#  [155, 73, 2759],
#  [763, 457, 2],
#  [763, 1515, 2],
#  [124, 2760],
#  [155, 1516, 7, 1517],
#  [155, 73, 1518, 2],
#  [155, 73, 628, 2],
#  [6, 48, 1519, 2],
#  [155, 73, 2761, 2],
#  [124, 2762, 2],
#  [124, 2763, 2],
#  [124, 1045, 2],
#  [2764],
#  [2765],
#  [2766, 2],
#  [2767, 2],
#  [2768, 2],
#  [2769, 2],
#  [1, 3, 22],
#  [10, 1471],
#  [1, 96, 3, 83, 639],
#  [1, 96, 3, 83, 1046],
#  [1, 59, 206],
#  [6, 117, 95, 59, 206],
#  [10, 785],
#  [10, 1047],
#  [10, 786],
#  [10, 35, 25, 1048],
#  [10, 35, 25, 2770],
#  [10, 35, 25, 2771],
#  [10, 786],
#  [10, 2772],
#  [10, 1049],
#  [10, 2773],
#  [86, 787],
#  [86, 2774],
#  [86, 35, 1520, 8, 17, 458],
#  [86, 788],
#  [1, 2775],
#  [10, 1050],
#  [1, 1521],
#  [1, 13, 1521],
#  [1, 15, 3, 1051],
#  [1, 15, 3, 1522],
#  [1, 59, 172],
#  [1, 640, 172],
#  [86, 2776],
#  [10, 399],
#  [1, 3, 1523],
#  [1, 3, 2777],
#  [86, 456],
#  [1, 2778],
#  [89, 107, 2779],
#  [1, 96, 2780],
#  [1, 1052],
#  [1, 789],
#  [1, 87, 230],
#  [2781],
#  [1, 3, 1524],
#  [400, 2782],
#  [1, 3, 1053],
#  [1, 3, 207],
#  [1, 3, 345],
#  [1, 3, 122],
#  [10, 240],
#  [1, 3, 790],
#  [1, 3, 791],
#  [1, 3, 792],
#  [1, 3, 1525],
#  [89, 55, 306],
#  [1, 3, 307],
#  [10, 17, 2783, 2784],
#  [10, 13, 2785, 1054],
#  [1, 3, 459],
#  [97, 70, 53],
#  [1, 87, 53],
#  [33, 624],
#  [1, 3, 793, 2],
#  [1, 3, 526],
#  [1, 3, 794],
#  [1, 3, 2786],
#  [1, 3, 2787],
#  [89, 2788],
#  [1, 3, 8, 17, 1004],
#  [1, 3, 641],
#  [1, 87, 53],
#  [1, 3, 154],
#  [1, 3, 94, 74],
#  [1, 3, 19, 241],
#  [1, 3, 308],
#  [1, 3, 1526],
#  [1, 3, 642],
#  [1, 3, 2789],
#  [1, 3, 2790],
#  [1, 3, 795],
#  [1, 87, 53],
#  [1, 15, 217, 53],
#  [1, 3, 279],
#  [1, 3, 19, 182],
#  [1, 3, 156],
#  [89, 3, 527],
#  [1, 3, 527],
#  [89, 3, 280],
#  [89, 3, 1527],
#  [1, 3, 401],
#  [1, 3, 643],
#  [1, 3, 1528],
#  [1, 3, 2791],
#  [1, 3, 796],
#  [1, 3, 1529],
#  [1, 3, 1530],
#  [1, 3, 242],
#  [1, 87, 53],
#  [1, 15, 217, 53],
#  [10, 188],
#  [1, 59, 626],
#  [33, 797],
#  [33, 35, 101],
#  [40, 798],
#  [33, 1055],
#  [6, 22],
#  [6, 281],
#  [6, 1056],
#  [6, 13, 644],
#  [6, 17, 645],
#  [6, 195],
#  [6, 231],
#  [6, 1531],
#  [6, 208],
#  [9, 7, 1057],
#  [189, 114],
#  [2792, 1532],
#  [2793, 36],
#  [2794, 22],
#  [2795, 22],
#  [2796, 22],
#  [153, 394, 2],
#  [203, 394, 2],
#  [153, 2],
#  [203, 42],
#  [153, 42],
#  [134, 2],
#  [1058, 2],
#  [1059, 2],
#  [646, 2],
#  [766, 2],
#  [145, 334, 2],
#  [646, 2],
#  [145, 334, 2],
#  [799, 2],
#  [111, 460],
#  [93, 460],
#  [34, 346, 2],
#  [93, 1060, 2],
#  [111, 1060, 2],
#  [93, 800, 2],
#  [165, 2797, 2],
#  [111, 196],
#  [93, 196],
#  [2798, 2],
#  [2799, 2],
#  [141, 347, 5],
#  [141, 51, 136, 5],
#  [141, 282, 1533, 5],
#  [2800, 2801],
#  [2802],
#  [2803],
#  [1534, 8, 17, 2804],
#  [2805],
#  [2806, 348, 2],
#  [2807, 2],
#  [2808, 2],
#  [461, 2809, 2],
#  [461, 2810, 2],
#  [2811],
#  [2812, 2],
#  [2813, 2],
#  [1535, 1536],
#  [618, 1536],
#  [2814],
#  [2815],
#  [2816],
#  [2817],
#  [2818],
#  [2819],
#  [2820, 22],
#  [2821, 22],
#  [402, 1061],
#  [40, 7, 2822],
#  [40, 7, 801],
#  [40, 7, 1004],
#  [40, 633],
#  [528, 2],
#  [647, 2],
#  [1062],
#  [1537],
#  [1062],
#  [528, 81],
#  [647, 81],
#  [258, 132, 1538],
#  [648, 132, 1538],
#  [258, 132, 403, 2],
#  [2823],
#  [2824],
#  [1438],
#  [85, 22],
#  [2825, 22],
#  [91, 22],
#  [2826],
#  [2827],
#  [2828],
#  [2829],
#  [1539, 14, 22],
#  [2830, 22],
#  [1013],
#  [1540],
#  [1541],
#  [301, 2831],
#  [2832],
#  [1481],
#  [1542],
#  [1543],
#  [2833, 2834],
#  [2835],
#  [1544, 2],
#  [6, 2836, 2],
#  [106, 17, 259, 1545, 2],
#  [6, 462],
#  [1546, 2],
#  [2837, 2],
#  [762, 2],
#  [30, 1063],
#  [39, 1063],
#  [30, 75, 188],
#  [39, 75, 188],
#  [4, 7, 529],
#  [4, 7, 232],
#  [4, 1064],
#  [4, 7, 253],
#  [4, 1065],
#  [4, 16, 388],
#  [4, 1066],
#  [4, 16, 146],
#  [4, 16, 1005],
#  [4, 2838],
#  [4, 7, 253],
#  [4, 7, 204],
#  [763, 309],
#  [2839],
#  [2840],
#  [2841],
#  [2842],
#  [530, 2843],
#  [649, 243],
#  [530, 243],
#  [1547, 209, 19, 74],
#  [1548, 209, 19, 74],
#  [2844, 2],
#  [2845, 2],
#  [1012],
#  [233, 349, 2],
#  [283, 349, 2],
#  [463, 123],
#  [2846, 123],
#  [2847, 123],
#  [2848, 349, 2],
#  [2849, 349, 2],
#  [2850, 22],
#  [2851, 22],
#  [2852, 2],
#  [2853, 2],
#  [2854, 2],
#  [2855, 2],
#  [12, 37, 234],
#  [12, 1549],
#  [12, 464, 53],
#  [1067, 348, 2856],
#  [106, 348, 202, 5],
#  [183, 1550, 69, 2857, 2],
#  [183, 1550, 69, 2858, 2],
#  [41, 1551, 5],
#  [41, 7, 802, 5],
#  [41, 7, 2859, 5],
#  [41, 7, 2860],
#  [41, 16, 235, 5],
#  [41, 16, 2861],
#  [41, 16, 2862],
#  [41, 2863],
#  [41, 650],
#  [2864, 2],
#  [2865, 2],
#  [24, 125, 146],
#  [23, 164, 146],
#  [1068, 146],
#  [1, 21, 19, 244],
#  [2866, 148],
#  [106, 21, 1552],
#  [106, 260, 1552],
#  [145, 465, 2867, 755, 2],
#  [118, 457, 5],
#  [118, 19, 2868, 5],
#  [2869],
#  [50, 764],
#  [34, 1014],
#  [34, 764],
#  [528, 2],
#  [647, 2],
#  [1062],
#  [50, 2870],
#  [102, 1553, 1554],
#  [106, 337, 2871],
#  [454, 14, 17, 261, 2],
#  [620, 2],
#  [176, 122],
#  [252],
#  [997],
#  [176, 122],
#  [252],
#  [262, 347, 5],
#  [262, 31, 19, 136, 5],
#  [262, 51, 136, 5],
#  [398, 22],
#  [455, 22],
#  [2872],
#  [2873],
#  [2874],
#  [997],
#  [252],
#  [1555, 2],
#  [404, 2],
#  [651, 2],
#  [173, 81],
#  [150, 131],
#  [150, 166, 2],
#  [173, 94, 31, 2],
#  [150, 94, 31, 2],
#  [173, 94, 117, 2],
#  [150, 94, 117, 2],
#  [173, 776, 2],
#  [150, 776, 2],
#  [620, 2],
#  [263, 302, 5],
#  [2875, 513, 5],
#  [27, 117, 95, 55, 302, 5],
#  [466, 130],
#  [461, 803, 1556],
#  [102, 803, 1556],
#  [26, 310, 11, 2],
#  [26, 531, 11, 2],
#  [26, 1069, 11, 2],
#  [26, 2876, 11, 2],
#  [26, 1070, 36],
#  [26, 1070, 11, 2],
#  [26, 2877, 36],
#  [26, 2878, 36],
#  [1557],
#  [1558],
#  [1, 1559],
#  [1560],
#  [1, 21, 310, 1561],
#  [1562],
#  [1563],
#  [1001, 5],
#  [1013],
#  [2879],
#  [762, 2],
#  ...]

# %%
encoder_input_data = pad_sequences(english_texts, maxlen = max_eng_word, padding = 'pre')
decoder_input_data = pad_sequences(french_texts, maxlen = max_fra_word, padding = 'pre')

# %%
decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[: , 1:]

# %%
decoder_target_data
# Out:
# array([[   0,    0,    0, ...,   92,    2,    0],
#        [   0,    0,    0, ...,    0,  991,    0],
#        [   0,    0,    0, ...,  334,    2,    0],
#        ...,
#        [   0,    0,    0, ..., 5804,  380,    0],
#        [   0,    0,    0, ..., 5805,  380,    0],
#        [   0,    0,    0, ...,  893,  456,    0]])

# %%
decoder_target_data.shape
# Out:
# (10000, 59)

# %%
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1
print(f"{eng_vocab_size} :: {fra_vocab_size}")
# Out:
# 2707 :: 5806

# %% [markdown]
# ### creating the encoder/decoders

# %%
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate
from tensorflow.keras.models import Model

# %%
latent_dim = 256

# %%
encoder_inputs = Input(shape = (max_eng_word, ))
encoder_emb = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_emb)

# %%
decoder_inputs = Input(shape = (max_fra_word, ))
decoder_emb_layers = Embedding(fra_vocab_size, latent_dim)
decoder_emb = decoder_emb_layers(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)

# %% [markdown]
# ### creating the base badhnau attention class

# %%
from tensorflow.keras.layers import Dense, Layer

# %%
class BahdanauAttention(Layer) : 
    def __init__(self, units) : 
        super(BahdanauAttention, self). __init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, query, values) : 
        query_with_time_axis = tensorflow.expand_dims(query, 1)
        score = self.V(tensorflow.nn.tanh(self.W1(values)) + self.W2(query_with_time_axis))
        attention_weights = tensorflow.nn.softmax(score, axis = 1)
        context_vector = attention_weights * score
        context_vector = tensorflow.reduce_sum(context_vector, axis = 1)

        return context_vector, attention_weights

# %%
attention = BahdanauAttention(latent_dim)
all_outputs = []
decoder_state_h, decoder_state_c = state_h, state_c
for t in range(max_fra_word) : 
    context_vector, _ = attention(decoder_state_h, decoder_state_c)
    X = tensorflow.expand_dims(decoder_emb[:, t], 1)
    X = Concatenate(axis = -1)([context_vector[:, None, :], X])
    output, decoder_state_h, decoder_state_c = decoder_lstm(X, initial_state = [decoder_state_h, decoder_state_c])
    output = Dense(fra_vocab_size, activation = 'softmax')(output)

    all_outputs.append(output)

decoder_outputs = tensorflow.concat(all_outputs, axis = 1)

# %%
model = Model()

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  embedding (Embedding)          (None, 14, 256)      692992      ['input_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 59)]         0           []
#
#  lstm (LSTM)                    [(None, 14, 256),    525312      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_1 (Embedding)        (None, 59, 256)      1486336     ['input_2[0][0]']
#
#  bahdanau_attention (BahdanauAt  ((None, 1),         131841      ['lstm[0][1]',
#  tention)                        (None, None, 1))                 'lstm[0][2]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[0][2]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[1][2]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[2][2]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[3][2]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[4][2]',
#                                                                   'lstm_1[5][1]',
#                                                                   'lstm_1[5][2]',
#                                                                   'lstm_1[6][1]',
#                                                                   'lstm_1[6][2]',
#                                                                   'lstm_1[7][1]',
#                                                                   'lstm_1[7][2]',
#                                                                   'lstm_1[8][1]',
#                                                                   'lstm_1[8][2]',
#                                                                   'lstm_1[9][1]',
#                                                                   'lstm_1[9][2]',
#                                                                   'lstm_1[10][1]',
#                                                                   'lstm_1[10][2]',
#                                                                   'lstm_1[11][1]',
#                                                                   'lstm_1[11][2]',
#                                                                   'lstm_1[12][1]',
#                                                                   'lstm_1[12][2]',
#                                                                   'lstm_1[13][1]',
#                                                                   'lstm_1[13][2]',
#                                                                   'lstm_1[14][1]',
#                                                                   'lstm_1[14][2]',
#                                                                   'lstm_1[15][1]',
#                                                                   'lstm_1[15][2]',
#                                                                   'lstm_1[16][1]',
#                                                                   'lstm_1[16][2]',
#                                                                   'lstm_1[17][1]',
#                                                                   'lstm_1[17][2]',
#                                                                   'lstm_1[18][1]',
#                                                                   'lstm_1[18][2]',
#                                                                   'lstm_1[19][1]',
#                                                                   'lstm_1[19][2]',
#                                                                   'lstm_1[20][1]',
#                                                                   'lstm_1[20][2]',
#                                                                   'lstm_1[21][1]',
#                                                                   'lstm_1[21][2]',
#                                                                   'lstm_1[22][1]',
#                                                                   'lstm_1[22][2]',
#                                                                   'lstm_1[23][1]',
#                                                                   'lstm_1[23][2]',
#                                                                   'lstm_1[24][1]',
#                                                                   'lstm_1[24][2]',
#                                                                   'lstm_1[25][1]',
#                                                                   'lstm_1[25][2]',
#                                                                   'lstm_1[26][1]',
#                                                                   'lstm_1[26][2]',
#                                                                   'lstm_1[27][1]',
#                                                                   'lstm_1[27][2]',
#                                                                   'lstm_1[28][1]',
#                                                                   'lstm_1[28][2]',
#                                                                   'lstm_1[29][1]',
#                                                                   'lstm_1[29][2]',
#                                                                   'lstm_1[30][1]',
#                                                                   'lstm_1[30][2]',
#                                                                   'lstm_1[31][1]',
#                                                                   'lstm_1[31][2]',
#                                                                   'lstm_1[32][1]',
#                                                                   'lstm_1[32][2]',
#                                                                   'lstm_1[33][1]',
#                                                                   'lstm_1[33][2]',
#                                                                   'lstm_1[34][1]',
#                                                                   'lstm_1[34][2]',
#                                                                   'lstm_1[35][1]',
#                                                                   'lstm_1[35][2]',
#                                                                   'lstm_1[36][1]',
#                                                                   'lstm_1[36][2]',
#                                                                   'lstm_1[37][1]',
#                                                                   'lstm_1[37][2]',
#                                                                   'lstm_1[38][1]',
#                                                                   'lstm_1[38][2]',
#                                                                   'lstm_1[39][1]',
#                                                                   'lstm_1[39][2]',
#                                                                   'lstm_1[40][1]',
#                                                                   'lstm_1[40][2]',
#                                                                   'lstm_1[41][1]',
#                                                                   'lstm_1[41][2]',
#                                                                   'lstm_1[42][1]',
#                                                                   'lstm_1[42][2]',
#                                                                   'lstm_1[43][1]',
#                                                                   'lstm_1[43][2]',
#                                                                   'lstm_1[44][1]',
#                                                                   'lstm_1[44][2]',
#                                                                   'lstm_1[45][1]',
#                                                                   'lstm_1[45][2]',
#                                                                   'lstm_1[46][1]',
#                                                                   'lstm_1[46][2]',
#                                                                   'lstm_1[47][1]',
#                                                                   'lstm_1[47][2]',
#                                                                   'lstm_1[48][1]',
#                                                                   'lstm_1[48][2]',
#                                                                   'lstm_1[49][1]',
#                                                                   'lstm_1[49][2]',
#                                                                   'lstm_1[50][1]',
#                                                                   'lstm_1[50][2]',
#                                                                   'lstm_1[51][1]',
#                                                                   'lstm_1[51][2]',
#                                                                   'lstm_1[52][1]',
#                                                                   'lstm_1[52][2]',
#                                                                   'lstm_1[53][1]',
#                                                                   'lstm_1[53][2]',
#                                                                   'lstm_1[54][1]',
#                                                                   'lstm_1[54][2]',
#                                                                   'lstm_1[55][1]',
#                                                                   'lstm_1[55][2]',
#                                                                   'lstm_1[56][1]',
#                                                                   'lstm_1[56][2]',
#                                                                   'lstm_1[57][1]',
#                                                                   'lstm_1[57][2]']
#
#  tf.__operators__.getitem (Slic  (None, 256)         0           ['embedding_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 1, 1)        0           ['bahdanau_attention[0][0]']
#  icingOpLambda)
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256)       0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  concatenate (Concatenate)      (None, 1, 257)       0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims[0][0]']
#
#  lstm_1 (LSTM)                  [(None, 1, 256),     526336      ['concatenate[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[0][2]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[1][2]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[2][2]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[3][2]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[4][2]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'lstm_1[5][1]',
#                                                                   'lstm_1[5][2]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'lstm_1[6][1]',
#                                                                   'lstm_1[6][2]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'lstm_1[7][1]',
#                                                                   'lstm_1[7][2]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'lstm_1[8][1]',
#                                                                   'lstm_1[8][2]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'lstm_1[9][1]',
#                                                                   'lstm_1[9][2]',
#                                                                   'concatenate_11[0][0]',
#                                                                   'lstm_1[10][1]',
#                                                                   'lstm_1[10][2]',
#                                                                   'concatenate_12[0][0]',
#                                                                   'lstm_1[11][1]',
#                                                                   'lstm_1[11][2]',
#                                                                   'concatenate_13[0][0]',
#                                                                   'lstm_1[12][1]',
#                                                                   'lstm_1[12][2]',
#                                                                   'concatenate_14[0][0]',
#                                                                   'lstm_1[13][1]',
#                                                                   'lstm_1[13][2]',
#                                                                   'concatenate_15[0][0]',
#                                                                   'lstm_1[14][1]',
#                                                                   'lstm_1[14][2]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'lstm_1[15][1]',
#                                                                   'lstm_1[15][2]',
#                                                                   'concatenate_17[0][0]',
#                                                                   'lstm_1[16][1]',
#                                                                   'lstm_1[16][2]',
#                                                                   'concatenate_18[0][0]',
#                                                                   'lstm_1[17][1]',
#                                                                   'lstm_1[17][2]',
#                                                                   'concatenate_19[0][0]',
#                                                                   'lstm_1[18][1]',
#                                                                   'lstm_1[18][2]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'lstm_1[19][1]',
#                                                                   'lstm_1[19][2]',
#                                                                   'concatenate_21[0][0]',
#                                                                   'lstm_1[20][1]',
#                                                                   'lstm_1[20][2]',
#                                                                   'concatenate_22[0][0]',
#                                                                   'lstm_1[21][1]',
#                                                                   'lstm_1[21][2]',
#                                                                   'concatenate_23[0][0]',
#                                                                   'lstm_1[22][1]',
#                                                                   'lstm_1[22][2]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'lstm_1[23][1]',
#                                                                   'lstm_1[23][2]',
#                                                                   'concatenate_25[0][0]',
#                                                                   'lstm_1[24][1]',
#                                                                   'lstm_1[24][2]',
#                                                                   'concatenate_26[0][0]',
#                                                                   'lstm_1[25][1]',
#                                                                   'lstm_1[25][2]',
#                                                                   'concatenate_27[0][0]',
#                                                                   'lstm_1[26][1]',
#                                                                   'lstm_1[26][2]',
#                                                                   'concatenate_28[0][0]',
#                                                                   'lstm_1[27][1]',
#                                                                   'lstm_1[27][2]',
#                                                                   'concatenate_29[0][0]',
#                                                                   'lstm_1[28][1]',
#                                                                   'lstm_1[28][2]',
#                                                                   'concatenate_30[0][0]',
#                                                                   'lstm_1[29][1]',
#                                                                   'lstm_1[29][2]',
#                                                                   'concatenate_31[0][0]',
#                                                                   'lstm_1[30][1]',
#                                                                   'lstm_1[30][2]',
#                                                                   'concatenate_32[0][0]',
#                                                                   'lstm_1[31][1]',
#                                                                   'lstm_1[31][2]',
#                                                                   'concatenate_33[0][0]',
#                                                                   'lstm_1[32][1]',
#                                                                   'lstm_1[32][2]',
#                                                                   'concatenate_34[0][0]',
#                                                                   'lstm_1[33][1]',
#                                                                   'lstm_1[33][2]',
#                                                                   'concatenate_35[0][0]',
#                                                                   'lstm_1[34][1]',
#                                                                   'lstm_1[34][2]',
#                                                                   'concatenate_36[0][0]',
#                                                                   'lstm_1[35][1]',
#                                                                   'lstm_1[35][2]',
#                                                                   'concatenate_37[0][0]',
#                                                                   'lstm_1[36][1]',
#                                                                   'lstm_1[36][2]',
#                                                                   'concatenate_38[0][0]',
#                                                                   'lstm_1[37][1]',
#                                                                   'lstm_1[37][2]',
#                                                                   'concatenate_39[0][0]',
#                                                                   'lstm_1[38][1]',
#                                                                   'lstm_1[38][2]',
#                                                                   'concatenate_40[0][0]',
#                                                                   'lstm_1[39][1]',
#                                                                   'lstm_1[39][2]',
#                                                                   'concatenate_41[0][0]',
#                                                                   'lstm_1[40][1]',
#                                                                   'lstm_1[40][2]',
#                                                                   'concatenate_42[0][0]',
#                                                                   'lstm_1[41][1]',
#                                                                   'lstm_1[41][2]',
#                                                                   'concatenate_43[0][0]',
#                                                                   'lstm_1[42][1]',
#                                                                   'lstm_1[42][2]',
#                                                                   'concatenate_44[0][0]',
#                                                                   'lstm_1[43][1]',
#                                                                   'lstm_1[43][2]',
#                                                                   'concatenate_45[0][0]',
#                                                                   'lstm_1[44][1]',
#                                                                   'lstm_1[44][2]',
#                                                                   'concatenate_46[0][0]',
#                                                                   'lstm_1[45][1]',
#                                                                   'lstm_1[45][2]',
#                                                                   'concatenate_47[0][0]',
#                                                                   'lstm_1[46][1]',
#                                                                   'lstm_1[46][2]',
#                                                                   'concatenate_48[0][0]',
#                                                                   'lstm_1[47][1]',
#                                                                   'lstm_1[47][2]',
#                                                                   'concatenate_49[0][0]',
#                                                                   'lstm_1[48][1]',
#                                                                   'lstm_1[48][2]',
#                                                                   'concatenate_50[0][0]',
#                                                                   'lstm_1[49][1]',
#                                                                   'lstm_1[49][2]',
#                                                                   'concatenate_51[0][0]',
#                                                                   'lstm_1[50][1]',
#                                                                   'lstm_1[50][2]',
#                                                                   'concatenate_52[0][0]',
#                                                                   'lstm_1[51][1]',
#                                                                   'lstm_1[51][2]',
#                                                                   'concatenate_53[0][0]',
#                                                                   'lstm_1[52][1]',
#                                                                   'lstm_1[52][2]',
#                                                                   'concatenate_54[0][0]',
#                                                                   'lstm_1[53][1]',
#                                                                   'lstm_1[53][2]',
#                                                                   'concatenate_55[0][0]',
#                                                                   'lstm_1[54][1]',
#                                                                   'lstm_1[54][2]',
#                                                                   'concatenate_56[0][0]',
#                                                                   'lstm_1[55][1]',
#                                                                   'lstm_1[55][2]',
#                                                                   'concatenate_57[0][0]',
#                                                                   'lstm_1[56][1]',
#                                                                   'lstm_1[56][2]',
#                                                                   'concatenate_58[0][0]',
#                                                                   'lstm_1[57][1]',
#                                                                   'lstm_1[57][2]']
#
#  tf.__operators__.getitem_2 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None, 1, 1)        0           ['bahdanau_attention[1][0]']
#  icingOpLambda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  concatenate_1 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_1[0][0]']
#
#  tf.__operators__.getitem_4 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  (None, 1, 1)        0           ['bahdanau_attention[2][0]']
#  icingOpLambda)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  concatenate_2 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_2[0][0]']
#
#  tf.__operators__.getitem_6 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, 1, 1)        0           ['bahdanau_attention[3][0]']
#  icingOpLambda)
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  concatenate_3 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_7[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_3[0][0]']
#
#  tf.__operators__.getitem_8 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_9 (Sl  (None, 1, 1)        0           ['bahdanau_attention[4][0]']
#  icingOpLambda)
#
#  tf.expand_dims_4 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  concatenate_4 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_9[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_4[0][0]']
#
#  tf.__operators__.getitem_10 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None, 1, 1)        0           ['bahdanau_attention[5][0]']
#  licingOpLambda)
#
#  tf.expand_dims_5 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  concatenate_5 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_11[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_5[0][0]']
#
#  tf.__operators__.getitem_12 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  (None, 1, 1)        0           ['bahdanau_attention[6][0]']
#  licingOpLambda)
#
#  tf.expand_dims_6 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  concatenate_6 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_13[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_6[0][0]']
#
#  tf.__operators__.getitem_14 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_15 (S  (None, 1, 1)        0           ['bahdanau_attention[7][0]']
#  licingOpLambda)
#
#  tf.expand_dims_7 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_14[0][
#                                                                  0]']
#
#  concatenate_7 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_15[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_7[0][0]']
#
#  tf.__operators__.getitem_16 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_17 (S  (None, 1, 1)        0           ['bahdanau_attention[8][0]']
#  licingOpLambda)
#
#  tf.expand_dims_8 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_16[0][
#                                                                  0]']
#
#  concatenate_8 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_17[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_8[0][0]']
#
#  tf.__operators__.getitem_18 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_19 (S  (None, 1, 1)        0           ['bahdanau_attention[9][0]']
#  licingOpLambda)
#
#  tf.expand_dims_9 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_18[0][
#                                                                  0]']
#
#  concatenate_9 (Concatenate)    (None, 1, 257)       0           ['tf.__operators__.getitem_19[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_9[0][0]']
#
#  tf.__operators__.getitem_20 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_21 (S  (None, 1, 1)        0           ['bahdanau_attention[10][0]']
#  licingOpLambda)
#
#  tf.expand_dims_10 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_20[0][
#                                                                  0]']
#
#  concatenate_10 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_21[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_10[0][0]']
#
#  tf.__operators__.getitem_22 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_23 (S  (None, 1, 1)        0           ['bahdanau_attention[11][0]']
#  licingOpLambda)
#
#  tf.expand_dims_11 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_22[0][
#                                                                  0]']
#
#  concatenate_11 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_23[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_11[0][0]']
#
#  tf.__operators__.getitem_24 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_25 (S  (None, 1, 1)        0           ['bahdanau_attention[12][0]']
#  licingOpLambda)
#
#  tf.expand_dims_12 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_24[0][
#                                                                  0]']
#
#  concatenate_12 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_25[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_12[0][0]']
#
#  tf.__operators__.getitem_26 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
# ...
#  dense_13 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[10][0]']
#
#  dense_14 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[11][0]']
#
#  dense_15 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[12][0]']
#
#  dense_16 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[13][0]']
#
#  dense_17 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[14][0]']
#
#  dense_18 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[15][0]']
#
#  dense_19 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[16][0]']
#
#  dense_20 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[17][0]']
#
#  dense_21 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[18][0]']
#
#  dense_22 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[19][0]']
#
#  dense_23 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[20][0]']
#
#  dense_24 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[21][0]']
#
#  dense_25 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[22][0]']
#
#  dense_26 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[23][0]']
#
#  dense_27 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[24][0]']
#
#  dense_28 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[25][0]']
#
#  dense_29 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[26][0]']
#
#  dense_30 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[27][0]']
#
#  dense_31 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[28][0]']
#
#  dense_32 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[29][0]']
#
#  dense_33 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[30][0]']
#
#  dense_34 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[31][0]']
#
#  dense_35 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[32][0]']
#
#  dense_36 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[33][0]']
#
#  dense_37 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[34][0]']
#
#  dense_38 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[35][0]']
#
#  dense_39 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[36][0]']
#
#  dense_40 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[37][0]']
#
#  dense_41 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[38][0]']
#
#  dense_42 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[39][0]']
#
#  dense_43 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[40][0]']
#
#  dense_44 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[41][0]']
#
#  dense_45 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[42][0]']
#
#  dense_46 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[43][0]']
#
#  dense_47 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[44][0]']
#
#  dense_48 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[45][0]']
#
#  dense_49 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[46][0]']
#
#  dense_50 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[47][0]']
#
#  dense_51 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[48][0]']
#
#  dense_52 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[49][0]']
#
#  dense_53 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[50][0]']
#
#  dense_54 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[51][0]']
#
#  dense_55 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[52][0]']
#
#  dense_56 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[53][0]']
#
#  dense_57 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[54][0]']
#
#  dense_58 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[55][0]']
#
#  dense_59 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[56][0]']
#
#  dense_60 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[57][0]']
#
#  dense_61 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[58][0]']
#
#  tf.concat (TFOpLambda)         (None, 59, 5806)     0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]',
#                                                                   'dense_5[0][0]',
#                                                                   'dense_6[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_8[0][0]',
#                                                                   'dense_9[0][0]',
#                                                                   'dense_10[0][0]',
#                                                                   'dense_11[0][0]',
#                                                                   'dense_12[0][0]',
#                                                                   'dense_13[0][0]',
#                                                                   'dense_14[0][0]',
#                                                                   'dense_15[0][0]',
#                                                                   'dense_16[0][0]',
#                                                                   'dense_17[0][0]',
#                                                                   'dense_18[0][0]',
#                                                                   'dense_19[0][0]',
#                                                                   'dense_20[0][0]',
#                                                                   'dense_21[0][0]',
#                                                                   'dense_22[0][0]',
#                                                                   'dense_23[0][0]',
#                                                                   'dense_24[0][0]',
#                                                                   'dense_25[0][0]',
#                                                                   'dense_26[0][0]',
#                                                                   'dense_27[0][0]',
#                                                                   'dense_28[0][0]',
#                                                                   'dense_29[0][0]',
#                                                                   'dense_30[0][0]',
#                                                                   'dense_31[0][0]',
#                                                                   'dense_32[0][0]',
#                                                                   'dense_33[0][0]',
#                                                                   'dense_34[0][0]',
#                                                                   'dense_35[0][0]',
#                                                                   'dense_36[0][0]',
#                                                                   'dense_37[0][0]',
#                                                                   'dense_38[0][0]',
#                                                                   'dense_39[0][0]',
#                                                                   'dense_40[0][0]',
#                                                                   'dense_41[0][0]',
#                                                                   'dense_42[0][0]',
#                                                                   'dense_43[0][0]',
#                                                                   'dense_44[0][0]',
#                                                                   'dense_45[0][0]',
#                                                                   'dense_46[0][0]',
#                                                                   'dense_47[0][0]',
#                                                                   'dense_48[0][0]',
#                                                                   'dense_49[0][0]',
#                                                                   'dense_50[0][0]',
#                                                                   'dense_51[0][0]',
#                                                                   'dense_52[0][0]',
#                                                                   'dense_53[0][0]',
#                                                                   'dense_54[0][0]',
#                                                                   'dense_55[0][0]',
#                                                                   'dense_56[0][0]',
#                                                                   'dense_57[0][0]',
#                                                                   'dense_58[0][0]',
#                                                                   'dense_59[0][0]',
#                                                                   'dense_60[0][0]',
#                                                                   'dense_61[0][0]']
#
# ==================================================================================================
# Total params: 91,399,195
# Trainable params: 91,399,195
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(
    [encoder_input_data, decoder_input_data], 
    np.expand_dims(decoder_target_data, -1),
    batch_size = 64, 
    epochs = 10,
    validation_split = 0.2
)
# Out:
# Epoch 1/10
# 125/125 [==============================] - 249s 1s/step - loss: 1.4171 - accuracy: 0.9171 - val_loss: 0.4283 - val_accuracy: 0.9426
# Epoch 2/10
# 125/125 [==============================] - 157s 1s/step - loss: 0.3506 - accuracy: 0.9495 - val_loss: 0.4428 - val_accuracy: 0.9426
# Epoch 3/10
# 125/125 [==============================] - 162s 1s/step - loss: 0.3493 - accuracy: 0.9495 - val_loss: 0.4486 - val_accuracy: 0.9420
# Epoch 4/10
# 125/125 [==============================] - 159s 1s/step - loss: 0.3492 - accuracy: 0.9495 - val_loss: 0.4532 - val_accuracy: 0.9420
# Epoch 5/10
# 125/125 [==============================] - 160s 1s/step - loss: 0.3493 - accuracy: 0.9495 - val_loss: 0.4570 - val_accuracy: 0.9426
# Epoch 6/10
# 125/125 [==============================] - 165s 1s/step - loss: 0.3491 - accuracy: 0.9494 - val_loss: 0.4602 - val_accuracy: 0.9420
# Epoch 7/10
# 125/125 [==============================] - 157s 1s/step - loss: 0.3490 - accuracy: 0.9496 - val_loss: 0.4648 - val_accuracy: 0.9420
# Epoch 8/10
# 125/125 [==============================] - 160s 1s/step - loss: 0.3490 - accuracy: 0.9494 - val_loss: 0.4671 - val_accuracy: 0.9420
# Epoch 9/10
# 125/125 [==============================] - 156s 1s/step - loss: 0.3478 - accuracy: 0.9496 - val_loss: 0.4581 - val_accuracy: 0.9420
# Epoch 10/10
# 125/125 [==============================] - 161s 1s/step - loss: 0.3319 - accuracy: 0.9506 - val_loss: 0.4224 - val_accuracy: 0.9438
