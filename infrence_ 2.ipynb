# %% [markdown]
# ## Infrence models

# %% [markdown]
# ### Data loading

# %%
import pandas as pd
import numpy as np

# %%
path = 'fra.txt'
eng_texts, fra_texts = [], []
num_samples = 10000

# %%
with open (path, 'r', encoding = 'UTF-8') as f :
    lines = f.read().split('\n')

    for line in lines[:num_samples] :
        eng_words, fra_words = line.split('\t')[:2]

        eng_words = eng_words.strip()
        fra_words = '<sos> ' + fra_words.strip() + ' <eos>'

        eng_texts.append(eng_words)
        fra_texts.append(fra_words)

# %%
eng_texts
# Out:
# ['Go.',
#  'Go.',
#  'Go.',
#  'Go.',
#  'Hi.',
#  'Hi.',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Who?',
#  'Wow!',
#  'Wow!',
#  'Wow!',
#  'Duck!',
#  'Duck!',
#  'Duck!',
#  'Fire!',
#  'Help!',
#  'Hide.',
#  'Hide.',
#  'Jump!',
#  'Jump.',
#  'Stop!',
#  'Stop!',
#  'Stop!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Begin.',
#  'Begin.',
#  'Go on.',
#  'Go on.',
#  'Go on.',
#  'Hello!',
#  'Hello!',
#  'Hello.',
#  'Hello.',
#  'Hello.',
#  'Hello.',
#  'I see.',
#  'I see.',
#  'I try.',
#  'I won!',
#  'I won!',
#  'I won.',
#  'Oh no!',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Shoot!',
#  'Shoot!',
#  'Smile.',
#  'Smile.',
#  'Smile.',
#  'Sorry?',
#  'Attack!',
#  'Attack!',
#  'Attack!',
#  'Attack!',
#  'Buy it.',
#  'Buy it.',
#  'Buy it.',
#  'Buy it.',
#  'Cheers!',
#  'Cheers!',
#  'Cheers!',
#  'Cheers!',
#  'Eat it.',
#  'Eat it.',
#  'Exhale.',
#  'Get up.',
#  'Get up.',
#  'Get up.',
#  'Go now.',
#  'Go now.',
#  'Go now.',
#  'Got it!',
#  'Got it!',
#  'Got it!',
#  'Got it?',
#  'Got it?',
#  'Got it?',
#  'Hop in.',
#  'Hop in.',
#  'Hug me.',
#  'Hug me.',
#  'I fell.',
#  'I fell.',
#  'I fled.',
#  'I hunt.',
#  'I knit.',
#  'I know.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I lied.',
#  'I lost.',
#  'I paid.',
#  'I paid.',
#  'I paid.',
#  'I pass.',
#  'I quit.',
#  'I quit.',
#  'I swim.',
#  "I'm 19.",
#  "I'm OK.",
#  "I'm OK.",
#  'Inhale.',
#  'Listen.',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'Really?',
#  'Really?',
#  'Really?',
#  'Really?',
#  'Really?',
#  'Thanks!',
#  'Thanks.',
#  'Thanks.',
#  'Thanks.',
#  'Try it.',
#  'Try it.',
#  'Try it.',
#  'We try.',
#  'We won.',
#  'We won.',
#  'We won.',
#  'We won.',
#  'We won.',
#  'Ask Tom.',
#  'Ask him.',
#  'Awesome!',
#  'Awesome!',
#  'Awesome!',
#  'Awesome.',
#  'Be calm.',
#  'Be calm.',
#  'Be calm.',
#  'Be cool.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be kind.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Beat it!',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Burn it.',
#  'Burn it.',
#  'Burn it.',
#  'Burn it.',
#  'Bury it.',
#  'Bury it.',
#  'Bury it.',
#  'Bury it.',
#  'Call me.',
#  'Call me.',
#  'Call us.',
#  'Call us.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on.',
#  'Come on.',
#  'Come on.',
#  'Drop it!',
#  'Drop it!',
#  'Drop it!',
#  'Drop it!',
#  'Fold it.',
#  'Fold it.',
#  'Fold it.',
#  'Fold it.',
#  'Get Tom.',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go back.',
#  'Go home.',
#  'Go home.',
#  'Go home.',
#  'Go home.',
#  'Go slow.',
#  'Go slow.',
#  'Goodbye!',
#  'Goodbye!',
#  'Goodbye!',
#  'Goodbye.',
#  'Hang on!',
#  'Hang on!',
#  'Hang on!',
#  'Hang on.',
#  'Hang on.',
#  'Hang on.',
#  'He left.',
#  'He runs.',
#  'Help me!',
#  'Help me.',
#  'Help me.',
#  'Help me.',
#  'Help me.',
#  'Help us.',
#  'Help us.',
#  'Hire me.',
#  'Hire me.',
#  'Hire me.',
#  'Hire me.',
#  'Hold it!',
#  'Hold it!',
#  'Hold it!',
#  'Hold it!',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hold up.',
#  'Hold up.',
#  'How sad!',
#  'Hug Tom.',
#  'I agree.',
#  'I cried.',
#  'I dozed.',
#  'I dozed.',
#  'I drive.',
#  'I drove.',
#  'I fired.',
#  'I froze.',
#  'I froze.',
#  'I smoke.',
#  'I snore.',
#  'I stink.',
#  'I stood.',
#  'I stood.',
#  'I swore.',
#  'I swore.',
#  'I tried.',
#  'I tried.',
#  'I tried.',
#  'I waved.',
#  "I'll go.",
#  "I'm Tom.",
#  "I'm fat.",
#  "I'm fat.",
#  "I'm fit.",
#  "I'm hit!",
#  "I'm hit!",
#  "I'm ill.",
#  "I'm mad.",
#  "I'm mad.",
#  "I'm mad.",
#  "I'm sad.",
#  "I'm sad.",
#  "I'm sad.",
#  "I'm shy.",
#  "I'm wet.",
#  "I'm wet.",
#  "It's me!",
#  'Join me.',
#  'Join us.',
#  'Join us.',
#  'Keep it.',
#  'Keep it.',
#  'Kick it.',
#  'Kick it.',
#  'Kill it.',
#  'Kill it.',
#  'Kill it.',
#  'Kill it.',
#  'Kiss me.',
#  'Kiss me.',
#  'Lie low.',
#  'Lie low.',
#  'Lock it.',
#  'Lock it.',
#  'Lock it.',
#  'Lock it.',
#  'Look up.',
#  'Look up.',
#  'Me, too.',
#  'Me, too.',
#  'Move on.',
#  'Move on.',
#  'Open it.',
#  'Open it.',
#  'Open it.',
#  'Open it.',
#  'Open up.',
#  'Open up.',
#  'Pair up.',
#  'Perfect!',
#  'Perfect!',
#  'Perfect!',
#  'Pull it.',
#  'Pull it.',
#  'Push it.',
#  'Push it.',
#  'Push it.',
#  'Push it.',
#  'Push it.',
#  'See you!',
#  'See you!',
#  'See you!',
#  'See you!',
#  'See you.',
#  'See you.',
#  'Show me.',
#  'Show me.',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Sign up.',
#  'Sign up.',
#  'Skip it.',
#  'Skip it.',
#  'So long.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Tell me.',
#  'Tell me.',
#  'Tom won.',
#  'Wake up!',
#  'Wake up!',
#  'Wake up!',
#  'Wake up.',
#  'Wake up.',
#  'Wash up.',
#  'Wash up.',
#  'We care.',
#  'We know.',
#  'We know.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'Welcome.',
#  'Welcome.',
#  'Who ran?',
#  'Who won?',
#  'Who won?',
#  'You run.',
#  'You win.',
#  'Aim high.',
#  'Aim high.',
#  'Am I fat?',
#  'Am I fat?',
#  'Ask them.',
#  'Ask them.',
#  'Back off!',
#  'Back off!',
#  'Back off!',
#  'Back off.',
#  'Back off.',
#  'Back off.',
#  'Back off.',
#  'Back off.',
#  'Be a man.',
#  'Be a man.',
#  'Be brave.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be quiet.',
#  'Be still.',
#  'Be still.',
#  'Be still.',
#  'Buzz off.',
#  'Call Tom.',
#  'Call Tom.',
#  'Can I go?',
#  'Cheer up!',
#  'Cheer up.',
#  'Cool off!',
#  'Cover me.',
#  'Cuff him.',
#  'Drive on.',
#  'Drive on.',
#  'Drive on.',
#  'Drive on.',
#  'Find Tom.',
#  'Find Tom.',
#  'Fix this.',
#  'Fix this.',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away.',
#  'Get away.',
#  'Get down!',
#  'Get down!',
#  'Get down!',
#  'Get down!',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get real!',
#  'Get real!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Good job!',
#  'Good job!',
#  'Good job!',
#  'Good job!',
#  'Grab Tom.',
#  'Grab Tom.',
#  'Grab him.',
#  'Grab him.',
#  'Grab him.',
#  'Have fun.',
#  'Have fun.',
#  'Have fun.',
#  'Have fun.',
#  'He spoke.',
#  'He spoke.',
#  'He spoke.',
#  'He tries.',
#  "He's wet.",
#  'Help Tom.',
#  'Help Tom.',
#  'Help Tom.',
#  'Hi, guys.',
#  'Hit back.',
#  'Hit back.',
#  'How cute!',
#  'How cute!',
#  'How cute!',
#  'How deep?',
#  'How nice!',
#  'How nice!',
#  'How nice!',
#  'How nice!',
#  'How nice!',
#  'How rude!',
#  'How rude!',
#  'How wise!',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'I am Tom.',
#  'I cursed.',
#  'I did OK.',
#  'I did OK.',
#  'I did it.',
#  'I did it.',
#  'I failed.',
#  'I forgot.',
#  'I get it.',
#  'I goofed.',
#  'I goofed.',
#  'I goofed.',
#  'I got it.',
#  'I got it.',
#  'I helped.',
#  'I jumped.',
#  'I looked.',
#  'I moaned.',
#  'I nodded.',
#  'I obeyed.',
#  'I phoned.',
#  'I phoned.',
#  'I refuse.',
#  'I refuse.',
#  'I rested.',
#  'I rested.',
#  'I saw it.',
#  'I saw it.',
#  'I sighed.',
#  'I smiled.',
#  'I stayed.',
#  'I stayed.',
#  'I talked.',
#  'I use it.',
#  'I use it.',
#  'I use it.',
#  "I'll pay.",
#  "I'll pay.",
#  "I'll try.",
#  "I'll try.",
#  "I'm back.",
#  "I'm back.",
#  "I'm bald.",
#  "I'm busy.",
#  "I'm busy.",
#  "I'm calm.",
#  "I'm cold.",
#  "I'm cool.",
#  "I'm cool.",
#  "I'm deaf.",
#  "I'm deaf.",
#  "I'm done.",
#  "I'm fair.",
#  "I'm fair.",
#  "I'm fair.",
#  "I'm fast.",
#  "I'm fine.",
#  "I'm fine.",
#  "I'm fine.",
#  "I'm free!",
#  "I'm free.",
#  "I'm free.",
#  "I'm full.",
#  "I'm full.",
#  "I'm game.",
#  "I'm game.",
#  "I'm glad.",
#  "I'm good.",
#  "I'm good.",
#  "I'm home.",
#  "I'm late.",
#  "I'm lazy.",
#  "I'm lazy.",
#  "I'm lazy.",
#  "I'm lazy.",
#  "I'm lost.",
#  "I'm lost.",
#  "I'm okay.",
#  "I'm okay.",
#  "I'm rich.",
#  "I'm safe.",
#  "I'm sick.",
#  "I'm sure.",
#  "I'm sure.",
#  "I'm sure.",
#  "I'm sure.",
#  "I'm tall.",
#  "I'm thin.",
#  "I'm tidy.",
#  "I'm tidy.",
#  "I'm ugly.",
#  "I'm ugly.",
#  "I'm ugly.",
#  "I'm weak.",
#  "I'm well.",
#  "I'm well.",
#  "I've won.",
#  "I've won.",
#  'It helps.',
#  'It hurts.',
#  'It works.',
#  'It works.',
#  "It's Tom.",
#  "It's fun.",
#  "It's fun.",
#  "It's his.",
#  "It's his.",
#  "It's hot.",
#  "It's new.",
#  "It's new.",
#  "It's odd.",
#  "It's red.",
#  "It's sad.",
#  'Keep out!',
#  'Keep out.',
#  'Kill Tom.',
#  'Kill Tom.',
#  'Kiss Tom.',
#  'Leave it.',
#  'Leave it.',
#  'Leave it.',
#  'Leave it.',
#  'Leave it.',
#  'Leave me.',
#  'Leave us.',
#  'Leave us.',
#  "Let's go!",
#  "Let's go!",
#  "Let's go!",
#  "Let's go.",
#  "Let's go.",
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Marry me.',
#  'Marry me.',
#  'May I go?',
#  'May I go?',
#  'May I go?',
#  'Nice try.',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Now stop!',
#  'Now stop!',
#  'Prove it.',
#  'Prove it.',
#  'Run away.',
#  'Run away.',
#  'Run away.',
#  'Run away.',
#  'Save Tom.',
#  'Save Tom.',
#  'Say what?',
#  'She came.',
#  'She died.',
#  'She left.',
#  'She runs.',
#  'Sit down!',
#  'Sit down!',
#  'Sit down!',
#  'Sit down.',
#  'Sit down.',
#  'Sit here.',
#  'Sit here.',
#  'Speak up!',
#  'Speak up!',
#  'Speak up!',
#  'Speed up.',
#  'Speed up.',
#  'Stand up.',
#  'Stop Tom.',
#  'Stop Tom.',
#  'Take Tom.',
#  'Taste it.',
#  'Taste it.',
#  'Taste it.',
#  'Taste it.',
#  'Tell Tom.',
#  'Tell Tom.',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'They won.',
#  'They won.',
#  'They won.',
#  'They won.',
#  'Tom came.',
#  'Tom died.',
#  'Tom knew.',
#  'Tom left.',
#  'Tom left.',
#  'Tom lied.',
#  'Tom lies.',
#  'Tom lost.',
#  'Tom paid.',
#  'Tom paid.',
#  'Tom went.',
#  "Tom's up.",
#  'Too late.',
#  'Touch it.',
#  'Touch it.',
#  'Touch it.',
#  'Touch it.',
#  'Trust me!',
#  'Trust me.',
#  'Trust me.',
#  'Trust me.',
#  'Trust me.',
#  'Try some.',
#  'Try some.',
#  'Try some.',
#  'Try this.',
#  'Try this.',
#  'Try this.',
#  'Use this.',
#  'Use this.',
#  'Use this.',
#  'Use this.',
#  'Warn Tom.',
#  'Warn Tom.',
#  'Watch me.',
#  'Watch me.',
#  'Watch us.',
#  'Watch us.',
#  'We agree.',
#  "We'll go.",
#  "We're OK.",
#  'What for?',
#  'What for?',
#  'What fun!',
#  'What fun!',
#  'Who am I?',
#  'Who came?',
#  'Who died?',
#  'Who fell?',
#  'Who lost?',
#  'Who paid?',
#  'Who paid?',
#  'Who quit?',
#  "Who's he?",
#  'Write me.',
#  'Write me.',
#  'You lost.',
#  'You lost.',
#  'You lost.',
#  'After you.',
#  'After you.',
#  'After you.',
#  'After you.',
#  'Aim. Fire!',
#  'Am I cute?',
#  'Am I late?',
#  'Answer me.',
#  'Be honest.',
#  'Be honest.',
#  'Be honest.',
#  'Be seated.',
#  'Be seated.',
#  'Be seated.',
#  'Be strong.',
#  'Birds fly.',
#  'Bless you.',
#  'Call home!',
#  'Calm down!',
#  'Calm down!',
#  'Calm down!',
#  'Calm down.',
#  'Calm down.',
#  'Calm down.',
#  'Can we go?',
#  'Can we go?',
#  'Can we go?',
#  'Catch Tom.',
#  'Catch Tom.',
#  'Catch him.',
#  'Catch him.',
#  'Catch him.',
#  'Chill out.',
#  'Chill out.',
#  'Choose me.',
#  'Come back.',
#  'Come back.',
#  'Come here.',
#  'Come here.',
#  'Come over.',
#  'Come over.',
#  'Come over.',
#  'Come over.',
#  'Come over.',
#  'Come soon.',
#  'Come soon.',
#  'Cool down.',
#  'Did I win?',
#  'Did I win?',
#  'Did I win?',
#  'Do it now.',
#  'Dogs bark.',
#  'Dogs bark.',
#  "Don't ask.",
#  "Don't cry.",
#  "Don't die.",
#  "Don't die.",
#  "Don't lie.",
#  "Don't lie.",
#  "Don't run.",
#  "Don't run.",
#  'Excuse me.',
#  'Excuse me.',
#  'Excuse me.',
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Fantastic!',
#  'Fantastic!',
#  'Fantastic!',
#  ...]

# %%
fra_texts
# Out:
# ['<sos> Va ! <eos>',
#  '<sos> Marche. <eos>',
#  '<sos> En route ! <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Salut ! <eos>',
#  '<sos> Salut. <eos>',
#  '<sos> Cours\u202f! <eos>',
#  '<sos> Courez\u202f! <eos>',
#  '<sos> Prenez vos jambes à vos cous ! <eos>',
#  '<sos> File ! <eos>',
#  '<sos> Filez ! <eos>',
#  '<sos> Cours ! <eos>',
#  '<sos> Fuyez ! <eos>',
#  '<sos> Fuyons ! <eos>',
#  '<sos> Cours\u202f! <eos>',
#  '<sos> Courez\u202f! <eos>',
#  '<sos> Prenez vos jambes à vos cous ! <eos>',
#  '<sos> File ! <eos>',
#  '<sos> Filez ! <eos>',
#  '<sos> Cours ! <eos>',
#  '<sos> Fuyez ! <eos>',
#  '<sos> Fuyons ! <eos>',
#  '<sos> Qui ? <eos>',
#  '<sos> Ça alors\u202f! <eos>',
#  '<sos> Waouh\xa0! <eos>',
#  '<sos> Wah\xa0! <eos>',
#  '<sos> À terre\xa0! <eos>',
#  '<sos> Baisse-toi\xa0! <eos>',
#  '<sos> Baissez-vous\xa0! <eos>',
#  '<sos> Au feu ! <eos>',
#  "<sos> À l'aide ! <eos>",
#  '<sos> Cache-toi. <eos>',
#  '<sos> Cachez-vous. <eos>',
#  '<sos> Saute. <eos>',
#  '<sos> Saute. <eos>',
#  '<sos> Ça suffit\u202f! <eos>',
#  '<sos> Stop\u202f! <eos>',
#  '<sos> Arrête-toi ! <eos>',
#  '<sos> Attends ! <eos>',
#  '<sos> Attendez ! <eos>',
#  '<sos> Attendez. <eos>',
#  '<sos> Attends ! <eos>',
#  '<sos> Attendez ! <eos>',
#  '<sos> Attends. <eos>',
#  '<sos> Attendez. <eos>',
#  '<sos> Commencez. <eos>',
#  '<sos> Commence. <eos>',
#  '<sos> Poursuis. <eos>',
#  '<sos> Continuez. <eos>',
#  '<sos> Poursuivez. <eos>',
#  '<sos> Bonjour ! <eos>',
#  '<sos> Salut ! <eos>',
#  '<sos> Bonjour ! <eos>',
#  '<sos> Salut ! <eos>',
#  '<sos> Bonjour. <eos>',
#  '<sos> Salut. <eos>',
#  '<sos> Je comprends. <eos>',
#  '<sos> Aha. <eos>',
#  "<sos> J'essaye. <eos>",
#  "<sos> J'ai gagné ! <eos>",
#  "<sos> Je l'ai emporté ! <eos>",
#  '<sos> J’ai gagné. <eos>',
#  '<sos> Oh non ! <eos>',
#  '<sos> Calme-toi. <eos>',
#  '<sos> Détends-toi\u202f! <eos>',
#  '<sos> Détendez-vous\u202f! <eos>',
#  '<sos> Relaxe, Max\u202f! <eos>',
#  '<sos> Cool, Raoul\u202f! <eos>',
#  '<sos> Du calme\u202f! <eos>',
#  '<sos> Relaxe ! <eos>',
#  '<sos> Calmez-vous ! <eos>',
#  '<sos> Détends-toi. <eos>',
#  '<sos> Détends-toi ! <eos>',
#  '<sos> Du calme. <eos>',
#  '<sos> Tranquille. <eos>',
#  '<sos> Tire ! <eos>',
#  '<sos> Tirez ! <eos>',
#  '<sos> Souriez\u202f! <eos>',
#  '<sos> Souris pour la caméra. <eos>',
#  '<sos> Souriez\u2009! <eos>',
#  '<sos> Pardon ? <eos>',
#  '<sos> Attaque ! <eos>',
#  '<sos> Attaquez ! <eos>',
#  "<sos> À l'attaque ! <eos>",
#  "<sos> À l'attaque\xa0! <eos>",
#  '<sos> Achetez-la ! <eos>',
#  '<sos> Achète-le ! <eos>',
#  '<sos> Achetez-le ! <eos>',
#  '<sos> Achète-la ! <eos>',
#  '<sos> Santé ! <eos>',
#  '<sos> À votre santé ! <eos>',
#  '<sos> Merci ! <eos>',
#  '<sos> Tchin-tchin ! <eos>',
#  '<sos> Mangez-le. <eos>',
#  '<sos> Mange-le. <eos>',
#  '<sos> Expire. <eos>',
#  '<sos> Lève-toi. <eos>',
#  '<sos> Lève-toi ! <eos>',
#  '<sos> Debout. <eos>',
#  '<sos> Va, maintenant. <eos>',
#  '<sos> Allez-y maintenant. <eos>',
#  '<sos> Vas-y maintenant. <eos>',
#  "<sos> J'ai pigé ! <eos>",
#  '<sos> Compris ! <eos>',
#  '<sos> Aha ! <eos>',
#  '<sos> Pigé\u202f? <eos>',
#  '<sos> Compris\u202f? <eos>',
#  "<sos> T'as capté\u202f? <eos>",
#  '<sos> Monte. <eos>',
#  '<sos> Montez. <eos>',
#  '<sos> Serre-moi dans tes bras ! <eos>',
#  '<sos> Serrez-moi dans vos bras ! <eos>',
#  '<sos> Je suis tombée. <eos>',
#  '<sos> Je suis tombé. <eos>',
#  "<sos> J'ai fui. <eos>",
#  '<sos> Je chasse. <eos>',
#  '<sos> Je tricote. <eos>',
#  '<sos> Je sais. <eos>',
#  '<sos> Je suis parti. <eos>',
#  '<sos> Je suis partie. <eos>',
#  '<sos> Je partis. <eos>',
#  '<sos> Je sortis. <eos>',
#  "<sos> J'ai menti. <eos>",
#  "<sos> J'ai perdu. <eos>",
#  '<sos> Je payais. <eos>',
#  '<sos> Je payai. <eos>',
#  '<sos> J’ai payé. <eos>',
#  '<sos> Je passe. <eos>',
#  "<sos> J'arrête. <eos>",
#  "<sos> J'ai arrêté. <eos>",
#  '<sos> Je nage. <eos>',
#  "<sos> J'ai 19 ans. <eos>",
#  '<sos> Je vais bien. <eos>',
#  '<sos> Ça va. <eos>',
#  '<sos> Inspire. <eos>',
#  '<sos> Écoutez ! <eos>',
#  "<sos> C'est pas possible\u202f! <eos>",
#  '<sos> Impossible\xa0! <eos>',
#  '<sos> Hors de question\u202f! <eos>',
#  '<sos> En aucun cas. <eos>',
#  '<sos> Sans façons\u202f! <eos>',
#  '<sos> Mon œil\u202f! <eos>',
#  "<sos> C'est hors de question ! <eos>",
#  "<sos> Il n'en est pas question ! <eos>",
#  "<sos> C'est exclu ! <eos>",
#  '<sos> En aucune manière ! <eos>',
#  '<sos> Hors de question ! <eos>',
#  '<sos> Sans blague ! <eos>',
#  '<sos> Vraiment\u202f? <eos>',
#  '<sos> Vrai ? <eos>',
#  '<sos> Ah bon ? <eos>',
#  '<sos> Ah vraiment ? <eos>',
#  '<sos> Vraiment ? <eos>',
#  '<sos> Merci ! <eos>',
#  '<sos> Je te remercie. <eos>',
#  '<sos> Merci ! <eos>',
#  '<sos> Merci. <eos>',
#  '<sos> Essaie. <eos>',
#  '<sos> Essayez. <eos>',
#  '<sos> Essaye. <eos>',
#  '<sos> On essaye. <eos>',
#  '<sos> Nous avons gagné. <eos>',
#  '<sos> Nous gagnâmes. <eos>',
#  "<sos> Nous l'avons emporté. <eos>",
#  "<sos> Nous l'emportâmes. <eos>",
#  '<sos> On a gagné. <eos>',
#  '<sos> Demande à Tom. <eos>',
#  '<sos> Demande-lui. <eos>',
#  '<sos> Fantastique\u202f! <eos>',
#  '<sos> Sensass ! <eos>',
#  '<sos> Trop cool ! <eos>',
#  '<sos> Génial. <eos>',
#  '<sos> Sois calme ! <eos>',
#  '<sos> Soyez calme ! <eos>',
#  '<sos> Soyez calmes ! <eos>',
#  '<sos> Sois détendu ! <eos>',
#  '<sos> Sois juste ! <eos>',
#  '<sos> Soyez juste ! <eos>',
#  '<sos> Soyez justes ! <eos>',
#  '<sos> Sois équitable ! <eos>',
#  '<sos> Soyez équitable ! <eos>',
#  '<sos> Soyez équitables ! <eos>',
#  '<sos> Sois honnête. <eos>',
#  '<sos> Sois sincère. <eos>',
#  '<sos> Soyez honnêtes. <eos>',
#  '<sos> Sois gentil. <eos>',
#  '<sos> Sois gentil ! <eos>',
#  '<sos> Sois gentille ! <eos>',
#  '<sos> Soyez gentil ! <eos>',
#  '<sos> Soyez gentille ! <eos>',
#  '<sos> Soyez gentils ! <eos>',
#  '<sos> Soyez gentilles ! <eos>',
#  '<sos> Cassez-vous\xa0! <eos>',
#  '<sos> Va te faire foutre ! <eos>',
#  '<sos> Dégage\u202f! <eos>',
#  '<sos> Casse-toi. <eos>',
#  '<sos> Pars ! <eos>',
#  '<sos> Foutez le camp ! <eos>',
#  '<sos> Fous le camp ! <eos>',
#  "<sos> Pars d'ici. <eos>",
#  '<sos> Va-t’en\xa0! <eos>',
#  '<sos> Disparais ! <eos>',
#  '<sos> Fiche le camp. <eos>',
#  '<sos> Tire-toi de là. <eos>',
#  '<sos> Casse-toi de là. <eos>',
#  '<sos> Oust ! <eos>',
#  '<sos> Dégage. <eos>',
#  "<sos> Fiche le camp d'ici. <eos>",
#  '<sos> Déguerpissez. <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Brûlez-le. <eos>',
#  '<sos> Brûlez-la. <eos>',
#  '<sos> Brûle-la. <eos>',
#  '<sos> Brûle-le. <eos>',
#  '<sos> Enterrez-le. <eos>',
#  '<sos> Enterre-le. <eos>',
#  '<sos> Enterrez-la. <eos>',
#  '<sos> Enterre-la. <eos>',
#  '<sos> Appelle-moi ! <eos>',
#  '<sos> Appelez-moi\xa0! <eos>',
#  '<sos> Appelle-nous ! <eos>',
#  '<sos> Appelez-nous ! <eos>',
#  '<sos> Entrez\u202f! <eos>',
#  '<sos> Entre. <eos>',
#  '<sos> Entre ! <eos>',
#  '<sos> Entrez ! <eos>',
#  '<sos> Allez\u202f! <eos>',
#  '<sos> En avant\u202f! <eos>',
#  '<sos> Allons ! <eos>',
#  "<sos> C'est pas vrai, dis ! <eos>",
#  '<sos> Viens\xa0! <eos>',
#  '<sos> Venez\u202f! <eos>',
#  '<sos> Secouez-vous ! <eos>',
#  '<sos> Secoue-toi ! <eos>',
#  '<sos> Allez, on y va\xa0! <eos>',
#  '<sos> Allez ! <eos>',
#  '<sos> Viens\xa0! <eos>',
#  '<sos> Venez\u202f! <eos>',
#  '<sos> Laisse tomber ! <eos>',
#  '<sos> Laissez tomber ! <eos>',
#  '<sos> Laisse-le tomber ! <eos>',
#  '<sos> Laissez-le tomber ! <eos>',
#  '<sos> Pliez-le. <eos>',
#  '<sos> Plie-le. <eos>',
#  '<sos> Pliez-la. <eos>',
#  '<sos> Plie-la. <eos>',
#  '<sos> Va chercher Tom. <eos>',
#  '<sos> Sors. <eos>',
#  '<sos> Sortez\u202f! <eos>',
#  '<sos> Dégage\u202f! <eos>',
#  '<sos> Disparais\u202f! <eos>',
#  '<sos> Casse-toi. <eos>',
#  '<sos> Dégagez ! <eos>',
#  '<sos> Sors ! <eos>',
#  '<sos> Sortez ! <eos>',
#  '<sos> Dégage ! <eos>',
#  '<sos> Disparais ! <eos>',
#  '<sos> Du balai ! <eos>',
#  '<sos> Fiche le camp. <eos>',
#  '<sos> Oust ! <eos>',
#  "<sos> Vers l'extérieur ! <eos>",
#  '<sos> Fichez le camp ! <eos>',
#  '<sos> Sortez. <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Sors. <eos>',
#  '<sos> Sortez\u202f! <eos>',
#  '<sos> Dégage\u202f! <eos>',
#  '<sos> Disparais\u202f! <eos>',
#  '<sos> Casse-toi. <eos>',
#  '<sos> Dégagez ! <eos>',
#  '<sos> Sors ! <eos>',
#  '<sos> Sortez ! <eos>',
#  '<sos> Disparais ! <eos>',
#  '<sos> Fiche le camp. <eos>',
#  '<sos> Oust ! <eos>',
#  '<sos> Sortez. <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Dégage\u202f! <eos>',
#  '<sos> Pars ! <eos>',
#  '<sos> Allez-vous-en\xa0! <eos>',
#  '<sos> Déguerpissez. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Va te faire foutre ! <eos>',
#  '<sos> Pars ! <eos>',
#  '<sos> Dégage ! <eos>',
#  '<sos> Fous le camp ! <eos>',
#  "<sos> Pars d'ici. <eos>",
#  '<sos> Va-t’en\xa0! <eos>',
#  '<sos> Disparais ! <eos>',
#  '<sos> Déguerpissez. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Allez-vous-en. <eos>',
#  '<sos> Recule. <eos>',
#  '<sos> Rentrez à la maison. <eos>',
#  '<sos> Rentre à la maison. <eos>',
#  '<sos> Rentre chez toi. <eos>',
#  '<sos> Rentrez chez vous. <eos>',
#  '<sos> Va doucement ! <eos>',
#  '<sos> Allez doucement ! <eos>',
#  '<sos> Adieu ! <eos>',
#  '<sos> À la revoyure. <eos>',
#  '<sos> Ciao. <eos>',
#  '<sos> Ciao. <eos>',
#  '<sos> Attends un peu ! <eos>',
#  '<sos> Attendez un peu ! <eos>',
#  '<sos> Attendez. <eos>',
#  '<sos> Tiens bon ! <eos>',
#  '<sos> Tenez bon ! <eos>',
#  '<sos> Attendez. <eos>',
#  '<sos> Il est parti. <eos>',
#  '<sos> Il court. <eos>',
#  '<sos> Aide-moi ! <eos>',
#  "<sos> À l'aide ! <eos>",
#  '<sos> Aide-moi. <eos>',
#  '<sos> Aidez-moi. <eos>',
#  '<sos> Aide-moi ! <eos>',
#  '<sos> Aidez-nous ! <eos>',
#  '<sos> Aide-nous ! <eos>',
#  '<sos> Engagez-moi. <eos>',
#  '<sos> Engage-moi. <eos>',
#  '<sos> Embauchez-moi. <eos>',
#  '<sos> Embauche-moi. <eos>',
#  '<sos> Ne bouge plus ! <eos>',
#  '<sos> Ne bougez plus ! <eos>',
#  '<sos> Restez où vous êtes ! <eos>',
#  '<sos> Attendez. <eos>',
#  '<sos> Ne quittez pas. <eos>',
#  '<sos> Attends. <eos>',
#  '<sos> Ne quitte pas ! <eos>',
#  '<sos> Accroche-toi ! <eos>',
#  '<sos> Tiens-bon ! <eos>',
#  '<sos> Tiens bon. <eos>',
#  '<sos> Tenez bon. <eos>',
#  "<sos> Comme c'est triste. <eos>",
#  '<sos> Fais un câlin à Tom. <eos>',
#  '<sos> Je suis du même avis. <eos>',
#  "<sos> J'ai pleuré. <eos>",
#  '<sos> Je me suis assoupi. <eos>',
#  '<sos> Je me suis assoupie. <eos>',
#  '<sos> Je conduis. <eos>',
#  '<sos> Je conduisis. <eos>',
#  "<sos> J'ai tiré. <eos>",
#  '<sos> Je me suis figé. <eos>',
#  '<sos> Je me suis figée. <eos>',
#  '<sos> Je fume. <eos>',
#  '<sos> Je ronfle. <eos>',
#  '<sos> Je pue. <eos>',
#  '<sos> Je me suis tenu debout. <eos>',
#  '<sos> Je me suis tenue debout. <eos>',
#  '<sos> J’ai promis. <eos>',
#  '<sos> J’ai juré. <eos>',
#  "<sos> J'essayai. <eos>",
#  "<sos> J'ai essayé. <eos>",
#  "<sos> J'ai tenté. <eos>",
#  '<sos> J’ai fait signe. <eos>',
#  "<sos> J'irai. <eos>",
#  '<sos> Je suis Tom. <eos>',
#  '<sos> Je suis gras. <eos>',
#  '<sos> Je suis gros. <eos>',
#  '<sos> Je suis en forme. <eos>',
#  '<sos> Je suis touché ! <eos>',
#  '<sos> Je suis touchée ! <eos>',
#  '<sos> Je suis malade. <eos>',
#  '<sos> Je suis fou. <eos>',
#  '<sos> Je suis folle. <eos>',
#  '<sos> Je suis en colère. <eos>',
#  '<sos> Je suis triste. <eos>',
#  "<sos> J'ai un coup de cafard. <eos>",
#  '<sos> Je suis malheureux. <eos>',
#  '<sos> Je suis timide. <eos>',
#  '<sos> Je suis mouillé. <eos>',
#  '<sos> Je suis mouillée. <eos>',
#  "<sos> C'est bibi\u202f! <eos>",
#  '<sos> Rejoignez-moi. <eos>',
#  '<sos> Joignez-vous. <eos>',
#  '<sos> Joignez-vous à nous. <eos>',
#  '<sos> Garde-le ! <eos>',
#  '<sos> Gardez-le ! <eos>',
#  '<sos> Donne-lui un coup de pied. <eos>',
#  '<sos> Donnez-lui un coup de pied. <eos>',
#  '<sos> Tuez-le. <eos>',
#  '<sos> Tue-le. <eos>',
#  '<sos> Tue-la. <eos>',
#  '<sos> Tuez-la. <eos>',
#  '<sos> Embrasse-moi. <eos>',
#  '<sos> Embrassez-moi. <eos>',
#  '<sos> À terre ! <eos>',
#  '<sos> Au sol ! <eos>',
#  '<sos> Verrouillez-le. <eos>',
#  '<sos> Verrouille-le. <eos>',
#  '<sos> Verrouillez-la. <eos>',
#  '<sos> Verrouille-la. <eos>',
#  '<sos> Levez les yeux. <eos>',
#  '<sos> Lève les yeux. <eos>',
#  '<sos> Moi aussi. <eos>',
#  '<sos> À moi aussi. <eos>',
#  '<sos> Passez à autre chose. <eos>',
#  '<sos> Passe à autre chose. <eos>',
#  '<sos> Ouvrez-le. <eos>',
#  '<sos> Ouvre-le. <eos>',
#  '<sos> Ouvre-la. <eos>',
#  '<sos> Ouvrez-la. <eos>',
#  '<sos> Ouvre-moi\u202f! <eos>',
#  '<sos> Ouvre. <eos>',
#  '<sos> Faites équipe. <eos>',
#  '<sos> Parfait\u202f! <eos>',
#  '<sos> Nickel\u202f! <eos>',
#  '<sos> Parfait ! <eos>',
#  '<sos> Tirez dessus. <eos>',
#  '<sos> Tire dessus. <eos>',
#  '<sos> Appuie dessus. <eos>',
#  '<sos> Poussez-le. <eos>',
#  '<sos> Pousse-le. <eos>',
#  '<sos> Poussez-la. <eos>',
#  '<sos> Pousse-la. <eos>',
#  '<sos> À plus tard\xa0! <eos>',
#  '<sos> À bientôt ! <eos>',
#  '<sos> À la prochaine ! <eos>',
#  '<sos> Ciao. <eos>',
#  '<sos> À plus. <eos>',
#  '<sos> Ciao. <eos>',
#  '<sos> Montre-moi ! <eos>',
#  '<sos> Montrez-moi ! <eos>',
#  '<sos> Taisez-vous\u202f! <eos>',
#  '<sos> Ferme-la\u202f! <eos>',
#  '<sos> Tais-toi ! <eos>',
#  '<sos> Ferme-la ! <eos>',
#  '<sos> La ferme ! <eos>',
#  '<sos> Bouclez-la ! <eos>',
#  '<sos> Fermez-la\xa0! <eos>',
#  '<sos> Ferme-la\xa0! <eos>',
#  '<sos> Inscrivez-vous. <eos>',
#  '<sos> Inscris-toi. <eos>',
#  '<sos> Laisse tomber. <eos>',
#  '<sos> Pas grave. <eos>',
#  '<sos> À plus tard\xa0! <eos>',
#  '<sos> Prends-le\u202f! <eos>',
#  '<sos> Prenez-le\u202f! <eos>',
#  '<sos> Prends-le ! <eos>',
#  '<sos> Prenez-le ! <eos>',
#  '<sos> Prenez-le. <eos>',
#  '<sos> Prends-le. <eos>',
#  '<sos> Dis-moi ! <eos>',
#  '<sos> Dites-moi ! <eos>',
#  '<sos> Tom a gagné. <eos>',
#  '<sos> Réveille-toi\u202f! <eos>',
#  '<sos> Réveille-toi ! <eos>',
#  '<sos> Réveillez-vous ! <eos>',
#  '<sos> Réveille-toi ! <eos>',
#  '<sos> Réveillez-vous ! <eos>',
#  '<sos> Lave-toi ! <eos>',
#  '<sos> Lavez-vous ! <eos>',
#  '<sos> Nous nous en soucions. <eos>',
#  '<sos> Nous savons. <eos>',
#  '<sos> On sait. <eos>',
#  '<sos> Nous perdîmes. <eos>',
#  '<sos> Nous avons perdu. <eos>',
#  '<sos> Nous fûmes battus. <eos>',
#  '<sos> Nous fûmes battues. <eos>',
#  '<sos> Nous fûmes défaits. <eos>',
#  '<sos> Nous fûmes défaites. <eos>',
#  '<sos> Nous avons été défaits. <eos>',
#  '<sos> Nous avons été défaites. <eos>',
#  '<sos> Nous avons été battus. <eos>',
#  '<sos> Nous avons été battues. <eos>',
#  '<sos> Bienvenue\u202f! <eos>',
#  '<sos> Soyez le bienvenu ! <eos>',
#  '<sos> Qui courait\xa0? <eos>',
#  '<sos> Qui a gagné ? <eos>',
#  "<sos> Qui l'a emporté ? <eos>",
#  '<sos> Tu cours. <eos>',
#  '<sos> Vous avez gagné. <eos>',
#  '<sos> Visez haut. <eos>',
#  '<sos> Vise haut. <eos>',
#  '<sos> Suis-je gros ? <eos>',
#  '<sos> Suis-je grosse ? <eos>',
#  '<sos> Demande-leur. <eos>',
#  '<sos> Demandez-leur. <eos>',
#  '<sos> Recule\u2009! <eos>',
#  '<sos> Reculez. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Recule\u2009! <eos>',
#  '<sos> Reculez. <eos>',
#  '<sos> Retire-toi\u2009! <eos>',
#  '<sos> Retirez-vous. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Sois un homme ! <eos>',
#  '<sos> Soyez un homme ! <eos>',
#  '<sos> Soyez courageux ! <eos>',
#  '<sos> Soyez bref. <eos>',
#  '<sos> Sois bref. <eos>',
#  '<sos> Sois brève. <eos>',
#  '<sos> Soyez brève. <eos>',
#  '<sos> Soyez brefs. <eos>',
#  '<sos> Soyez brèves. <eos>',
#  '<sos> Tiens-toi sage. <eos>',
#  '<sos> Sois calme ! <eos>',
#  '<sos> Soyez calme ! <eos>',
#  '<sos> Soyez calmes ! <eos>',
#  '<sos> Casse-toi. <eos>',
#  '<sos> Appelle Tom. <eos>',
#  '<sos> Appelez Tom. <eos>',
#  '<sos> Je peux y aller\xa0? <eos>',
#  '<sos> Courage\u202f! <eos>',
#  '<sos> Courage\u202f! <eos>',
#  '<sos> Détends-toi\u202f! <eos>',
#  '<sos> Couvre-moi. <eos>',
#  '<sos> Menottez-le. <eos>',
#  '<sos> Avance ! <eos>',
#  '<sos> Avancez ! <eos>',
#  '<sos> Continue à rouler ! <eos>',
#  '<sos> Continuez à rouler ! <eos>',
#  '<sos> Trouve Tom. <eos>',
#  '<sos> Trouvez Tom. <eos>',
#  '<sos> Réparez ceci. <eos>',
#  '<sos> Répare ça. <eos>',
#  '<sos> Dégage\u202f! <eos>',
#  '<sos> Casse-toi. <eos>',
#  '<sos> Pars ! <eos>',
#  '<sos> Dégage ! <eos>',
#  '<sos> Fous le camp ! <eos>',
#  "<sos> Pars d'ici. <eos>",
#  '<sos> Va-t’en\xa0! <eos>',
#  '<sos> Écarte-toi ! <eos>',
#  '<sos> Disparais ! <eos>',
#  '<sos> Allez-vous-en\xa0! <eos>',
#  '<sos> Fiche le camp. <eos>',
#  '<sos> Tire-toi de là. <eos>',
#  '<sos> Dégage. <eos>',
#  "<sos> Va-t'en ! <eos>",
#  "<sos> Criss ton camp d'icit ! <eos>",
#  '<sos> Fichez le camp. <eos>',
#  '<sos> Déguerpissez. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Barrez-vous. <eos>',
#  '<sos> Barre-toi. <eos>',
#  '<sos> Va-t’en ! <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Tu dis n’importe quoi\xa0! <eos>',
#  '<sos> Pars. <eos>',
#  '<sos> Partez. <eos>',
#  '<sos> Lâche-toi ! <eos>',
#  '<sos> À terre ! <eos>',
#  '<sos> Au sol ! <eos>',
#  '<sos> Descends. <eos>',
#  '<sos> Descends ! <eos>',
#  '<sos> Descendez ! <eos>',
#  '<sos> Lâche-toi ! <eos>',
#  '<sos> Lâchez-vous ! <eos>',
#  '<sos> À terre ! <eos>',
#  '<sos> Au sol ! <eos>',
#  '<sos> Descends. <eos>',
#  "<sos> Va voir ailleurs si j'y suis\u202f! <eos>",
#  '<sos> Dégage\u202f! <eos>',
#  '<sos> Va au diable ! <eos>',
#  '<sos> Déguerpissez. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Va te faire foutre\xa0! <eos>',
#  '<sos> Va te faire voir\xa0! <eos>',
#  '<sos> Fiche le camp. <eos>',
#  '<sos> Fichez le camp. <eos>',
#  '<sos> Déguerpissez. <eos>',
#  '<sos> Cassez-vous. <eos>',
#  '<sos> Bouge ! <eos>',
#  '<sos> Décampez ! <eos>',
#  '<sos> Décampe ! <eos>',
#  '<sos> Sois réaliste ! <eos>',
#  '<sos> Tu délires\xa0! <eos>',
#  '<sos> Allez\u202f! <eos>',
#  '<sos> Vas-y. <eos>',
#  '<sos> En avant\u202f! <eos>',
#  '<sos> Va ! <eos>',
#  '<sos> Poursuis ! <eos>',
#  '<sos> Poursuivez ! <eos>',
#  '<sos> Passe devant ! <eos>',
#  '<sos> Vas-y ! <eos>',
#  '<sos> Allez-y ! <eos>',
#  '<sos> Continuez ! <eos>',
#  '<sos> Continue ! <eos>',
#  '<sos> Allez ! <eos>',
#  '<sos> Avance ! <eos>',
#  '<sos> En avant\xa0! <eos>',
#  '<sos> Allez\u202f! <eos>',
#  '<sos> Vas-y. <eos>',
#  '<sos> Va ! <eos>',
#  '<sos> Poursuis ! <eos>',
#  '<sos> Poursuivez ! <eos>',
#  '<sos> Passe devant ! <eos>',
#  '<sos> Vas-y ! <eos>',
#  '<sos> Allez-y ! <eos>',
#  '<sos> Continuez ! <eos>',
#  '<sos> Continue ! <eos>',
#  '<sos> Allez ! <eos>',
#  '<sos> Avance ! <eos>',
#  '<sos> En route ! <eos>',
#  '<sos> Bien joué\u202f! <eos>',
#  '<sos> Bon boulot\u202f! <eos>',
#  '<sos> Beau travail\u202f! <eos>',
#  '<sos> Bravo ! <eos>',
#  '<sos> Attrape Tom. <eos>',
#  '<sos> Attrapez Tom. <eos>',
#  '<sos> Attrape-le. <eos>',
#  '<sos> Attrapez-le. <eos>',
#  '<sos> Mettez-lui la main dessus ! <eos>',
#  '<sos> Amuse-toi bien ! <eos>',
#  '<sos> Amusez-vous bien ! <eos>',
#  '<sos> Amuse-toi bien. <eos>',
#  '<sos> Amusez-vous bien. <eos>',
#  '<sos> Il a parlé. <eos>',
#  '<sos> Il a pris la parole. <eos>',
#  "<sos> Il s'est exprimé. <eos>",
#  '<sos> Il essaye. <eos>',
#  '<sos> Il est mouillé. <eos>',
#  '<sos> Aide Tom. <eos>',
#  '<sos> Aidez Tom. <eos>',
#  '<sos> Aidez Tom ! <eos>',
#  '<sos> Salut, les mecs ! <eos>',
#  '<sos> Riposte. <eos>',
#  '<sos> Ripostez. <eos>',
#  "<sos> Comme c'est mignon\u202f! <eos>",
#  '<sos> Trop mignon ! <eos>',
#  '<sos> Trop mignonne ! <eos>',
#  '<sos> Quelle profondeur\u202f? <eos>',
#  '<sos> Comme elle est belle\u202f! <eos>',
#  "<sos> Comme c'est chouette ! <eos>",
#  "<sos> Comme c'est gentil ! <eos>",
#  "<sos> C'est du joli ! <eos>",
#  "<sos> Comme c'est agréable ! <eos>",
#  '<sos> Quelle grossièreté ! <eos>',
#  '<sos> Quelle impolitesse ! <eos>',
#  '<sos> Quelle sagesse ! <eos>',
#  '<sos> Dépêche-toi. <eos>',
#  '<sos> Grouille\u202f! <eos>',
#  '<sos> Pressez-vous ! <eos>',
#  '<sos> Fiça ! <eos>',
#  '<sos> Magne-toi ! <eos>',
#  '<sos> Magnez-vous ! <eos>',
#  '<sos> Je suis Tom. <eos>',
#  "<sos> J'ai juré. <eos>",
#  "<sos> Je m'en suis bien sorti. <eos>",
#  "<sos> Je m'en suis bien sortie. <eos>",
#  "<sos> Je l'ai fait. <eos>",
#  "<sos> C'est moi qui l'ai fait. <eos>",
#  "<sos> J'ai échoué. <eos>",
#  "<sos> J'ai oublié. <eos>",
#  "<sos> J'ai compris. <eos>",
#  "<sos> J'ai fait une gaffe. <eos>",
#  "<sos> J'ai fait une bourde. <eos>",
#  "<sos> J'ai fait une boulette. <eos>",
#  "<sos> J'ai compris. <eos>",
#  "<sos> J'ai capté. <eos>",
#  "<sos> J'ai aidé. <eos>",
#  "<sos> J'ai sauté. <eos>",
#  '<sos> J’ai regardé. <eos>',
#  '<sos> J’ai râlé. <eos>',
#  '<sos> J’ai fait signe de la tête. <eos>',
#  '<sos> J’ai obéi. <eos>',
#  '<sos> Je téléphonai. <eos>',
#  "<sos> J'ai téléphoné. <eos>",
#  '<sos> Je refuse. <eos>',
#  '<sos> Je le refuse. <eos>',
#  '<sos> Je me suis reposé. <eos>',
#  '<sos> Je me suis reposée. <eos>',
#  "<sos> Je l'ai vu. <eos>",
#  '<sos> Je l’ai vu. <eos>',
#  '<sos> J’ai soupiré. <eos>',
#  "<sos> J'ai souri. <eos>",
#  '<sos> Je suis resté. <eos>',
#  '<sos> Je suis restée. <eos>',
#  '<sos> J’ai parlé. <eos>',
#  "<sos> Je l'utilise. <eos>",
#  "<sos> J'en fais usage. <eos>",
#  "<sos> Je m'en sers. <eos>",
#  '<sos> Je paierai. <eos>',
#  '<sos> Je paie. <eos>',
#  '<sos> Je vais essayer. <eos>',
#  "<sos> J'essaierai. <eos>",
#  '<sos> Je suis revenu. <eos>',
#  '<sos> Me revoilà. <eos>',
#  '<sos> Je suis chauve. <eos>',
#  '<sos> Je suis occupé. <eos>',
#  '<sos> Je suis occupée. <eos>',
#  '<sos> Je suis calme. <eos>',
#  "<sos> J'ai froid. <eos>",
#  '<sos> Je suis détendu. <eos>',
#  '<sos> Je suis détendue. <eos>',
#  '<sos> Je suis sourd. <eos>',
#  '<sos> Je suis sourde. <eos>',
#  "<sos> J'en ai fini. <eos>",
#  '<sos> Je suis juste. <eos>',
#  "<sos> J'ai la peau claire. <eos>",
#  "<sos> J'ai le teint clair. <eos>",
#  '<sos> Je suis rapide. <eos>',
#  '<sos> Tout va bien. <eos>',
#  '<sos> Je vais bien. <eos>',
#  '<sos> Ça va. <eos>',
#  '<sos> Je suis libre ! <eos>',
#  '<sos> Je suis libre. <eos>',
#  '<sos> Je suis disponible. <eos>',
#  '<sos> Je suis repu\u202f! <eos>',
#  '<sos> Je suis rassasié\u202f! <eos>',
#  "<sos> J'en suis. <eos>",
#  '<sos> Je suis de la partie. <eos>',
#  '<sos> Je suis content. <eos>',
#  '<sos> Je vais bien. <eos>',
#  '<sos> Je suis bon. <eos>',
#  '<sos> Je suis chez moi. <eos>',
#  '<sos> Je suis en retard. <eos>',
#  '<sos> Je suis paresseux. <eos>',
#  '<sos> Je suis fainéant. <eos>',
#  '<sos> Je suis paresseuse. <eos>',
#  '<sos> Je suis fainéante. <eos>',
#  '<sos> Je suis paumé. <eos>',
#  '<sos> Je suis perdue. <eos>',
#  '<sos> Je vais bien. <eos>',
#  '<sos> Je me porte bien. <eos>',
#  '<sos> Je suis riche. <eos>',
#  '<sos> Je suis en sécurité. <eos>',
#  '<sos> Je suis malade. <eos>',
#  "<sos> J'en suis certain. <eos>",
#  '<sos> Je suis certain. <eos>',
#  "<sos> J'en suis sûr. <eos>",
#  "<sos> J'en suis sûre. <eos>",
#  '<sos> Je suis grande. <eos>',
#  '<sos> Je suis mince. <eos>',
#  '<sos> Je suis ordonné. <eos>',
#  '<sos> Je suis ordonnée. <eos>',
#  '<sos> Je suis laid. <eos>',
#  '<sos> Je suis laide. <eos>',
#  '<sos> Je suis moche. <eos>',
#  '<sos> Je suis faible. <eos>',
#  '<sos> Je vais bien. <eos>',
#  '<sos> Je me porte bien. <eos>',
#  "<sos> J'ai gagné. <eos>",
#  "<sos> Je l'ai emporté. <eos>",
#  '<sos> Ça aide. <eos>',
#  '<sos> Ça fait mal. <eos>',
#  '<sos> Elle marche. <eos>',
#  '<sos> Ça fonctionne. <eos>',
#  "<sos> C'est Tom. <eos>",
#  "<sos> C'est marrant. <eos>",
#  "<sos> C'est rigolo. <eos>",
#  "<sos> C'est le sien. <eos>",
#  "<sos> C'est la sienne. <eos>",
#  "<sos> C'est chaud. <eos>",
#  "<sos> C'est nouveau. <eos>",
#  "<sos> C'est neuf. <eos>",
#  "<sos> C'est bizarre. <eos>",
#  '<sos> Il est rouge. <eos>',
#  '<sos> C’est triste. <eos>',
#  "<sos> Défense d'entrer. <eos>",
#  "<sos> N'entrez pas. <eos>",
#  '<sos> Tuez Tom. <eos>',
#  '<sos> Tue Tom. <eos>',
#  '<sos> Embrasse Tom. <eos>',
#  '<sos> Laisse tomber ! <eos>',
#  '<sos> Laissez tomber ! <eos>',
#  '<sos> Laisse ! <eos>',
#  '<sos> Laissez ça. <eos>',
#  '<sos> Laisse ça. <eos>',
#  '<sos> Laissez-moi ! <eos>',
#  '<sos> Laisse-nous ! <eos>',
#  '<sos> Laissez-nous ! <eos>',
#  '<sos> Allons-y ! <eos>',
#  '<sos> Allons ! <eos>',
#  '<sos> En route ! <eos>',
#  '<sos> Allons-y ! <eos>',
#  '<sos> En route ! <eos>',
#  '<sos> Attention ! <eos>',
#  '<sos> Faites attention\u202f! <eos>',
#  '<sos> Fais attention\u202f! <eos>',
#  '<sos> Soyez prudente ! <eos>',
#  '<sos> Fais gaffe ! <eos>',
#  '<sos> Faites gaffe ! <eos>',
#  '<sos> Fais attention ! <eos>',
#  '<sos> Regarde donc ! <eos>',
#  '<sos> Faites attention. <eos>',
#  '<sos> Fais attention. <eos>',
#  '<sos> Épouse-moi ! <eos>',
#  '<sos> Épousez-moi ! <eos>',
#  '<sos> Puis-je partir ? <eos>',
#  '<sos> Puis-je y aller ? <eos>',
#  "<sos> Puis-je m'y rendre ? <eos>",
#  '<sos> Belle tentative. <eos>',
#  '<sos> Taratata\u202f! <eos>',
#  '<sos> Billevesées\u202f! <eos>',
#  '<sos> Jamais de la vie\u202f! <eos>',
#  '<sos> Baratin\u202f! <eos>',
#  "<sos> N'importe quoi ! <eos>",
#  '<sos> Balivernes ! <eos>',
#  '<sos> Foutaises ! <eos>',
#  '<sos> Des conneries ! <eos>',
#  '<sos> Des bêtises ! <eos>',
#  '<sos> Non-sens\u2009! <eos>',
#  '<sos> Fariboles ! <eos>',
#  '<sos> Conneries ! <eos>',
#  '<sos> Arrêtez-vous maintenant\xa0! <eos>',
#  '<sos> Arrête-toi maintenant\xa0! <eos>',
#  '<sos> Prouvez-le. <eos>',
#  '<sos> Prouve-le. <eos>',
#  '<sos> Fuyez. <eos>',
#  '<sos> Fuis. <eos>',
#  '<sos> Enfuyez-vous. <eos>',
#  '<sos> Enfuis-toi. <eos>',
#  '<sos> Sauve Tom. <eos>',
#  '<sos> Sauvez Tom. <eos>',
#  '<sos> De quoi\u202f? <eos>',
#  '<sos> Elle est venue. <eos>',
#  '<sos> Elle est morte. <eos>',
#  '<sos> Elle est partie. <eos>',
#  '<sos> Elle court. <eos>',
#  '<sos> Assieds-toi ! <eos>',
#  '<sos> Asseyez-vous ! <eos>',
#  '<sos> Asseyez-vous. <eos>',
#  '<sos> Assieds-toi. <eos>',
#  '<sos> Asseyez-vous. <eos>',
#  '<sos> Assieds-toi ici. <eos>',
#  '<sos> Asseyez-vous ici. <eos>',
#  '<sos> Parle plus fort\u202f! <eos>',
#  '<sos> Parlez plus fort\u202f! <eos>',
#  '<sos> Parle plus fort ! <eos>',
#  '<sos> Accélère. <eos>',
#  '<sos> Accélérez. <eos>',
#  '<sos> Lève-toi. <eos>',
#  '<sos> Arrête Tom. <eos>',
#  '<sos> Stoppez Tom. <eos>',
#  '<sos> Prends Tom. <eos>',
#  '<sos> Goûte-le. <eos>',
#  '<sos> Goûte-la. <eos>',
#  '<sos> Goûtez-le. <eos>',
#  '<sos> Goûtez-la. <eos>',
#  '<sos> Dis-le à Tom. <eos>',
#  '<sos> Informez-en Tom. <eos>',
#  '<sos> Fantastique\u202f! <eos>',
#  '<sos> Génial\u202f! <eos>',
#  '<sos> Super\u202f! <eos>',
#  '<sos> Au poil\u202f! <eos>',
#  '<sos> Impeccable\u202f! <eos>',
#  '<sos> Nickel\u202f! <eos>',
#  '<sos> Excellent\u202f! <eos>',
#  '<sos> Magnifique\u202f! <eos>',
#  '<sos> Nickel chrome\u202f! <eos>',
#  '<sos> Bien. <eos>',
#  '<sos> Formidable ! <eos>',
#  "<sos> C'est génial ! <eos>",
#  '<sos> À la bonne heure ! <eos>',
#  "<sos> C'est super. <eos>",
#  '<sos> Super ! <eos>',
#  '<sos> Génial ! <eos>',
#  '<sos> Sensass ! <eos>',
#  '<sos> Ils gagnèrent. <eos>',
#  '<sos> Elles gagnèrent. <eos>',
#  '<sos> Ils ont gagné. <eos>',
#  '<sos> Elles ont gagné. <eos>',
#  '<sos> Tom est venu. <eos>',
#  '<sos> Tom est mort. <eos>',
#  '<sos> Tom savait. <eos>',
#  '<sos> Tom est parti. <eos>',
#  '<sos> Tom partit. <eos>',
#  '<sos> Tom a menti. <eos>',
#  '<sos> Tom ment. <eos>',
#  '<sos> Tom a perdu. <eos>',
#  '<sos> Tom a payé. <eos>',
#  '<sos> Tom payait. <eos>',
#  '<sos> Tom est parti. <eos>',
#  '<sos> Tom est debout. <eos>',
#  '<sos> Trop tard. <eos>',
#  '<sos> Touchez-le. <eos>',
#  '<sos> Touchez-la. <eos>',
#  '<sos> Touche-le. <eos>',
#  '<sos> Touche-la. <eos>',
#  '<sos> Fais-moi confiance\u202f! <eos>',
#  '<sos> Faites-moi confiance. <eos>',
#  '<sos> Fais-moi confiance. <eos>',
#  '<sos> Ayez confiance en moi. <eos>',
#  '<sos> Aie confiance en moi. <eos>',
#  '<sos> Essaies-en ! <eos>',
#  '<sos> Essayez-en ! <eos>',
#  '<sos> Essaie. <eos>',
#  '<sos> Essaie ceci ! <eos>',
#  '<sos> Essayez ceci ! <eos>',
#  '<sos> Essaye ceci. <eos>',
#  '<sos> Utilise ceci. <eos>',
#  '<sos> Utilisez ceci. <eos>',
#  '<sos> Emploie ceci ! <eos>',
#  '<sos> Employez ceci ! <eos>',
#  '<sos> Avertis Tom. <eos>',
#  '<sos> Préviens Tom. <eos>',
#  '<sos> Regarde-moi ! <eos>',
#  '<sos> Regardez-moi ! <eos>',
#  '<sos> Regardez-nous ! <eos>',
#  '<sos> Regarde-nous ! <eos>',
#  "<sos> Nous sommes d'accord. <eos>",
#  '<sos> Nous irons. <eos>',
#  '<sos> Nous allons bien. <eos>',
#  '<sos> Pour quoi faire\u202f? <eos>',
#  '<sos> À quoi bon ? <eos>',
#  "<sos> Qu'est-ce qu'on s'est marrés ! <eos>",
#  "<sos> Qu'est-ce qu'on s'est marrées ! <eos>",
#  '<sos> Qui suis-je ? <eos>',
#  '<sos> Qui est venu ? <eos>',
#  '<sos> Qui est mort ? <eos>',
#  '<sos> Qui est tombé\xa0? <eos>',
#  '<sos> Qui a perdu ? <eos>',
#  '<sos> Qui a payé\xa0? <eos>',
#  '<sos> Qui a payé? <eos>',
#  '<sos> Qui démissionne\xa0? <eos>',
#  '<sos> Qui est-il\u202f? <eos>',
#  '<sos> Écris-moi ! <eos>',
#  '<sos> Écrivez-moi ! <eos>',
#  '<sos> Tu as perdu. <eos>',
#  '<sos> Vous avez perdu. <eos>',
#  '<sos> T’as perdu. <eos>',
#  '<sos> Je vous en prie. <eos>',
#  '<sos> Après vous. <eos>',
#  '<sos> À vous l’honneur. <eos>',
#  '<sos> À toi l’honneur. <eos>',
#  '<sos> En joue ! Feu ! <eos>',
#  '<sos> Suis-je mignon ? <eos>',
#  '<sos> Suis-je en retard ? <eos>',
#  '<sos> Répondez-moi. <eos>',
#  '<sos> Sois honnête. <eos>',
#  '<sos> Soyez honnêtes. <eos>',
#  '<sos> Soyez honnête. <eos>',
#  '<sos> Assieds-toi ! <eos>',
#  '<sos> Asseyez-vous ! <eos>',
#  '<sos> Asseyez-vous. <eos>',
#  '<sos> Sois puissante\xa0! <eos>',
#  '<sos> Les oiseaux volent. <eos>',
#  '<sos> À tes souhaits\u202f! <eos>',
#  '<sos> Appelle à la maison ! <eos>',
#  '<sos> Calmez-vous ! <eos>',
#  '<sos> Du calme. <eos>',
#  '<sos> Tranquille. <eos>',
#  '<sos> Calme-toi. <eos>',
#  '<sos> Du calme. <eos>',
#  '<sos> Tranquille. <eos>',
#  '<sos> Pouvons-nous partir ? <eos>',
#  '<sos> Pouvons-nous nous en aller ? <eos>',
#  '<sos> Pouvons-nous y aller ? <eos>',
#  '<sos> Attrape Tom. <eos>',
#  '<sos> Attrapez Tom. <eos>',
#  '<sos> Attrape-le\u202f! <eos>',
#  '<sos> Rattrape-le. <eos>',
#  '<sos> Saisissez-le. <eos>',
#  '<sos> Calme-toi. <eos>',
#  '<sos> Tranquille. <eos>',
#  '<sos> Choisis-moi ! <eos>',
#  '<sos> Reviens ! <eos>',
#  '<sos> Revenez ! <eos>',
#  '<sos> Viens ici. <eos>',
#  '<sos> Venez là. <eos>',
#  '<sos> Venez ici ! <eos>',
#  '<sos> Viens chez nous ! <eos>',
#  '<sos> Venez chez nous ! <eos>',
#  '<sos> Viens chez moi ! <eos>',
#  '<sos> Venez chez moi ! <eos>',
#  '<sos> Viens bientôt ! <eos>',
#  '<sos> Venez bientôt ! <eos>',
#  '<sos> Calmez-vous ! <eos>',
#  '<sos> Ai-je gagné ? <eos>',
#  "<sos> L'ai-je emporté ? <eos>",
#  '<sos> Est-ce moi qui ai gagné ? <eos>',
#  '<sos> Faites-le maintenant. <eos>',
#  '<sos> Des chiens aboient. <eos>',
#  '<sos> Les chiens aboient. <eos>',
#  '<sos> Ne demande pas ! <eos>',
#  '<sos> Ne pleure pas ! <eos>',
#  '<sos> Ne meurs pas ! <eos>',
#  '<sos> Ne mourez pas ! <eos>',
#  '<sos> Ne mens pas. <eos>',
#  '<sos> Ne mens pas ! <eos>',
#  '<sos> Ne courez pas. <eos>',
#  '<sos> Ne cours pas. <eos>',
#  '<sos> Excuse-moi. <eos>',
#  '<sos> Excusez-moi. <eos>',
#  "<sos> Je m'excuse. <eos>",
#  '<sos> Pardon\u202f? <eos>',
#  '<sos> Je vous demande pardon\u202f? <eos>',
#  '<sos> Plaît-il\u202f? <eos>',
#  '<sos> Plait-il\u202f? <eos>',
#  '<sos> Pardon ? <eos>',
#  '<sos> Fantastique\u202f! <eos>',
#  '<sos> Fantastique\xa0! <eos>',
#  '<sos> Sensass ! <eos>',
#  ...]

# %% [markdown]
# ### Data prep

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_eng_word = max([len(word) for word in eng_texts])
max_fra_word = max([len(word) for word in fra_texts])
print(f"{max_eng_word} :: {max_fra_word}")
# Out:
# 14 :: 69

# %%
eng_tok = Tokenizer(filters = ' ', lower = True)
eng_tok.fit_on_texts(eng_texts)
encoder_input_data = eng_tok.texts_to_sequences(eng_texts)
encoder_input_data = pad_sequences(encoder_input_data, maxlen = max_eng_word, padding = 'pre')

# %%
encoder_input_data
# Out:
# array([[  0,   0,   0, ...,   0,   0,  30],
#        [  0,   0,   0, ...,   0,   0,  30],
#        [  0,   0,   0, ...,   0,   0,  30],
#        ...,
#        [  0,   0,   0, ...,  10, 207, 436],
#        [  0,   0,   0, ...,  10, 207, 261],
#        [  0,   0,   0, ...,  10, 207, 200]])

# %%
fra_tok = Tokenizer(filters = ' ', lower = True)
fra_tok.fit_on_texts(fra_texts)
decoder_input_data = fra_tok.texts_to_sequences(fra_texts)
decoder_input_data = pad_sequences(decoder_input_data, maxlen = max_fra_word, padding = 'pre')

# %%
decoder_input_data
# Out:
# array([[   0,    0,    0, ...,   42,    4,    2],
#        [   0,    0,    0, ...,    1,  430,    2],
#        [   0,    0,    0, ...,  326,    4,    2],
#        ...,
#        [   0,    0,    0, ..., 5570,  369,    2],
#        [   0,    0,    0, ..., 5571,  369,    2],
#        [   0,    0,    0, ...,  517,  446,    2]])

# %%
fra_tok.word_index.keys()
# Out:
# dict_keys(['<sos>', '<eos>', 'je', '!', 'tom', 'suis', '?', "c'est", 'est', 'nous', 'de', 'il', "j'ai", 'ne', 'pas', 'le', 'vous', 'à', 'me', 'la', 'a', 'un', 'en', 'tu', 'les', 'tom.', 'ça', 'une', 'est-ce', 'sont', 'ils', 'qui', 'que', 'soyez', 'fait', 'pas.', 'sommes', 'êtes', 'elles', 'du', 'elle', 'va', 'des', 'ça.', 'te', 'sois', 'été', 'es', 'ce', 'faut', 'y', 'êtes-vous', 'fais', 'bien.', 'on', 'ai', 'se', 'tout', 'restez', "m'a", 'besoin', "l'ai", "j'aime", 'reste', 'était', 'peux', 'avons', "n'est", "j'étais", 'mon', "s'est", "c'était", 'au', 'sens', 'es-tu', 'bien', 'moi.', 'ont', 'aller.', 'partir.', 'ici.', 'prends', 'faites', 'veux', 'arrête', 'j’ai', 'vais', "j'en", 'train', 'chez', 'est-il', "s'il", 'prenez', "m'en", 'arrêtez', "l'a", 'personne', 'mal.', 'dois', "j'adore", 'avec', 'cela', "l'air", 'trop', 'moi', 'comme', 'suis-je', 'triste.', 'ton', 'quelle', 'toi.', 'ma', 'plaît.', 'calme.', 'ceci.', 'comment', 'as', 'très', "d'un", 'maintenant.', 'là.', 'allez', 'plus', 'continuez', 'laissez-moi', 'viens', 'votre', 'laisse', 'puis-je', 'aller', 'laisse-moi', 'pour', 'faire', 'déteste', 'cela.', 'perdu.', 'maison.', 'vous.', 'continue', 'venez', 'quel', 'dans', 'bon.', 'malade.', 'sais', 'eu', 'monde', 'voir.', 'tellement', "n'ai", 'avez', "j'y", 'regarde', 'ici', 'dit', 'seul.', "s'agit", 'tranquille.', 'bon', 'demande', 'fou.', 'nous.', 'vu.', 'regardez', 'mal', "d'une", 'juste', 'pris', 'faire.', 'sécurité.', 'c’est', "qu'est-ce", 'lui.', "t'es", 'pouvons', 'a-t-il', 'gagné.', "n'en", 'courir.', "t'ai", 'attends', 'debout.', 'laissez', 'coup', 'yeux.', 'chaud.', 'attention.', 'parle', 'une.', 'un.', 'lui', 'sur', 'sans', 'tomber.', 'fait.', 'occupé.', 'bizarre.', 'confiance', 'vite.', 'parler.', 'senti', 'temps.', 'maintenant', 'bouge', 'pars', 'chercher', 'si', 'porte', 'bonne', 'vois', 'là', 'grand.', 'peut', 'mourir.', 'heureux.', 'travail.', 'dispose', 'chien.', "j'irai", 'pourrait', 'dessus.', 'essayer.', 'nouveau.', 'quoi', 'mort.', 'essaie', "d'accord.", 'perdu', 'ai-je', "s'en", 'mange', 'terminé.', 'attendez', 'merci', 'vrai', 'dis', 'voir', 'froid.', 'retard.', 'faible.', 'confiance.', 'ceci', 'prie.', 'toi', 'chance.', 'non.', 'vu', 'as-tu', 'pouvez', 'vos', 'parti.', 'gentil.', 'où', 'gros.', 'colère.', 'maison', 'pouvons-nous', 'mien.', 'boulot.', "l'aide.", 'vie', "j'apprécie", 'mieux.', 'fais-le', 'davantage.', 'fils.', 'sait', 'serai', 'sympa.', 'tous', 'par', 'vraiment', 'allons', 'plus.', 'riche.', 'sûr.', 'marrant.', "m'y", 'essayez', 'lit', 'mis', 'vue.', 'prêt.', 'mauvais.', 'temps', "n'y", 'encore.', 'chanter.', 'sentis', 'thé.', "l'amour", 'simplement', 'rien.', 'nouveau', 'sommes-nous', "t'en", 'beaucoup.', 'gagné', 'tiens', 'essayé.', 'timide.', 'fini.', 'juste.', 'paresseux.', 'tard.', 'avance.', 'cool.', 'venir.', 'nager.', 'devenu', 'blessé.', 'blessé', 'grand', 'entrer', 'tous.', 'gagner.', "j'avais", 'dehors.', 'arme', 'avait', 'voiture.', 'dormir.', 'idée.', 'facile.', 'vrai.', 'route', 'non', 'tes', 'aucune', 'décampe', 'pleuré.', 'avance', 'trouve', 'attrape', 'main', 'occupée.', 'prudente', 'partir', 'joue', 'vieux.', 'voilà', 'avoir', 'besoin.', 'vus.', 'mes', 'rester.', 'seule.', 'premier.', 'dur.', 'mienne.', 'garde', 'entrer.', 'vas', 'venir', 'tranquille', 'lire.', 'marcher.', 'tiré', "l'intérieur.", 'perdre.', 'horrible.', 'drôle.', 'encore', 'était-il', 'heureuse.', 'aux', 'danser.', 'idiot.', 'jamais.', 'tort.', 'français.', 'veuillez', "n'a", 'marche', "quelqu'un", 'sont-ils', 'livre.', 'menti.', 'ans.', 'ah', "l'avons", 'camp.', 'tomber', 'laisse-le', 'vers', 'promis.', 'sait.', 'haut.', 'souri.', 'grande.', 'attention', 'fort', 'reviens', 'sérieux.', 'vues.', 'travailler.', 'vie.', 'tête', 'saoul.', 'prête', 'prêt', 'et', 'gardez', 'lis', 'bouger.', 'assis.', 'soin', 'malade', 'demandez', 'manger.', 'tôt.', 'attendre.', 'sentie', 'préparé', 'bonne.', 'faim', 'fou', 'toutes.', 'devons', 'aider.', 'avez-vous', 'chercher.', 'jeune.', 'également', 'bière.', 'beaucoup ...

# %%
decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[:, 1:]
decoder_target_data
# Out:
# array([[  0,   0,   0, ...,   4,   2,   0],
#        [  0,   0,   0, ..., 430,   2,   0],
#        [  0,   0,   0, ...,   4,   2,   0],
#        ...,
#        [  0,   0,   0, ..., 369,   2,   0],
#        [  0,   0,   0, ..., 369,   2,   0],
#        [  0,   0,   0, ..., 446,   2,   0]])

# %%
print(f"{encoder_input_data.shape} :: {decoder_input_data.shape} :: {decoder_target_data.shape}")
# Out:
# (10000, 14) :: (10000, 69) :: (10000, 69)

# %% [markdown]
# ### vocabs

# %%
eng_vocabs = len(eng_tok.word_index) + 1
fra_vocabs = len(fra_tok.word_index) + 1

# %%
print(f"{eng_vocabs} :: {fra_vocabs}")
# Out:
# 2707 :: 5572

# %% [markdown]
# ### making the encoders

# %%
from tensorflow.keras.layers import Input, Embedding, LSTM

# %%
latent_dim = 256

# %%
enc_inputs = Input(shape = (max_eng_word, ))
enc_emb = Embedding(eng_vocabs, latent_dim)(enc_inputs)
enc_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)
enc_outputs, state_h, state_c = enc_lstm(enc_emb)

# %% [markdown]
# ### making the decoders

# %%
dec_inputs = Input(shape = (max_fra_word))
dec_emb_layer = Embedding(fra_vocabs, latent_dim)
dec_emb = dec_emb_layer(dec_inputs)
dec_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)

# %% [markdown]
# ### building the final Bahdanau attention model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Concatenate, Dense

# %%
class BahdanauAttention(Layer) : 
    def __init__(self, units) :
        super(BahdanauAttention, self).__init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, query, values) :
        query_wuth_time_axis = tensorflow.expand_dims(query, 1)
        score = self.V(tensorflow.nn.tanh(self.W1(values)) + self.W2(query_wuth_time_axis))
        attention_weights = tensorflow.nn.softmax(score, 1)
        context_vector = attention_weights * score
        context_vector = tensorflow.reduce_sum(context_vector, 1)

        return context_vector, attention_weights

# %%
attention = BahdanauAttention(latent_dim)
all_outputs = []
decoder_state_h, decoder_state_c = state_h, state_c
for t in range(max_fra_word) : 
    context_vector, _ = attention(decoder_state_h, decoder_state_c)
    X = tensorflow.expand_dims(dec_emb[:, t], 1)
    X = Concatenate(axis = -1)([context_vector[:, None, :], X])
    outputs, decoder_state_h, decoder_state_c = dec_lstm(X, initial_state = [decoder_state_h, decoder_state_c])
    outputs = Dense(fra_vocabs, activation = 'softmax')(outputs)
    all_outputs.append(outputs)

dec_outputs = tensorflow.concat(all_outputs, 1)

# %% [markdown]
# ### main model and training

# %%
model = Model()

# %%
model = Model([enc_inputs, dec_inputs], dec_outputs)
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 14)]         0           []
#
#  embedding_4 (Embedding)        (None, 14, 256)      692992      ['input_13[0][0]']
#
#  input_14 (InputLayer)          [(None, 69)]         0           []
#
#  lstm_4 (LSTM)                  [(None, 14, 256),    525312      ['embedding_4[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_5 (Embedding)        (None, 69, 256)      1426432     ['input_14[0][0]']
#
#  bahdanau_attention_2 (Bahdanau  ((None, 1),         131841      ['lstm_4[0][1]',
#  Attention)                      (None, None, 1))                 'lstm_4[0][2]',
#                                                                   'lstm_5[0][1]',
#                                                                   'lstm_5[0][2]',
#                                                                   'lstm_5[1][1]',
#                                                                   'lstm_5[1][2]',
#                                                                   'lstm_5[2][1]',
#                                                                   'lstm_5[2][2]',
#                                                                   'lstm_5[3][1]',
#                                                                   'lstm_5[3][2]',
#                                                                   'lstm_5[4][1]',
#                                                                   'lstm_5[4][2]',
#                                                                   'lstm_5[5][1]',
#                                                                   'lstm_5[5][2]',
#                                                                   'lstm_5[6][1]',
#                                                                   'lstm_5[6][2]',
#                                                                   'lstm_5[7][1]',
#                                                                   'lstm_5[7][2]',
#                                                                   'lstm_5[8][1]',
#                                                                   'lstm_5[8][2]',
#                                                                   'lstm_5[9][1]',
#                                                                   'lstm_5[9][2]',
#                                                                   'lstm_5[10][1]',
#                                                                   'lstm_5[10][2]',
#                                                                   'lstm_5[11][1]',
#                                                                   'lstm_5[11][2]',
#                                                                   'lstm_5[12][1]',
#                                                                   'lstm_5[12][2]',
#                                                                   'lstm_5[13][1]',
#                                                                   'lstm_5[13][2]',
#                                                                   'lstm_5[14][1]',
#                                                                   'lstm_5[14][2]',
#                                                                   'lstm_5[15][1]',
#                                                                   'lstm_5[15][2]',
#                                                                   'lstm_5[16][1]',
#                                                                   'lstm_5[16][2]',
#                                                                   'lstm_5[17][1]',
#                                                                   'lstm_5[17][2]',
#                                                                   'lstm_5[18][1]',
#                                                                   'lstm_5[18][2]',
#                                                                   'lstm_5[19][1]',
#                                                                   'lstm_5[19][2]',
#                                                                   'lstm_5[20][1]',
#                                                                   'lstm_5[20][2]',
#                                                                   'lstm_5[21][1]',
#                                                                   'lstm_5[21][2]',
#                                                                   'lstm_5[22][1]',
#                                                                   'lstm_5[22][2]',
#                                                                   'lstm_5[23][1]',
#                                                                   'lstm_5[23][2]',
#                                                                   'lstm_5[24][1]',
#                                                                   'lstm_5[24][2]',
#                                                                   'lstm_5[25][1]',
#                                                                   'lstm_5[25][2]',
#                                                                   'lstm_5[26][1]',
#                                                                   'lstm_5[26][2]',
#                                                                   'lstm_5[27][1]',
#                                                                   'lstm_5[27][2]',
#                                                                   'lstm_5[28][1]',
#                                                                   'lstm_5[28][2]',
#                                                                   'lstm_5[29][1]',
#                                                                   'lstm_5[29][2]',
#                                                                   'lstm_5[30][1]',
#                                                                   'lstm_5[30][2]',
#                                                                   'lstm_5[31][1]',
#                                                                   'lstm_5[31][2]',
#                                                                   'lstm_5[32][1]',
#                                                                   'lstm_5[32][2]',
#                                                                   'lstm_5[33][1]',
#                                                                   'lstm_5[33][2]',
#                                                                   'lstm_5[34][1]',
#                                                                   'lstm_5[34][2]',
#                                                                   'lstm_5[35][1]',
#                                                                   'lstm_5[35][2]',
#                                                                   'lstm_5[36][1]',
#                                                                   'lstm_5[36][2]',
#                                                                   'lstm_5[37][1]',
#                                                                   'lstm_5[37][2]',
#                                                                   'lstm_5[38][1]',
#                                                                   'lstm_5[38][2]',
#                                                                   'lstm_5[39][1]',
#                                                                   'lstm_5[39][2]',
#                                                                   'lstm_5[40][1]',
#                                                                   'lstm_5[40][2]',
#                                                                   'lstm_5[41][1]',
#                                                                   'lstm_5[41][2]',
#                                                                   'lstm_5[42][1]',
#                                                                   'lstm_5[42][2]',
#                                                                   'lstm_5[43][1]',
#                                                                   'lstm_5[43][2]',
#                                                                   'lstm_5[44][1]',
#                                                                   'lstm_5[44][2]',
#                                                                   'lstm_5[45][1]',
#                                                                   'lstm_5[45][2]',
#                                                                   'lstm_5[46][1]',
#                                                                   'lstm_5[46][2]',
#                                                                   'lstm_5[47][1]',
#                                                                   'lstm_5[47][2]',
#                                                                   'lstm_5[48][1]',
#                                                                   'lstm_5[48][2]',
#                                                                   'lstm_5[49][1]',
#                                                                   'lstm_5[49][2]',
#                                                                   'lstm_5[50][1]',
#                                                                   'lstm_5[50][2]',
#                                                                   'lstm_5[51][1]',
#                                                                   'lstm_5[51][2]',
#                                                                   'lstm_5[52][1]',
#                                                                   'lstm_5[52][2]',
#                                                                   'lstm_5[53][1]',
#                                                                   'lstm_5[53][2]',
#                                                                   'lstm_5[54][1]',
#                                                                   'lstm_5[54][2]',
#                                                                   'lstm_5[55][1]',
#                                                                   'lstm_5[55][2]',
#                                                                   'lstm_5[56][1]',
#                                                                   'lstm_5[56][2]',
#                                                                   'lstm_5[57][1]',
#                                                                   'lstm_5[57][2]',
#                                                                   'lstm_5[58][1]',
#                                                                   'lstm_5[58][2]',
#                                                                   'lstm_5[59][1]',
#                                                                   'lstm_5[59][2]',
#                                                                   'lstm_5[60][1]',
#                                                                   'lstm_5[60][2]',
#                                                                   'lstm_5[61][1]',
#                                                                   'lstm_5[61][2]',
#                                                                   'lstm_5[62][1]',
#                                                                   'lstm_5[62][2]',
#                                                                   'lstm_5[63][1]',
#                                                                   'lstm_5[63][2]',
#                                                                   'lstm_5[64][1]',
#                                                                   'lstm_5[64][2]',
#                                                                   'lstm_5[65][1]',
#                                                                   'lstm_5[65][2]',
#                                                                   'lstm_5[66][1]',
#                                                                   'lstm_5[66][2]',
#                                                                   'lstm_5[67][1]',
#                                                                   'lstm_5[67][2]']
#
#  tf.__operators__.getitem_252 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_253 (  (None, 1, 1)        0           ['bahdanau_attention_2[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_128 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_252[0]
#  )                                                               [0]']
#
#  concatenate_128 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_253[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_128[0][0]']
#
#  lstm_5 (LSTM)                  [(None, 1, 256),     526336      ['concatenate_128[0][0]',
#                                  (None, 256),                     'lstm_4[0][1]',
#                                  (None, 256)]                     'lstm_4[0][2]',
#                                                                   'concatenate_129[0][0]',
#                                                                   'lstm_5[0][1]',
#                                                                   'lstm_5[0][2]',
#                                                                   'concatenate_130[0][0]',
#                                                                   'lstm_5[1][1]',
#                                                                   'lstm_5[1][2]',
#                                                                   'concatenate_131[0][0]',
#                                                                   'lstm_5[2][1]',
#                                                                   'lstm_5[2][2]',
#                                                                   'concatenate_132[0][0]',
#                                                                   'lstm_5[3][1]',
#                                                                   'lstm_5[3][2]',
#                                                                   'concatenate_133[0][0]',
#                                                                   'lstm_5[4][1]',
#                                                                   'lstm_5[4][2]',
#                                                                   'concatenate_134[0][0]',
#                                                                   'lstm_5[5][1]',
#                                                                   'lstm_5[5][2]',
#                                                                   'concatenate_135[0][0]',
#                                                                   'lstm_5[6][1]',
#                                                                   'lstm_5[6][2]',
#                                                                   'concatenate_136[0][0]',
#                                                                   'lstm_5[7][1]',
#                                                                   'lstm_5[7][2]',
#                                                                   'concatenate_137[0][0]',
#                                                                   'lstm_5[8][1]',
#                                                                   'lstm_5[8][2]',
#                                                                   'concatenate_138[0][0]',
#                                                                   'lstm_5[9][1]',
#                                                                   'lstm_5[9][2]',
#                                                                   'concatenate_139[0][0]',
#                                                                   'lstm_5[10][1]',
#                                                                   'lstm_5[10][2]',
#                                                                   'concatenate_140[0][0]',
#                                                                   'lstm_5[11][1]',
#                                                                   'lstm_5[11][2]',
#                                                                   'concatenate_141[0][0]',
#                                                                   'lstm_5[12][1]',
#                                                                   'lstm_5[12][2]',
#                                                                   'concatenate_142[0][0]',
#                                                                   'lstm_5[13][1]',
#                                                                   'lstm_5[13][2]',
#                                                                   'concatenate_143[0][0]',
#                                                                   'lstm_5[14][1]',
#                                                                   'lstm_5[14][2]',
#                                                                   'concatenate_144[0][0]',
#                                                                   'lstm_5[15][1]',
#                                                                   'lstm_5[15][2]',
#                                                                   'concatenate_145[0][0]',
#                                                                   'lstm_5[16][1]',
#                                                                   'lstm_5[16][2]',
#                                                                   'concatenate_146[0][0]',
#                                                                   'lstm_5[17][1]',
#                                                                   'lstm_5[17][2]',
#                                                                   'concatenate_147[0][0]',
#                                                                   'lstm_5[18][1]',
#                                                                   'lstm_5[18][2]',
#                                                                   'concatenate_148[0][0]',
#                                                                   'lstm_5[19][1]',
#                                                                   'lstm_5[19][2]',
#                                                                   'concatenate_149[0][0]',
#                                                                   'lstm_5[20][1]',
#                                                                   'lstm_5[20][2]',
#                                                                   'concatenate_150[0][0]',
#                                                                   'lstm_5[21][1]',
#                                                                   'lstm_5[21][2]',
#                                                                   'concatenate_151[0][0]',
#                                                                   'lstm_5[22][1]',
#                                                                   'lstm_5[22][2]',
#                                                                   'concatenate_152[0][0]',
#                                                                   'lstm_5[23][1]',
#                                                                   'lstm_5[23][2]',
#                                                                   'concatenate_153[0][0]',
#                                                                   'lstm_5[24][1]',
#                                                                   'lstm_5[24][2]',
#                                                                   'concatenate_154[0][0]',
#                                                                   'lstm_5[25][1]',
#                                                                   'lstm_5[25][2]',
#                                                                   'concatenate_155[0][0]',
#                                                                   'lstm_5[26][1]',
#                                                                   'lstm_5[26][2]',
#                                                                   'concatenate_156[0][0]',
#                                                                   'lstm_5[27][1]',
#                                                                   'lstm_5[27][2]',
#                                                                   'concatenate_157[0][0]',
#                                                                   'lstm_5[28][1]',
#                                                                   'lstm_5[28][2]',
#                                                                   'concatenate_158[0][0]',
#                                                                   'lstm_5[29][1]',
#                                                                   'lstm_5[29][2]',
#                                                                   'concatenate_159[0][0]',
#                                                                   'lstm_5[30][1]',
#                                                                   'lstm_5[30][2]',
#                                                                   'concatenate_160[0][0]',
#                                                                   'lstm_5[31][1]',
#                                                                   'lstm_5[31][2]',
#                                                                   'concatenate_161[0][0]',
#                                                                   'lstm_5[32][1]',
#                                                                   'lstm_5[32][2]',
#                                                                   'concatenate_162[0][0]',
#                                                                   'lstm_5[33][1]',
#                                                                   'lstm_5[33][2]',
#                                                                   'concatenate_163[0][0]',
#                                                                   'lstm_5[34][1]',
#                                                                   'lstm_5[34][2]',
#                                                                   'concatenate_164[0][0]',
#                                                                   'lstm_5[35][1]',
#                                                                   'lstm_5[35][2]',
#                                                                   'concatenate_165[0][0]',
#                                                                   'lstm_5[36][1]',
#                                                                   'lstm_5[36][2]',
#                                                                   'concatenate_166[0][0]',
#                                                                   'lstm_5[37][1]',
#                                                                   'lstm_5[37][2]',
#                                                                   'concatenate_167[0][0]',
#                                                                   'lstm_5[38][1]',
#                                                                   'lstm_5[38][2]',
#                                                                   'concatenate_168[0][0]',
#                                                                   'lstm_5[39][1]',
#                                                                   'lstm_5[39][2]',
#                                                                   'concatenate_169[0][0]',
#                                                                   'lstm_5[40][1]',
#                                                                   'lstm_5[40][2]',
#                                                                   'concatenate_170[0][0]',
#                                                                   'lstm_5[41][1]',
#                                                                   'lstm_5[41][2]',
#                                                                   'concatenate_171[0][0]',
#                                                                   'lstm_5[42][1]',
#                                                                   'lstm_5[42][2]',
#                                                                   'concatenate_172[0][0]',
#                                                                   'lstm_5[43][1]',
#                                                                   'lstm_5[43][2]',
#                                                                   'concatenate_173[0][0]',
#                                                                   'lstm_5[44][1]',
#                                                                   'lstm_5[44][2]',
#                                                                   'concatenate_174[0][0]',
#                                                                   'lstm_5[45][1]',
#                                                                   'lstm_5[45][2]',
#                                                                   'concatenate_175[0][0]',
#                                                                   'lstm_5[46][1]',
#                                                                   'lstm_5[46][2]',
#                                                                   'concatenate_176[0][0]',
#                                                                   'lstm_5[47][1]',
#                                                                   'lstm_5[47][2]',
#                                                                   'concatenate_177[0][0]',
#                                                                   'lstm_5[48][1]',
#                                                                   'lstm_5[48][2]',
#                                                                   'concatenate_178[0][0]',
#                                                                   'lstm_5[49][1]',
#                                                                   'lstm_5[49][2]',
#                                                                   'concatenate_179[0][0]',
#                                                                   'lstm_5[50][1]',
#                                                                   'lstm_5[50][2]',
#                                                                   'concatenate_180[0][0]',
#                                                                   'lstm_5[51][1]',
#                                                                   'lstm_5[51][2]',
#                                                                   'concatenate_181[0][0]',
#                                                                   'lstm_5[52][1]',
#                                                                   'lstm_5[52][2]',
#                                                                   'concatenate_182[0][0]',
#                                                                   'lstm_5[53][1]',
#                                                                   'lstm_5[53][2]',
#                                                                   'concatenate_183[0][0]',
#                                                                   'lstm_5[54][1]',
#                                                                   'lstm_5[54][2]',
#                                                                   'concatenate_184[0][0]',
#                                                                   'lstm_5[55][1]',
#                                                                   'lstm_5[55][2]',
#                                                                   'concatenate_185[0][0]',
#                                                                   'lstm_5[56][1]',
#                                                                   'lstm_5[56][2]',
#                                                                   'concatenate_186[0][0]',
#                                                                   'lstm_5[57][1]',
#                                                                   'lstm_5[57][2]',
#                                                                   'concatenate_187[0][0]',
#                                                                   'lstm_5[58][1]',
#                                                                   'lstm_5[58][2]',
#                                                                   'concatenate_188[0][0]',
#                                                                   'lstm_5[59][1]',
#                                                                   'lstm_5[59][2]',
#                                                                   'concatenate_189[0][0]',
#                                                                   'lstm_5[60][1]',
#                                                                   'lstm_5[60][2]',
#                                                                   'concatenate_190[0][0]',
#                                                                   'lstm_5[61][1]',
#                                                                   'lstm_5[61][2]',
#                                                                   'concatenate_191[0][0]',
#                                                                   'lstm_5[62][1]',
#                                                                   'lstm_5[62][2]',
#                                                                   'concatenate_192[0][0]',
#                                                                   'lstm_5[63][1]',
#                                                                   'lstm_5[63][2]',
#                                                                   'concatenate_193[0][0]',
#                                                                   'lstm_5[64][1]',
#                                                                   'lstm_5[64][2]',
#                                                                   'concatenate_194[0][0]',
#                                                                   'lstm_5[65][1]',
#                                                                   'lstm_5[65][2]',
#                                                                   'concatenate_195[0][0]',
#                                                                   'lstm_5[66][1]',
#                                                                   'lstm_5[66][2]',
#                                                                   'concatenate_196[0][0]',
#                                                                   'lstm_5[67][1]',
#                                                                   'lstm_5[67][2]']
#
#  tf.__operators__.getitem_254 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_255 (  (None, 1, 1)        0           ['bahdanau_attention_2[1][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_129 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_254[0]
#  )                                                               [0]']
#
#  concatenate_129 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_255[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_129[0][0]']
#
#  tf.__operators__.getitem_256 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_257 (  (None, 1, 1)        0           ['bahdanau_attention_2[2][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_130 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_256[0]
#  )                                                               [0]']
#
#  concatenate_130 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_257[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_130[0][0]']
#
#  tf.__operators__.getitem_258 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_259 (  (None, 1, 1)        0           ['bahdanau_attention_2[3][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_131 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_258[0]
#  )                                                               [0]']
#
#  concatenate_131 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_259[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_131[0][0]']
#
#  tf.__operators__.getitem_260 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_261 (  (None, 1, 1)        0           ['bahdanau_attention_2[4][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_132 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_260[0]
#  )                                                               [0]']
#
#  concatenate_132 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_261[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_132[0][0]']
#
#  tf.__operators__.getitem_262 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_263 (  (None, 1, 1)        0           ['bahdanau_attention_2[5][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_133 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_262[0]
#  )                                                               [0]']
#
#  concatenate_133 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_263[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_133[0][0]']
#
#  tf.__operators__.getitem_264 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_265 (  (None, 1, 1)        0           ['bahdanau_attention_2[6][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_134 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_264[0]
#  )                                                               [0]']
#
#  concatenate_134 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_265[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_134[0][0]']
#
#  tf.__operators__.getitem_266 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_267 (  (None, 1, 1)        0           ['bahdanau_attention_2[7][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_135 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_266[0]
#  )                                                               [0]']
#
#  concatenate_135 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_267[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_135[0][0]']
#
#  tf.__operators__.getitem_268 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_269 (  (None, 1, 1)        0           ['bahdanau_attention_2[8][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_136 (TFOpLambda  (None, 1, 256)      0           ['tf.__operators__.getitem_268[0]
#  )                                                               [0]']
#
#  concatenate_136 (Concatenate)  (None, 1, 257)       0           ['tf.__operators__.getitem_269[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_136[0][0]']
#
#  tf.__operators__.getitem_270 (  (None, 256)         0           ['embedding_5[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_271 (  (None, 1, 1)        0           ['bahdanau_attention_2[9][0]']
#  SlicingOpLambda)
# ...
#  dense_162 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[25][0]']
#
#  dense_163 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[26][0]']
#
#  dense_164 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[27][0]']
#
#  dense_165 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[28][0]']
#
#  dense_166 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[29][0]']
#
#  dense_167 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[30][0]']
#
#  dense_168 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[31][0]']
#
#  dense_169 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[32][0]']
#
#  dense_170 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[33][0]']
#
#  dense_171 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[34][0]']
#
#  dense_172 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[35][0]']
#
#  dense_173 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[36][0]']
#
#  dense_174 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[37][0]']
#
#  dense_175 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[38][0]']
#
#  dense_176 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[39][0]']
#
#  dense_177 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[40][0]']
#
#  dense_178 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[41][0]']
#
#  dense_179 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[42][0]']
#
#  dense_180 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[43][0]']
#
#  dense_181 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[44][0]']
#
#  dense_182 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[45][0]']
#
#  dense_183 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[46][0]']
#
#  dense_184 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[47][0]']
#
#  dense_185 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[48][0]']
#
#  dense_186 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[49][0]']
#
#  dense_187 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[50][0]']
#
#  dense_188 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[51][0]']
#
#  dense_189 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[52][0]']
#
#  dense_190 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[53][0]']
#
#  dense_191 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[54][0]']
#
#  dense_192 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[55][0]']
#
#  dense_193 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[56][0]']
#
#  dense_194 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[57][0]']
#
#  dense_195 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[58][0]']
#
#  dense_196 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[59][0]']
#
#  dense_197 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[60][0]']
#
#  dense_198 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[61][0]']
#
#  dense_199 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[62][0]']
#
#  dense_200 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[63][0]']
#
#  dense_201 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[64][0]']
#
#  dense_202 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[65][0]']
#
#  dense_203 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[66][0]']
#
#  dense_204 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[67][0]']
#
#  dense_205 (Dense)              (None, 1, 5572)      1432004     ['lstm_5[68][0]']
#
#  tf.concat_2 (TFOpLambda)       (None, 69, 5572)     0           ['dense_137[0][0]',
#                                                                   'dense_138[0][0]',
#                                                                   'dense_139[0][0]',
#                                                                   'dense_140[0][0]',
#                                                                   'dense_141[0][0]',
#                                                                   'dense_142[0][0]',
#                                                                   'dense_143[0][0]',
#                                                                   'dense_144[0][0]',
#                                                                   'dense_145[0][0]',
#                                                                   'dense_146[0][0]',
#                                                                   'dense_147[0][0]',
#                                                                   'dense_148[0][0]',
#                                                                   'dense_149[0][0]',
#                                                                   'dense_150[0][0]',
#                                                                   'dense_151[0][0]',
#                                                                   'dense_152[0][0]',
#                                                                   'dense_153[0][0]',
#                                                                   'dense_154[0][0]',
#                                                                   'dense_155[0][0]',
#                                                                   'dense_156[0][0]',
#                                                                   'dense_157[0][0]',
#                                                                   'dense_158[0][0]',
#                                                                   'dense_159[0][0]',
#                                                                   'dense_160[0][0]',
#                                                                   'dense_161[0][0]',
#                                                                   'dense_162[0][0]',
#                                                                   'dense_163[0][0]',
#                                                                   'dense_164[0][0]',
#                                                                   'dense_165[0][0]',
#                                                                   'dense_166[0][0]',
#                                                                   'dense_167[0][0]',
#                                                                   'dense_168[0][0]',
#                                                                   'dense_169[0][0]',
#                                                                   'dense_170[0][0]',
#                                                                   'dense_171[0][0]',
#                                                                   'dense_172[0][0]',
#                                                                   'dense_173[0][0]',
#                                                                   'dense_174[0][0]',
#                                                                   'dense_175[0][0]',
#                                                                   'dense_176[0][0]',
#                                                                   'dense_177[0][0]',
#                                                                   'dense_178[0][0]',
#                                                                   'dense_179[0][0]',
#                                                                   'dense_180[0][0]',
#                                                                   'dense_181[0][0]',
#                                                                   'dense_182[0][0]',
#                                                                   'dense_183[0][0]',
#                                                                   'dense_184[0][0]',
#                                                                   'dense_185[0][0]',
#                                                                   'dense_186[0][0]',
#                                                                   'dense_187[0][0]',
#                                                                   'dense_188[0][0]',
#                                                                   'dense_189[0][0]',
#                                                                   'dense_190[0][0]',
#                                                                   'dense_191[0][0]',
#                                                                   'dense_192[0][0]',
#                                                                   'dense_193[0][0]',
#                                                                   'dense_194[0][0]',
#                                                                   'dense_195[0][0]',
#                                                                   'dense_196[0][0]',
#                                                                   'dense_197[0][0]',
#                                                                   'dense_198[0][0]',
#                                                                   'dense_199[0][0]',
#                                                                   'dense_200[0][0]',
#                                                                   'dense_201[0][0]',
#                                                                   'dense_202[0][0]',
#                                                                   'dense_203[0][0]',
#                                                                   'dense_204[0][0]',
#                                                                   'dense_205[0][0]']
#
# ==================================================================================================
# Total params: 102,111,189
# Trainable params: 102,111,189
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(
    [encoder_input_data, decoder_input_data],
    np.expand_dims(decoder_target_data, -1),
    batch_size = 128,
    epochs = 1,
    validation_split = 0.2
)
# Out:
# 63/63 [==============================] - 392s 4s/step - loss: 2.4929 - accuracy: 0.8760 - val_loss: 0.3807 - val_accuracy: 0.9416

# %% [markdown]
# ## Inference models

# %% [markdown]
# ### reverse indexing

# %%
reverse_eng_tokens = {i : w for w, i in eng_tok.word_index.items()}
reverse_fra_tokens = {i : w for w, i in fra_tok.word_index.items()}

# %%
reverse_eng_tokens
# Out:
# {1: 'i',
#  2: "i'm",
#  3: 'tom',
#  4: 'is',
#  5: 'a',
#  6: 'it',
#  7: 'you',
#  8: 'it.',
#  9: "it's",
#  10: 'we',
#  11: 'was',
#  12: 'be',
#  13: 'are',
#  14: 'he',
#  15: 'me.',
#  16: 'get',
#  17: 'you.',
#  18: "don't",
#  19: "you're",
#  20: 'tom.',
#  21: 'go',
#  22: 'they',
#  23: 'up.',
#  24: 'can',
#  25: 'do',
#  26: "i'll",
#  27: 'take',
#  28: 'let',
#  29: 'to',
#  30: 'go.',
#  31: "that's",
#  32: 'the',
#  33: 'have',
#  34: 'this',
#  35: 'keep',
#  36: 'got',
#  37: 'me',
#  38: "they're",
#  39: 'not',
#  40: "we're",
#  41: 'need',
#  42: 'did',
#  43: "tom's",
#  44: 'stay',
#  45: 'my',
#  46: 'come',
#  47: 'no',
#  48: 'am',
#  49: 'she',
#  50: "let's",
#  51: 'that.',
#  52: 'who',
#  53: 'like',
#  54: "he's",
#  55: 'stop',
#  56: 'this.',
#  57: 'him.',
#  58: 'saw',
#  59: 'here.',
#  60: 'that',
#  61: 'love',
#  62: 'how',
#  63: 'us.',
#  64: 'all',
#  65: 'feel',
#  66: 'must',
#  67: 'what',
#  68: 'look',
#  69: 'out.',
#  70: 'want',
#  71: 'it?',
#  72: 'in.',
#  73: 'felt',
#  74: "can't",
#  75: 'just',
#  76: 'lost.',
#  77: 'see',
#  78: 'home.',
#  79: 'one.',
#  80: 'try',
#  81: 'please',
#  82: 'down.',
#  83: 'will',
#  84: 'back.',
#  85: 'again.',
#  86: 'out!',
#  87: 'had',
#  88: 'your',
#  89: 'it!',
#  90: 'in',
#  91: 'them.',
#  92: 'safe.',
#  93: 'may',
#  94: 'made',
#  95: 'at',
#  96: 'sad.',
#  97: 'so',
#  98: 'for',
#  99: 'mine.',
#  100: 'away.',
#  101: 'good.',
#  102: "we'll",
#  103: 'ok.',
#  104: 'help',
#  105: 'hate',
#  106: 'alone.',
#  107: 'give',
#  108: 'on',
#  109: 'has',
#  110: 'ask',
#  111: 'wait',
#  112: 'now.',
#  113: 'away!',
#  114: 'on.',
#  115: 'know',
#  116: 'busy.',
#  117: "i've",
#  118: 'won.',
#  119: 'too',
#  120: 'over.',
#  121: 'went',
#  122: 'hold',
#  123: 'fun.',
#  124: 'work.',
#  125: 'you?',
#  126: 'go?',
#  127: 'trust',
#  128: 'me?',
#  129: 'job.',
#  130: 'with',
#  131: 'up!',
#  132: 'win.',
#  133: 'still.',
#  134: 'here',
#  135: 'help.',
#  136: 'quiet.',
#  137: 'leave',
#  138: 'bad.',
#  139: 'know.',
#  140: 'call',
#  141: 'bed.',
#  142: 'make',
#  143: 'very',
#  144: 'run.',
#  145: 'wait.',
#  146: 'cool.',
#  147: 'well.',
#  148: 'come.',
#  149: 'lucky.',
#  150: 'there.',
#  151: 'happy.',
#  152: "isn't",
#  153: 'try.',
#  154: 'left.',
#  155: 'beat',
#  156: 'lazy.',
#  157: 'stop.',
#  158: 'big.',
#  159: 'eat',
#  160: 'calm.',
#  161: 'fair.',
#  162: 'me!',
#  163: 'mad.',
#  164: 'late.',
#  165: 'sit',
#  166: 'stand',
#  167: 'found',
#  168: 'prepared.',
#  169: 'grab',
#  170: 'now',
#  171: 'going.',
#  172: 'leave.',
#  173: 'crazy.',
#  174: 'her.',
#  175: "it'll",
#  176: 'more.',
#  177: 'home?',
#  178: "didn't",
#  179: 'dog.',
#  180: 'naive.',
#  181: 'relax.',
#  182: 'care.',
#  183: 'free.',
#  184: 'die.',
#  185: 'ready.',
#  186: 'early.',
#  187: 'sorry.',
#  188: 'easy.',
#  189: 'time.',
#  190: 'funny.',
#  191: 'hurt?',
#  192: 'lot.',
#  193: 'one',
#  194: 'buy',
#  195: 'nice.',
#  196: 'hang',
#  197: 'ahead.',
#  198: 'watch',
#  199: 'old.',
#  200: 'talk.',
#  201: 'drunk.',
#  202: 'first.',
#  203: "what's",
#  204: 'outside.',
#  205: 'wrong.',
#  206: 'him',
#  207: 'never',
#  208: 'could',
#  209: 'looks',
#  210: 'see.',
#  211: 'fat.',
#  212: 'open',
#  213: 'shut',
#  214: 'back',
#  215: 'good',
#  216: 'cold.',
#  217: 'sick.',
#  218: 'terrific!',
#  219: 'forget',
#  220: 'said',
#  221: 'tough.',
#  222: 'read',
#  223: 'ready?',
#  224: 'loved',
#  225: 'too.',
#  226: 'tell',
#  227: 'done.',
#  228: 'weak.',
#  229: 'hot.',
#  230: 'go!',
#  231: "who's",
#  232: 'so.',
#  233: 'lost',
#  234: 'no.',
#  235: 'broke.',
#  236: 'bring',
#  237: 'an',
#  238: 'liked',
#  239: "won't",
#  240: 'came',
#  241: 'quit.',
#  242: 'drop',
#  243: 'push',
#  244: 'use',
#  245: 'fast.',
#  246: 'rich.',
#  247: 'run',
#  248: 'walk.',
#  249: 'tired.',
#  250: 'yours.',
#  251: 'hard.',
#  252: 'tight.',
#  253: 'start',
#  254: 'help?',
#  255: 'cut',
#  256: 'moving.',
#  257: 'love?',
#  258: 'please.',
#  259: 'called',
#  260: 'easy!',
#  261: 'swim.',
#  262: 'wake',
#  263: 'off.',
#  264: 'down!',
#  265: 'ahead!',
#  266: 'fine.',
#  267: 'say',
#  268: 'died.',
#  269: 'speak',
#  270: 'seated.',
#  271: 'inside.',
#  272: 'tom?',
#  273: 'sing.',
#  274: 'naked.',
#  275: 'us',
#  276: "she's",
#  277: 'turn',
#  278: 'careful.',
#  279: 'move.',
#  280: 'broke',
#  281: 'hurt.',
#  282: 'awful.',
#  283: 'that?',
#  284: 'shot',
#  285: 'car.',
#  286: 'way!',
#  287: 'fired.',
#  288: 'kill',
#  289: 'lock',
#  290: 'find',
#  291: 'clean.',
#  292: 'pardon',
#  293: 'up?',
#  294: 'ignore',
#  295: 'loves',
#  296: 'took',
#  297: 'does',
#  298: 'door.',
#  299: 'on!',
#  300: 'show',
#  301: 'nonsense!',
#  302: 'lost?',
#  303: 'cry.',
#  304: 'stay.',
#  305: 'right.',
#  306: 'loosen',
#  307: 'careful!',
#  308: 'left',
#  309: 'told',
#  310: "tom'll",
#  311: 'mean.',
#  312: 'yourself.',
#  313: 'son.',
#  314: 'sleep.',
#  315: 'are.',
#  316: 'yours?',
#  317: 'stupid.',
#  318: 'nobody',
#  319: 'slowly.',
#  320: 'true.',
#  321: 'great.',
#  322: 'nothing.',
#  323: 'focused.',
#  324: 'kind.',
#  325: 'shy.',
#  326: 'you!',
#  327: 'ugly.',
#  328: 'hurts.',
#  329: 'after',
#  330: 'in?',
#  331: 'dead.',
#  332: 'of',
#  333: 'step',
#  334: 'well',
#  335: 'serious.',
#  336: 'look.',
#  337: 'trying.',
#  338: 'weird.',
#  339: 'pick',
#  340: 'all.',
#  341: "you've",
#  342: 'merciful.',
#  343: 'fined.',
#  344: 'play',
#  345: 'sure?',
#  346: 'french.',
#  347: 'life',
#  348: 'nuts!',
#  349: 'gun.',
#  350: 'drink',
#  351: 'silly.',
#  352: "they'll",
#  353: 'unbelievable!',
#  354: 'them',
#  355: 'smile.',
#  356: 'thanks.',
#  357: 'tried.',
#  358: 'move',
#  359: 'brave.',
#  360: 'fix',
#  361: 'lost!',
#  362: 'hurry',
#  363: 'sure.',
#  364: 'new.',
#  365: 'came.',
#  366: 'he?',
#  367: 'strong.',
#  368: 'retired.',
#  369: 'woke',
#  370: 'cook.',
#  371: 'alive.',
#  372: 'angry.',
#  373: 'dizzy.',
#  374: 'lying.',
#  375: 'short.',
#  376: 'stuck.',
#  377: 'food.',
#  378: 'eat.',
#  379: 'check',
#  380: 'enjoy',
#  381: 'hurt',
#  382: 'mad?',
#  383: 'busy?',
#  384: 'these.',
#  385: 'ate',
#  386: 'young.',
#  387: 'needed',
#  388: 'saved',
#  389: 'should',
#  390: 'break.',
#  391: 'drink.',
#  392: 'memorize',
#  393: 'date.',
#  394: 'send',
#  395: 'rest.',
#  396: 'rude.',
#  397: 'once.',
#  398: 'everyone',
#  399: 'cruel.',
#  400: 'tie',
#  401: 'shoe.',
#  402: 'cried.',
#  403: 'drive.',
#  404: 'ill.',
#  405: 'join',
#  406: 'brief.',
#  407: 'drive',
#  408: 'pay.',
#  409: 'write',
#  410: 'luck.',
#  411: 'relaxed.',
#  412: 'dying.',
#  413: 'seriously?',
#  414: 'care!',
#  415: 'wonderful!',
#  416: 'forgive',
#  417: 'worry.',
#  418: 'tea.',
#  419: 'check.',
#  420: 'lonely.',
#  421: 'done?',
#  422: 'kidding?',
#  423: 'talk',
#  424: 'time',
#  425: 'new?',
#  426: 'where',
#  427: 'again!',
#  428: 'seat.',
#  429: 'beer.',
#  430: 'needs',
#  431: 'caught',
#  432: 'live',
#  433: 'mary.',
#  434: 'up',
#  435: 'cute.',
#  436: 'lose.',
#  437: 'there?',
#  438: 'alone?',
#  439: 'cat.',
#  440: 'might',
#  441: 'book.',
#  442: 'happy?',
#  443: 'tricked',
#  444: 'only',
#  445: 'run!',
#  446: 'agree.',
#  447: 'lie',
#  448: 'hit',
#  449: 'smiled.',
#  450: 'talked.',
#  451: 'thin.',
#  452: 'some.',
#  453: 'win?',
#  454: 'excuse',
#  455: 'head',
#  456: 'gave',
#  457: "i'd",
#  458: 'armed.',
#  459: 'awake.',
#  460: 'hers.',
#  461: 'ours.',
#  462: 'right?',
#  463: 'met',
#  464: 'last.',
#  465: 'hurry.',
#  466: 'coming.',
#  467: 'normal.',
#  468: 'shaken.',
#  469: 'vote.',
#  470: 'study',
#  471: 'here?',
#  472: 'creative.',
#  473: 'discreet.',
#  474: 'punctual.',
#  475: 'thorough.',
#  476: 'bored.',
#  477: 'upset.',
#  478: 'reading.',
#  479: 'joke.',
#  480: 'many',
#  481: 'tom,',
#  482: 'walk',
#  483: 'anybody',
#  484: 'best.',
#  485: 'way.',
#  486: "wasn't",
#  487: 'thanks',
#  488: 'and',
#  489: 'room.',
#  490: 'were',
#  491: 'outrank',
#  492: 'hi.',
#  493: 'hug',
#  494: 'really?',
#  495: 'sign',
#  496: 'off!',
#  497: 'spoke.',
#  498: 'rested.',
#  499: 'his.',
#  500: 'odd.',
#  501: 'nice',
#  502: 'save',
#  503: 'taste',
#  504: 'catch',
#  505: 'follow',
#  506: 'crashed.',
#  507: 'obey.',
#  508: 'slow',
#  509: 'done!',
#  510: 'wrong?',
#  511: 'around.',
#  512: 'prudent.',
#  513: 'wine.',
#  514: 'work?',
#  515: 'read.',
#  516: 'hear',
#  517: 'not.',
#  518: 'promised.',
#  519: 'remember.',
#  520: 'work',
#  521: 'losing.',
#  522: 'tall?',
#  523: 'safe?',
#  524: 'water.',
#  525: 'sharp.',
#  526: 'age.',
#  527: 'fell',
#  528: 'cash.',
#  529: 'eggs.',
#  530: 'messed',
#  531: 'change.',
#  532: 'dancing.',
#  533: 'driving.',
#  534: 'unlucky.',
#  535: 'working.',
#  536: 'nuts?',
#  537: 'remain',
#  538: 'there',
#  539: 'cold?',
#  540: 'miss',
#  541: 'this?',
#  542: 'confident.',
#  543: 'our',
#  544: 'resist.',
#  545: 'fear',
#  546: 'denied',
#  547: 'likes',
#  548: 'wants',
#  549: 'admire',
#  550: 'key.',
#  551: 'helped',
#  552: 'going',
#  553: 'boss.',
#  554: 'running.',
#  555: 'knows',
#  556: 'exhausted.',
#  557: 'terrible.',
#  558: 'awesome.',
#  559: 'burn',
#  560: 'wet.',
#  561: 'deaf.',
#  562: 'tall.',
#  563: 'works.',
#  564: 'calm',
#  565: 'lie.',
#  566: 'faster.',
#  567: 'fire.',
#  568: "how's",
#  569: 'escaped.',
#  570: 'hope',
#  571: 'call.',
#  572: 'blind.',
#  573: 'dirty.',
#  574: 'fussy.',
#  575: 'ok?',
#  576: 'back!',
#  577: 'thank',
#  578: 'content.',
#  579: 'patient.',
#  580: 'come?',
#  581: 'smart.',
#  582: 'built',
#  583: 'chuckled.',
#  584: 'guess',
#  585: 'yes.',
#  586: 'tried',
#  587: 'twin.',
#  588: 'better.',
#  589: 'sweet.',
#  590: 'problem.',
#  591: 'smell',
#  592: 'aside.',
#  593: 'gone.',
#  594: 'war',
#  595: 'decide.',
#  596: 'friendly.',
#  597: 'ruthless.',
#  598: 'asleep.',
#  599: 'drank',
#  600: 'rice.',
#  601: 'eyes.',
#  602: 'bet.',
#  603: 'sell',
#  604: 'moved.',
#  605: 'excited.',
#  606: 'worried.',
#  607: 'deal.',
#  608: 'list.',
#  609: 'smoke?',
#  610: 'ok,',
#  611: 'think',
#  612: 'twins.',
#  613: 'objective.',
#  614: 'quickly.',
#  615: 'bother.',
#  616: 'kid',
#  617: 'upstairs.',
#  618: 'money.',
#  619: 'myself.',
#  620: 'proof.',
#  621: 'music.',
#  622: 'addicted.',
#  623: 'innocent.',
#  624: 'idea.',
#  625: 'singing.',
#  626: 'ended.',
#  627: 'soon!',
#  628: 'shame',
#  629: 'while.',
#  630: 'guilty.',
#  631: 'scared.',
#  632: 'stoned.',
#  633: 'quit',
#  634: 'tired?',
#  635: 'boy.',
#  636: 'favor.',
#  637: 'gear.',
#  638: 'fed',
#  639: 'plan.',
#  640: 'rescued',
#  641: 'hurts',
#  642: 'enough.',
#  643: 'hide.',
#  644: 'stop!',
#  645: 'hello.',
#  646: 'fell.',
#  647: 'lied.',
#  648: 'paid.',
#  649: 'smoke.',
#  650: 'me,',
#  651: 'pull',
#  652: 'long.',
#  653: 'man.',
#  654: 'nice!',
#  655: 'helped.',
#  656: 'obeyed.',
#  657: 'full.',
#  658: 'glad.',
#  659: 'cute?',
#  660: 'honest.',
#  661: 'bless',
#  662: 'fainted.',
#  663: 'knew',
#  664: 'burned.',
#  665: 'warm.',
#  666: 'that!',
#  667: 'start.',
#  668: 'sing?',
#  669: 'men',
#  670: 'is.',
#  671: 'canceled.',
#  672: 'envy',
#  673: 'fixed',
#  674: 'ran',
#  675: 'sat',
#  676: 'shoot.',
#  677: 'eating.',
#  678: 'famous.',
#  679: 'hungry.',
#  680: 'ruined.',
#  681: 'strict.',
#  682: 'free?',
#  683: 'true?',
#  684: 'close.',
#  685: 'problem!',
#  686: 'bit.',
#  687: 'sec.',
#  688: 'why',
#  689: 'anyone',
#  690: 'cheerful.',
#  691: 'watchful.',
#  692: 'off',
#  693: 'speak.',
#  694: 'changed.',
#  695: 'box.',
#  696: 'home',
#  697: 'helps',
#  698: 'dance.',
#  699: 'share.',
#  700: 'blue.',
#  701: 'dumb.',
#  702: 'dogs.',
#  703: 'kids.',
#  704: 'cake.',
#  705: 'soup.',
#  706: 'pay',
#  707: 'recovered.',
#  708: 'still',
#  709: 'succeeded.',
#  710: 'manage.',
#  711: 'baffled.',
#  712: 'curious.',
#  713: 'love.',
#  714: 'married.',
#  715: 'duty.',
#  716: 'starved.',
#  717: 'trapped.',
#  718: 'writing.',
#  719: 'fake.',
#  720: 'timing.',
#  721: 'put',
#  722: 'remember',
#  723: 'crying.',
#  724: 'bath.',
#  725: 'bite.',
#  726: 'icky.',
#  727: 'nuts.',
#  728: 'vote',
#  729: 'car',
#  730: 'now?',
#  731: 'swim?',
#  732: 'gun!',
#  733: 'doctor.',
#  734: 'hand.',
#  735: 'believe',
#  736: 'faint.',
#  737: 'giddy.',
#  738: 'caught.',
#  739: 'handled',
#  740: 'plans.',
#  741: 'why.',
#  742: 'fighting.',
#  743: 'finished.',
#  744: 'positive.',
#  745: 'fake?',
#  746: 'smiling.',
#  747: 'guess.',
#  748: 'closely.',
#  749: 'recess',
#  750: 'set',
#  751: 'stir',
#  752: 'command.',
#  753: 'hates',
#  754: 'meant',
#  755: 'welcome',
#  756: 'respectful.',
#  757: 'check,',
#  758: 'some',
#  759: 'girls',
#  760: 'god',
#  761: 'touched',
#  762: 'hiking.',
#  763: 'nearby.',
#  764: 'looked',
#  765: 'wanted',
#  766: 'works',
#  767: 'bragging.',
#  768: 'begin.',
#  769: 'won!',
#  770: 'shoot!',
#  771: 'attack!',
#  772: 'cheers!',
#  773: 'pass.',
#  774: 'listen.',
#  775: 'bury',
#  776: 'fold',
#  777: 'slow.',
#  778: 'hire',
#  779: 'stink.',
#  780: 'aim',
#  781: 'high.',
#  782: 'cover',
#  783: 'job!',
#  784: 'failed.',
#  785: 'forgot.',
#  786: 'goofed.',
#  787: 'refuse.',
#  788: 'red.',
#  789: 'knew.',
#  790: 'touch',
#  791: 'i?',
#  792: 'choose',
#  793: 'soon.',
#  794: 'dogs',
#  795: 'beg',
#  796: 'ski.',
#  797: 'cheated.',
#  798: 'cringed.',
#  799: 'giggled.',
#  800: 'hurried.',
#  801: 'loyal.',
#  802: 'stinks.',
#  803: 'worked.',
#  804: 'jump',
#  805: 'seize',
#  806: 'him!',
#  807: 'swam.',
#  808: 'voted.',
#  809: 'agreed.',
#  810: 'along.',
#  811: 'destroy',
#  812: 'fret.',
#  813: 'push.',
#  814: 'rush.',
#  815: 'flinched.',
#  816: 'screamed.',
#  817: 'squinted.',
#  818: 'wrote',
#  819: 'hero.',
#  820: 'buying.',
#  821: 'chubby.',
#  822: 'direct.',
#  823: 'loaded.',
#  824: 'skinny.',
#  825: 'sneaky.',
#  826: 'unwell.',
#  827: 'wasted.',
#  828: 'happens.',
#  829: 'fox.',
#  830: 'lighten',
#  831: 'alert.',
#  832: 'mind!',
#  833: 'oh,',
#  834: 'replace',
#  835: 'sing',
#  836: 'bus.',
#  837: 'cheat.',
#  838: 'flies.',
#  839: 'winced.',
#  840: 'harder.',
#  841: 'sick?',
#  842: 'anybody.',
#  843: 'clean',
#  844: 'argue.',
#  845: 'fight.',
#  846: 'leave!',
#  847: 'finish',
#  848: 'stood',
#  849: 'burned',
#  850: 'say.',
#  851: 'fruit.',
#  852: 'fired',
#  853: 'pigs.',
#  854: 'both.',
#  855: 'struggled.',
#  856: 'nervous.',
#  857: 'fool.',
#  858: 'stunned.',
#  859: 'talking.',
#  860: 'legal?',
#  861: 'broken.',
#  862: 'silent.',
#  863: 'means',
#  864: 'card.',
#  865: 'grow.',
#  866: 'shake',
#  867: 'shall',
#  868: 'still!',
#  869: 'by.',
#  870: 'refused.',
#  871: 'says',
#  872: 'meat.',
#  873: 'deaf?',
#  874: 'lame?',
#  875: 'attentive.',
#  876: 'quickly!',
#  877: 'know?',
#  878: 'drink?',
#  879: 'empty',
#  880: 'rifle.',
#  881: 'hand',
#  882: 'bigot.',
#  883: 'pen.',
#  884: 'always',
#  885: 'apologized.',
#  886: 'dumped.',
#  887: 'kid.',
#  888: 'hugged',
#  889: 'books.',
#  890: 'missed',
#  891: 'map.',
#  892: 'started',
#  893: 'robbed.',
#  894: 'warned.',
#  895: 'twice.',
#  896: 'sue',
#  897: 'farmer.',
#  898: 'divorced.',
#  899: 'saint.',
#  900: 'stubborn.',
#  901: 'crazy?',
#  902: 'small.',
#  903: 'obvious.',
#  904: 'digging.',
#  905: 'listen',
#  906: 'mary',
#  907: 'quietly.',
#  908: 'eyes',
#  909: 'sued',
#  910: 'arguing.',
#  911: 'pushing.',
#  912: 'yelling!',
#  913: 'control.',
#  914: "that'll",
#  915: 'stole',
#  916: 'pale.',
#  917: 'up,',
#  918: 'hope.',
#  919: 'overslept.',
#  920: 'sent',
#  921: 'wish',
#  922: 'any',
#  923: 'angry?',
#  924: 'supportive.',
#  925: 'go,',
#  926: 'pitch?',
#  927: 'close',
#  928: 'fly',
#  929: 'kite.',
#  930: 'ignored',
#  931: 'freaked',
#  932: 'clue.',
#  933: 'coffee.',
#  934: 'winter.',
#  935: 'cancer.',
#  936: 'movies.',
#  937: 'skiing.',
#  938: 'dinner.',
#  939: 'object.',
#  940: 'ought',
#  941: 'surrendered.',
#  942: 'trusted',
#  943: 'stabbed.',
#  944: 'busy,',
#  945: 'depressed.',
#  946: 'forgetful.',
#  947: 'observant.',
#  948: 'leak.',
#  949: 'takes',
#  950: 'treat.',
#  951: 'outdated.',
#  952: 'minute.',
#  953: 'climbing.',
#  954: "one's",
#  955: 'number.',
#  956: 'clearly.',
#  957: 'moment.',
#  958: 'cup',
#  959: 'till',
#  960: 'six.',
#  961: 'wow!',
#  962: 'duck!',
#  963: 'jump!',
#  964: 'wait!',
#  965: 'awesome!',
#  966: 'goodbye!',
#  967: 'goodbye.',
#  968: 'snore.',
#  969: 'kiss',
#  970: 'low.',
#  971: 'perfect!',
#  972: 'fat?',
#  973: 'cool',
#  974: 'tries.',
#  975: 'cute!',
#  976: 'looked.',
#  977: 'stayed.',
#  978: 'bald.',
#  979: 'okay.',
#  980: 'prove',
#  981: 'warn',
#  982: 'for?',
#  983: 'answer',
#  984: 'fly.',
#  985: 'ask.',
#  986: 'fantastic!',
#  987: 'west.',
#  988: 'exhaled.',
#  989: 'grinned.',
#  990: 'pack.',
#  991: 'sober.',
#  992: 'hot?',
#  993: 'open.',
#  994: 'sand.',
#  995: 'course!',
#  996: 'rest',
#  997: '"aah."',
#  998: 'knows.',
#  999: 'yawned.',
#  1000: 'cares?',
#  ...}

# %%
reverse_fra_tokens
# Out:
# {1: '<sos>',
#  2: '<eos>',
#  3: 'je',
#  4: '!',
#  5: 'tom',
#  6: 'suis',
#  7: '?',
#  8: "c'est",
#  9: 'est',
#  10: 'nous',
#  11: 'de',
#  12: 'il',
#  13: "j'ai",
#  14: 'ne',
#  15: 'pas',
#  16: 'le',
#  17: 'vous',
#  18: 'à',
#  19: 'me',
#  20: 'la',
#  21: 'a',
#  22: 'un',
#  23: 'en',
#  24: 'tu',
#  25: 'les',
#  26: 'tom.',
#  27: 'ça',
#  28: 'une',
#  29: 'est-ce',
#  30: 'sont',
#  31: 'ils',
#  32: 'qui',
#  33: 'que',
#  34: 'soyez',
#  35: 'fait',
#  36: 'pas.',
#  37: 'sommes',
#  38: 'êtes',
#  39: 'elles',
#  40: 'du',
#  41: 'elle',
#  42: 'va',
#  43: 'des',
#  44: 'ça.',
#  45: 'te',
#  46: 'sois',
#  47: 'été',
#  48: 'es',
#  49: 'ce',
#  50: 'faut',
#  51: 'y',
#  52: 'êtes-vous',
#  53: 'fais',
#  54: 'bien.',
#  55: 'on',
#  56: 'ai',
#  57: 'se',
#  58: 'tout',
#  59: 'restez',
#  60: "m'a",
#  61: 'besoin',
#  62: "l'ai",
#  63: "j'aime",
#  64: 'reste',
#  65: 'était',
#  66: 'peux',
#  67: 'avons',
#  68: "n'est",
#  69: "j'étais",
#  70: 'mon',
#  71: "s'est",
#  72: "c'était",
#  73: 'au',
#  74: 'sens',
#  75: 'es-tu',
#  76: 'bien',
#  77: 'moi.',
#  78: 'ont',
#  79: 'aller.',
#  80: 'partir.',
#  81: 'ici.',
#  82: 'prends',
#  83: 'faites',
#  84: 'veux',
#  85: 'arrête',
#  86: 'j’ai',
#  87: 'vais',
#  88: "j'en",
#  89: 'train',
#  90: 'chez',
#  91: 'est-il',
#  92: "s'il",
#  93: 'prenez',
#  94: "m'en",
#  95: 'arrêtez',
#  96: "l'a",
#  97: 'personne',
#  98: 'mal.',
#  99: 'dois',
#  100: "j'adore",
#  101: 'avec',
#  102: 'cela',
#  103: "l'air",
#  104: 'trop',
#  105: 'moi',
#  106: 'comme',
#  107: 'suis-je',
#  108: 'triste.',
#  109: 'ton',
#  110: 'quelle',
#  111: 'toi.',
#  112: 'ma',
#  113: 'plaît.',
#  114: 'calme.',
#  115: 'ceci.',
#  116: 'comment',
#  117: 'as',
#  118: 'très',
#  119: "d'un",
#  120: 'maintenant.',
#  121: 'là.',
#  122: 'allez',
#  123: 'plus',
#  124: 'continuez',
#  125: 'laissez-moi',
#  126: 'viens',
#  127: 'votre',
#  128: 'laisse',
#  129: 'puis-je',
#  130: 'aller',
#  131: 'laisse-moi',
#  132: 'pour',
#  133: 'faire',
#  134: 'déteste',
#  135: 'cela.',
#  136: 'perdu.',
#  137: 'maison.',
#  138: 'vous.',
#  139: 'continue',
#  140: 'venez',
#  141: 'quel',
#  142: 'dans',
#  143: 'bon.',
#  144: 'malade.',
#  145: 'sais',
#  146: 'eu',
#  147: 'monde',
#  148: 'voir.',
#  149: 'tellement',
#  150: "n'ai",
#  151: 'avez',
#  152: "j'y",
#  153: 'regarde',
#  154: 'ici',
#  155: 'dit',
#  156: 'seul.',
#  157: "s'agit",
#  158: 'tranquille.',
#  159: 'bon',
#  160: 'demande',
#  161: 'fou.',
#  162: 'nous.',
#  163: 'vu.',
#  164: 'regardez',
#  165: 'mal',
#  166: "d'une",
#  167: 'juste',
#  168: 'pris',
#  169: 'faire.',
#  170: 'sécurité.',
#  171: 'c’est',
#  172: "qu'est-ce",
#  173: 'lui.',
#  174: "t'es",
#  175: 'pouvons',
#  176: 'a-t-il',
#  177: 'gagné.',
#  178: "n'en",
#  179: 'courir.',
#  180: "t'ai",
#  181: 'attends',
#  182: 'debout.',
#  183: 'laissez',
#  184: 'coup',
#  185: 'yeux.',
#  186: 'chaud.',
#  187: 'attention.',
#  188: 'parle',
#  189: 'une.',
#  190: 'un.',
#  191: 'lui',
#  192: 'sur',
#  193: 'sans',
#  194: 'tomber.',
#  195: 'fait.',
#  196: 'occupé.',
#  197: 'bizarre.',
#  198: 'confiance',
#  199: 'vite.',
#  200: 'parler.',
#  201: 'senti',
#  202: 'temps.',
#  203: 'maintenant',
#  204: 'bouge',
#  205: 'pars',
#  206: 'chercher',
#  207: 'si',
#  208: 'porte',
#  209: 'bonne',
#  210: 'vois',
#  211: 'là',
#  212: 'grand.',
#  213: 'peut',
#  214: 'mourir.',
#  215: 'heureux.',
#  216: 'travail.',
#  217: 'dispose',
#  218: 'chien.',
#  219: "j'irai",
#  220: 'pourrait',
#  221: 'dessus.',
#  222: 'essayer.',
#  223: 'nouveau.',
#  224: 'quoi',
#  225: 'mort.',
#  226: 'essaie',
#  227: "d'accord.",
#  228: 'perdu',
#  229: 'ai-je',
#  230: "s'en",
#  231: 'mange',
#  232: 'terminé.',
#  233: 'attendez',
#  234: 'merci',
#  235: 'vrai',
#  236: 'dis',
#  237: 'voir',
#  238: 'froid.',
#  239: 'retard.',
#  240: 'faible.',
#  241: 'confiance.',
#  242: 'ceci',
#  243: 'prie.',
#  244: 'toi',
#  245: 'chance.',
#  246: 'non.',
#  247: 'vu',
#  248: 'as-tu',
#  249: 'pouvez',
#  250: 'vos',
#  251: 'parti.',
#  252: 'gentil.',
#  253: 'où',
#  254: 'gros.',
#  255: 'colère.',
#  256: 'maison',
#  257: 'pouvons-nous',
#  258: 'mien.',
#  259: 'boulot.',
#  260: "l'aide.",
#  261: 'vie',
#  262: "j'apprécie",
#  263: 'mieux.',
#  264: 'fais-le',
#  265: 'davantage.',
#  266: 'fils.',
#  267: 'sait',
#  268: 'serai',
#  269: 'sympa.',
#  270: 'tous',
#  271: 'par',
#  272: 'vraiment',
#  273: 'allons',
#  274: 'plus.',
#  275: 'riche.',
#  276: 'sûr.',
#  277: 'marrant.',
#  278: "m'y",
#  279: 'essayez',
#  280: 'lit',
#  281: 'mis',
#  282: 'vue.',
#  283: 'prêt.',
#  284: 'mauvais.',
#  285: 'temps',
#  286: "n'y",
#  287: 'encore.',
#  288: 'chanter.',
#  289: 'sentis',
#  290: 'thé.',
#  291: "l'amour",
#  292: 'simplement',
#  293: 'rien.',
#  294: 'nouveau',
#  295: 'sommes-nous',
#  296: "t'en",
#  297: 'beaucoup.',
#  298: 'gagné',
#  299: 'tiens',
#  300: 'essayé.',
#  301: 'timide.',
#  302: 'fini.',
#  303: 'juste.',
#  304: 'paresseux.',
#  305: 'tard.',
#  306: 'avance.',
#  307: 'cool.',
#  308: 'venir.',
#  309: 'nager.',
#  310: 'devenu',
#  311: 'blessé.',
#  312: 'blessé',
#  313: 'grand',
#  314: 'entrer',
#  315: 'tous.',
#  316: 'gagner.',
#  317: "j'avais",
#  318: 'dehors.',
#  319: 'arme',
#  320: 'avait',
#  321: 'voiture.',
#  322: 'dormir.',
#  323: 'idée.',
#  324: 'facile.',
#  325: 'vrai.',
#  326: 'route',
#  327: 'non',
#  328: 'tes',
#  329: 'aucune',
#  330: 'décampe',
#  331: 'pleuré.',
#  332: 'avance',
#  333: 'trouve',
#  334: 'attrape',
#  335: 'main',
#  336: 'occupée.',
#  337: 'prudente',
#  338: 'partir',
#  339: 'joue',
#  340: 'vieux.',
#  341: 'voilà',
#  342: 'avoir',
#  343: 'besoin.',
#  344: 'vus.',
#  345: 'mes',
#  346: 'rester.',
#  347: 'seule.',
#  348: 'premier.',
#  349: 'dur.',
#  350: 'mienne.',
#  351: 'garde',
#  352: 'entrer.',
#  353: 'vas',
#  354: 'venir',
#  355: 'tranquille',
#  356: 'lire.',
#  357: 'marcher.',
#  358: 'tiré',
#  359: "l'intérieur.",
#  360: 'perdre.',
#  361: 'horrible.',
#  362: 'drôle.',
#  363: 'encore',
#  364: 'était-il',
#  365: 'heureuse.',
#  366: 'aux',
#  367: 'danser.',
#  368: 'idiot.',
#  369: 'jamais.',
#  370: 'tort.',
#  371: 'français.',
#  372: 'veuillez',
#  373: "n'a",
#  374: 'marche',
#  375: "quelqu'un",
#  376: 'sont-ils',
#  377: 'livre.',
#  378: 'menti.',
#  379: 'ans.',
#  380: 'ah',
#  381: "l'avons",
#  382: 'camp.',
#  383: 'tomber',
#  384: 'laisse-le',
#  385: 'vers',
#  386: 'promis.',
#  387: 'sait.',
#  388: 'haut.',
#  389: 'souri.',
#  390: 'grande.',
#  391: 'attention',
#  392: 'fort',
#  393: 'reviens',
#  394: 'sérieux.',
#  395: 'vues.',
#  396: 'travailler.',
#  397: 'vie.',
#  398: 'tête',
#  399: 'saoul.',
#  400: 'prête',
#  401: 'prêt',
#  402: 'et',
#  403: 'gardez',
#  404: 'lis',
#  405: 'bouger.',
#  406: 'assis.',
#  407: 'soin',
#  408: 'malade',
#  409: 'demandez',
#  410: 'manger.',
#  411: 'tôt.',
#  412: 'attendre.',
#  413: 'sentie',
#  414: 'préparé',
#  415: 'bonne.',
#  416: 'faim',
#  417: 'fou',
#  418: 'toutes.',
#  419: 'devons',
#  420: 'aider.',
#  421: 'avez-vous',
#  422: 'chercher.',
#  423: 'jeune.',
#  424: 'également',
#  425: 'bière.',
#  426: 'beaucoup',
#  427: 'veut',
#  428: 'donné',
#  429: 'seulement',
#  430: 'marche.',
#  431: 'bonjour.',
#  432: 'blague',
#  433: 'calme',
#  434: 'dégage\u202f!',
#  435: 'camp',
#  436: 'fiche',
#  437: 'déguerpissez.',
#  438: 'sors',
#  439: 'décampez',
#  440: 'cassez-vous.',
#  441: 'pue.',
#  442: 'ferme',
#  443: 'tiens-toi',
#  444: 'appelle',
#  445: 'attrapez',
#  446: 'parlé.',
#  447: 'mignon',
#  448: 'tête.',
#  449: 'rapide.',
#  450: 'attention\u202f!',
#  451: "n'importe",
#  452: 'parlez',
#  453: 'super.',
#  454: 'essaye',
#  455: 'faites-le',
#  456: 'voici.',
#  457: 'skier.',
#  458: 'chat.',
#  459: 'aveugle.',
#  460: 'difficile.',
#  461: 'nu.',
#  462: 'nourriture.',
#  463: "l'écart.",
#  464: 'vin.',
#  465: "l'extérieur.",
#  466: 'plaisir.',
#  467: 'connais',
#  468: 'deux.',
#  469: 'vérifier.',
#  470: 'payer.',
#  471: 'fort.',
#  472: "l'amour\u202f?",
#  473: 'faux.',
#  474: 'plaît',
#  475: 'seconde',
#  476: 'sécurité',
#  477: 'peut-il',
#  478: 'prie',
#  479: 'deux',
#  480: 'œufs.',
#  481: "qu'il",
#  482: 'avais',
#  483: 'naïf.',
#  484: 'prête.',
#  485: 'travaille',
#  486: 'blague.',
#  487: 'marcher',
#  488: "l'ont",
#  489: 'tom,',
#  490: 'connaît.',
#  491: 'voiture',
#  492: 'prends-en',
#  493: 'stupide.',
#  494: 'arme.',
#  495: 'plan.',
#  496: 'toutes',
#  497: "s'agit-il",
#  498: 'fut',
#  499: 'vient',
#  500: 'flics',
#  501: 'emporté',
#  502: 'serre-moi',
#  503: 'aucun',
#  504: 'merci.',
#  505: 'essaie.',
#  506: "d'ici.",
#  507: 'laissez-le',
#  508: 'peu',
#  509: 'tenez',
#  510: 'quitte',
#  511: 'pied.',
#  512: 'aussi.',
#  513: 'passe',
#  514: 'brève.',
#  515: 'libre.',
#  516: 'certain.',
#  517: 'jamais',
#  518: 'assieds-toi',
#  519: 'venu.',
#  520: 'fais-moi',
#  521: 'après',
#  522: 'pleure',
#  523: 'oubliez',
#  524: 'va-t-il',
#  525: 'réussi.',
#  526: 'retraite.',
#  527: 'réveillé.',
#  528: 'ferai',
#  529: 'propre.',
#  530: 'dure.',
#  531: 'marché.',
#  532: 'simple.',
#  533: 'assise.',
#  534: 'prudent.',
#  535: 'prudente.',
#  536: 'main.',
#  537: 'prudent',
#  538: 'apporte',
#  539: 'pousse',
#  540: 'chante',
#  541: 'tenez-vous',
#  542: 'cassé.',
#  543: 'cuisiner.',
#  544: 'vieille.',
#  545: 'trouvé.',
#  546: 'fus',
#  547: 'normal.',
#  548: 'sûr',
#  549: 'passé.',
#  550: 'silencieux.',
#  551: 'sortir.',
#  552: 'rien',
#  553: 'fois.',
#  554: 'vite',
#  555: 'dites',
#  556: 'méchant.',
#  557: 'retour.',
#  558: "qu'est",
#  559: 'soit',
#  560: 'aider',
#  561: 'sais-tu',
#  562: 'pouvez-vous',
#  563: 'jetez',
#  564: 'âge.',
#  565: 'peur.',
#  566: 'licencié.',
#  567: 'riz.',
#  568: 'liquide.',
#  569: 'crédule.',
#  570: 'naïve.',
#  571: 'service.',
#  572: 'gagne.',
#  573: 'fini',
#  574: 'faisons',
#  575: 'mille',
#  576: 'maintenant,',
#  577: 'arrêter.',
#  578: 'lentement.',
#  579: 'eu.',
#  580: 'thomas',
#  581: 'doucement.',
#  582: 'froid',
#  583: 'voulons',
#  584: 'sont-elles',
#  585: 'nager',
#  586: 'resté',
#  587: "l'école",
#  588: 'laissé',
#  589: 'laissa',
#  590: 'filles',
#  591: 'appelé.',
#  592: 'fis',
#  593: 'bois',
#  594: 'prendre.',
#  595: 'musique.',
#  596: 'vis',
#  597: 'notre',
#  598: 'dingue.',
#  599: 'cruel.',
#  600: 'coupable.',
#  601: 'porte.',
#  602: 'ouvre',
#  603: 'chaussure.',
#  604: 'jambes',
#  605: 'arrête-toi',
#  606: 'attendez.',
#  607: 'calmez-vous',
#  608: 'allez-y',
#  609: 'vas-y',
#  610: 'serrez-moi',
#  611: 'va.',
#  612: 'remercie.',
#  613: 'essaye.',
#  614: 'emporté.',
#  615: 'génial.',
#  616: 'sincère.',
#  617: 'gentil',
#  618: 'casse-toi.',
#  619: 'disparais',
#  620: 'sors.',
#  621: 'doucement',
#  622: 'court.',
#  623: 'bougez',
#  624: 'folle.',
#  625: 'malheureux.',
#  626: 'bref.',
#  627: 'beau',
#  628: 'sorti.',
#  629: 'l’ai',
#  630: 'content.',
#  631: 'paresseuse.',
#  632: 'mince.',
#  633: 'sien.',
#  634: 'sienne.',
#  635: 'allons-y',
#  636: 'asseyez-vous',
#  637: 'faites-moi',
#  638: 'est-il\u202f?',
#  639: 'revenez',
#  640: 'avant.',
#  641: 'sexy.',
#  642: 'ricané.',
#  643: 'parti',
#  644: 'partie',
#  645: 'veux.',
#  646: 'tourne.',
#  647: 'mentir.',
#  648: 'brûlé.',
#  649: 'nôtre.',
#  650: 'partir\u202f!',
#  651: 'derrière',
#  652: '«',
#  653: 'assis',
#  654: 'commencez',
#  655: 'commence',
#  656: 'problème.',
#  657: 'conduis',
#  658: 'quiconque',
#  659: 'seul',
#  660: 'hommes',
#  661: 'poussez',
#  662: 'sentais',
#  663: 'déteste.',
#  664: 'connais.',
#  665: 'aimé',
#  666: 'héros.',
#  667: "l'eau.",
#  668: 'proximité.',
#  669: 'tout.',
#  670: 'amusant.',
#  671: 'voyait.',
#  672: 'perdus.',
#  673: 'riches.',
#  674: 'était-ce',
#  675: 'pourquoi',
#  676: 'appelé',
#  677: "m'as",
#  678: 'folle',
#  679: 'donner',
#  680: 'essayé',
#  681: 'boîte.',
#  682: 'place.',
#  683: 'endormi.',
#  684: 'demandé',
#  685: 'pourrais',
#  686: 'vertiges.',
#  687: 'chiens.',
#  688: 'enfants.',
#  689: 'sauvé.',
#  690: 'sauvée.',
#  691: 'sauvés.',
#  692: 'vends',
#  693: 'viré.',
#  694: 'fatigué.',
#  695: 'fatiguée.',
#  696: 'allé',
#  697: 'honte.',
#  698: 'minable.',
#  699: 'plaît,',
#  700: 'carte.',
#  701: 'exact.',
#  702: 'eue.',
#  703: 'peuvent',
#  704: 'reposer.',
#  705: 'lentement',
#  706: 'chien',
#  707: 'deviens',
#  708: 'peux-tu',
#  709: 'donne-moi',
#  710: 'laissés',
#  711: 'laissées',
#  712: 'aime',
#  713: 'clé.',
#  714: 'pourquoi.',
#  715: 'faim.',
#  716: 'près',
#  717: 'yeux',
#  718: 'terminée.',
#  719: 'sentait',
#  720: 'là-bas.',
#  721: 'marie.',
#  722: 'apeuré.',
#  723: 'dieu',
#  724: 'dû',
#  725: 'fallait',
#  726: 'résister.',
#  727: 'vanter.',
#  728: 'salut',
#  729: 'file',
#  730: 'cours',
#  731: 'feu',
#  732: 'calme-toi.',
#  733: 'calme\u202f!',
#  734: 'détends-toi',
#  735: 'tire',
#  736: 'tirez',
#  737: 'pardon',
#  738: 'bras',
#  739: 'sais.',
#  740: 'partis.',
#  741: 'hors',
#  742: 'vraiment\u202f?',
#  743: 'sensass',
#  744: 'honnête.',
#  745: 'entre.',
#  746: 'rentre',
#  747: 'ciao.',
#  748: 'aide-moi',
#  749: 'quittez',
#  750: 'accroche-toi',
#  751: 'mouillé.',
#  752: 'autre',
#  753: 'bientôt',
#  754: 'fûmes',
#  755: 'gros',
#  756: 'avancez',
#  757: 'rouler',
#  758: 'trouvez',
#  759: 'descends.',
#  760: 'vas-y.',
#  761: 'bravo',
#  762: 'échoué.',
#  763: 'compris.',
#  764: 'regardé.',
#  765: 'signe',
#  766: 'obéi.',
#  767: 'paie.',
#  768: 'détendu.',
#  769: 'détendue.',
#  770: 'sourd.',
#  771: 'libre',
#  772: 'disponible.',
#  773: 'perdue.',
#  774: 'laid.',
#  775: 'aide.',
#  776: 'morte.',
#  777: 'venu',
#  778: 'chiens',
#  779: 'pardon\u202f?',
#  780: 'oublie',
#  781: 'boulot',
#  782: 'route.',
#  783: 'cessez',
#  784: 'tenez.',
#  785: 'bizarre',
#  786: 'rentré',
#  787: 'donne',
#  788: 'dit.',
#  789: 'vis.',
#  790: 'vois.',
#  791: 'vivant.',
#  792: 'sale.',
#  793: 'ivre.',
#  794: 'nue.',
#  795: 'poil.',
#  796: 'raison.',
#  797: 'désolé.',
#  798: 'heures',
#  799: 'gratuit.',
#  800: 'ainsi',
#  801: 'immobile',
#  802: 'toi\u202f!',
#  803: 'baissé.',
#  804: 'miens.',
#  805: 'miennes.',
#  806: 'cuisine.',
#  807: 'voté.',
#  808: 'réussi\u202f!',
#  809: 'est-ce\u202f?',
#  810: 'parlé',
#  811: 'toi,',
#  812: 'raison',
#  813: 'tort',
#  814: 'vigilant',
#  815: 'patient.',
#  816: 'vérifie',
#  817: 'pas\xa0!',
#  818: 'cédé.',
#  819: 'voilà.',
#  820: 'annulé.',
#  821: 'suppose.',
#  822: "l'aime",
#  823: "t'aime",
#  824: 'rappelle.',
#  825: 'oui.',
#  826: 'envie',
#  827: "n'étais",
#  828: 'dernier.',
#  829: 'arrive.',
#  830: 'fonctionnera.',
#  831: 'nuit.',
#  832: 'mignon.',
#  833: 'vôtre.',
#  834: 'sortir',
#  835: "d'essayer.",
#  836: 'gentille.',
#  837: 'étudie',
#  838: 'étudiez',
#  839: 'bus.',
#  840: 'garçon',
#  841: 'elle.',
#  842: "l'heure",
#  843: 'pleurer.',
#  844: 'peu.',
#  845: "t'avons",
#  846: 'faibles.',
#  847: 'coup.',
#  848: 'terminé',
#  849: 'prêts',
#  850: 'prêtes',
#  851: 'attendre',
#  852: 'savez-vous',
#  853: 'aidé',
#  854: 'nouveau\u202f!',
#  855: 'discuter.',
#  856: 'partez',
#  857: 'jette',
#  858: 'œil',
#  859: 'aime.',
#  860: 'levé.',
#  861: 'parviens',
#  862: 'attrapé.',
#  863: 'attrapée.',
#  864: 'idiote.',
#  865: 'entendu',
#  866: 'mary.',
#  867: 'aimé.',
#  868: 'devrais',
#  869: 'conduire.',
#  870: 'marié.',
#  871: 'égoïste.',
#  872: 'faisait',
#  873: 'marché',
#  874: 'entrer\u202f?',
#  875: 'dire',
#  876: 'devrais-je',
#  877: 'prendre',
#  878: "m'ont",
#  879: 'largué.',
#  880: 'refusé.',
#  881: 'âgé.',
#  882: 'savons',
#  883: 'jumeaux.',
#  884: "t'a",
#  885: 'immédiatement.',
#  886: 'crainte.',
#  887: 'donnez-moi',
#  888: "l'école.",
#  889: 'horreur',
#  890: 'mangé',
#  891: 'crois.',
#  892: 'réparer.',
#  893: 'égal.',
#  894: 'affreusement',
#  895: 'feu.',
#  896: 'ceux-ci.',
#  897: 'pari.',
#  898: 'livres.',
#  899: 'taxi.',
#  900: 'justice.',
#  901: 'procès.',
#  902: "n'était",
#  903: 'incroyable.',
#  904: 'défaut.',
#  905: 'demander',
#  906: 'creuser.',
#  907: 'concentré.',
#  908: 'concentrée.',
#  909: 'regarder',
#  910: 'sourire.',
#  911: 'écrire.',
#  912: "d'abord.",
#  913: 'verre,',
#  914: 'pause',
#  915: 'finie.',
#  916: 'honte',
#  917: 'moment',
#  918: 'pousser.',
#  919: 'hurler',
#  920: 'commandes.',
#  921: "t'ont",
#  922: 'vont',
#  923: 'gâteau.',
#  924: 'pourrions',
#  925: 'chef.',
#  926: 'femme.',
#  927: 'solidaire.',
#  928: 'fermez',
#  929: 'bouchon',
#  930: 'mangez',
#  931: 'donnez-la-moi.',
#  932: 'bénisse',
#  933: 'trompé.',
#  934: 'acheter',
#  935: 'trouvé',
#  936: "n'avais",
#  937: 'fallu',
#  938: 'café.',
#  939: "l'hiver.",
#  940: 'cancer.',
#  941: 'liste.',
#  942: 'manque.',
#  943: 'objection.',
#  944: 'chambre.',
#  945: 'ses',
#  946: "n'est-ce",
#  947: "qu'un.",
#  948: "qu'une.",
#  949: 'prenez-en',
#  950: 'verrouille',
#  951: 'lacet.',
#  952: 'lacet',
#  953: "jusqu'à",
#  954: 'heures.',
#  955: 'cous',
#  956: 'filez',
#  957: 'saute.',
#  958: 'commencez.',
#  959: 'bonjour',
#  960: 'détends-toi\u202f!',
#  961: 'détendez-vous\u202f!',
#  962: 'relaxe',
#  963: 'santé',
#  964: 'tombée.',
#  965: 'tombé.',
#  966: 'partie.',
#  967: 'payé.',
#  968: 'possible\u202f!',
#  969: 'question',
#  970: 'fantastique\u202f!',
#  971: 'honnêtes.',
#  972: 'fous',
#  973: 'va-t’en\xa0!',
#  974: 'oust',
#  975: 'dégage.',
#  976: 'allez\u202f!',
#  977: 'allez,',
#  978: 'sortez',
#  979: 'dégage',
#  980: 'fichez',
#  981: 'sortez.',
#  982: 'conduis.',
#  983: 'tenue',
#  984: 'tenté.',
#  985: 'signe.',
#  986: "j'irai.",
#  987: 'gras.',
#  988: 'terre',
#  989: 'sol',
#  990: 'chose.',
#  991: 'grave.',
#  992: 'prenez-le.',
#  993: 'prends-le.',
#  994: 'bienvenu',
#  995: 'recule\u2009!',
#  996: 'reculez.',
#  997: 'appelez',
#  998: 'répare',
#  999: 'pars.',
#  1000: 'poursuis',
#  ...}

# %%
print(f"{len(reverse_eng_tokens)} :: {len(reverse_fra_tokens)}")
# Out:
# 2706 :: 5571

# %%
target_word_index = fra_tok.word_index

# %%
len(target_word_index)
# Out:
# 5805

# %% [markdown]
# ### encoders

# %%
enc_model = Model(enc_inputs, [enc_outputs, state_h, state_c])

# %% [markdown]
# ### decoders

# %%
decoder_state_input_h = Input(shape = (latent_dim, ))
decoder_state_input_c = Input(shape = (latent_dim, ))
encoder_outputs_inputs = Input(shape = (max_eng_word, latent_dim))
decoder_input_single = Input(shape = (1, ))
decoder_emb_2 = dec_emb_layer(decoder_input_single)
context_vector, attention_weights = attention(decoder_state_input_h, encoder_outputs_inputs)
X = Concatenate(axis = -1)([tensorflow.expand_dims(context_vector, 1), decoder_emb_2])
decoder_outputs, state_h_inf, state_c_inf = dec_lstm(X, initial_state = [decoder_state_input_h, decoder_state_input_c])
decoder_outputs = Dense(fra_vocabs, activation = 'softmax')(decoder_outputs)

dec_model = Model(
    [decoder_input_single, decoder_state_input_h, decoder_state_input_c, encoder_outputs_inputs],
    [decoder_outputs, state_h_inf, state_c_inf, attention_weights]
)

# %% [markdown]
# ### final decode sequence function

# %%
def decode_sequence(input_seq) : 
    enc_outs, state_h, state_c = enc_model.predict(input_seq)

    target_seq = np.array([[fra_tok.word_index['<sos>']]])
    
    stop_condition = False
    decode_sentence = []

    while not stop_condition :
        output_tokens, h, c, attn = dec_model.predict([target_seq, state_h, state_c, enc_outs])

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = reverse_fra_tokens.get(sampled_token_index, '')

        if (sampled_word == '<eos>' or len(decode_sentence) > max_fra_word) :
            stop_condition = True
        else :
            decode_sentence.append(sampled_word)

        target_seq = np.array([[sampled_token_index]])

        state_h, state_c = h, c

    return ' '.join(decode_sentence)

# %% [markdown]
# ### Batch testing

# %%
# for i in range(10) : 
#     input_seq = encoder_input_data[i : i+1]
#     decoded_sentences = decode_sequence(input_seq)
#     print(f"english words : {eng_texts[i]}")
#     print(f"french words : {decoded_sentences}")
#     print('-'*30)
