# %% [markdown]
# ## Attention models : 3

# %% [markdown]
# ### data prep

# %%
import pandas as pd
import numpy as np

# %%
path = 'fra.txt'
eng_texts, fra_texts = [], []
num_samples = 10000

# %%
with open(path, 'r', encoding = 'UTF-8') as f : 
    lines = f.read().split('\n')

    for line in lines[:num_samples] : 
        eng_words, fra_words = line.split('\t')[:2]

        fra_words = '\t' + fra_words + '\n'

        eng_texts.append(eng_words)
        fra_texts.append(fra_words)

# %%
eng_texts
# Out:
# ['Go.',
#  'Go.',
#  'Go.',
#  'Go.',
#  'Hi.',
#  'Hi.',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run!',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Run.',
#  'Who?',
#  'Wow!',
#  'Wow!',
#  'Wow!',
#  'Duck!',
#  'Duck!',
#  'Duck!',
#  'Fire!',
#  'Help!',
#  'Hide.',
#  'Hide.',
#  'Jump!',
#  'Jump.',
#  'Stop!',
#  'Stop!',
#  'Stop!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Begin.',
#  'Begin.',
#  'Go on.',
#  'Go on.',
#  'Go on.',
#  'Hello!',
#  'Hello!',
#  'Hello.',
#  'Hello.',
#  'Hello.',
#  'Hello.',
#  'I see.',
#  'I see.',
#  'I try.',
#  'I won!',
#  'I won!',
#  'I won.',
#  'Oh no!',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Relax.',
#  'Shoot!',
#  'Shoot!',
#  'Smile.',
#  'Smile.',
#  'Smile.',
#  'Sorry?',
#  'Attack!',
#  'Attack!',
#  'Attack!',
#  'Attack!',
#  'Buy it.',
#  'Buy it.',
#  'Buy it.',
#  'Buy it.',
#  'Cheers!',
#  'Cheers!',
#  'Cheers!',
#  'Cheers!',
#  'Eat it.',
#  'Eat it.',
#  'Exhale.',
#  'Get up.',
#  'Get up.',
#  'Get up.',
#  'Go now.',
#  'Go now.',
#  'Go now.',
#  'Got it!',
#  'Got it!',
#  'Got it!',
#  'Got it?',
#  'Got it?',
#  'Got it?',
#  'Hop in.',
#  'Hop in.',
#  'Hug me.',
#  'Hug me.',
#  'I fell.',
#  'I fell.',
#  'I fled.',
#  'I hunt.',
#  'I knit.',
#  'I know.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I lied.',
#  'I lost.',
#  'I paid.',
#  'I paid.',
#  'I paid.',
#  'I pass.',
#  'I quit.',
#  'I quit.',
#  'I swim.',
#  "I'm 19.",
#  "I'm OK.",
#  "I'm OK.",
#  'Inhale.',
#  'Listen.',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'Really?',
#  'Really?',
#  'Really?',
#  'Really?',
#  'Really?',
#  'Thanks!',
#  'Thanks.',
#  'Thanks.',
#  'Thanks.',
#  'Try it.',
#  'Try it.',
#  'Try it.',
#  'We try.',
#  'We won.',
#  'We won.',
#  'We won.',
#  'We won.',
#  'We won.',
#  'Ask Tom.',
#  'Ask him.',
#  'Awesome!',
#  'Awesome!',
#  'Awesome!',
#  'Awesome.',
#  'Be calm.',
#  'Be calm.',
#  'Be calm.',
#  'Be cool.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be fair.',
#  'Be kind.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Be nice.',
#  'Beat it!',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Beat it.',
#  'Burn it.',
#  'Burn it.',
#  'Burn it.',
#  'Burn it.',
#  'Bury it.',
#  'Bury it.',
#  'Bury it.',
#  'Bury it.',
#  'Call me.',
#  'Call me.',
#  'Call us.',
#  'Call us.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on!',
#  'Come on.',
#  'Come on.',
#  'Come on.',
#  'Drop it!',
#  'Drop it!',
#  'Drop it!',
#  'Drop it!',
#  'Fold it.',
#  'Fold it.',
#  'Fold it.',
#  'Fold it.',
#  'Get Tom.',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out!',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Get out.',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away!',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go away.',
#  'Go back.',
#  'Go home.',
#  'Go home.',
#  'Go home.',
#  'Go home.',
#  'Go slow.',
#  'Go slow.',
#  'Goodbye!',
#  'Goodbye!',
#  'Goodbye!',
#  'Goodbye.',
#  'Hang on!',
#  'Hang on!',
#  'Hang on!',
#  'Hang on.',
#  'Hang on.',
#  'Hang on.',
#  'He left.',
#  'He runs.',
#  'Help me!',
#  'Help me.',
#  'Help me.',
#  'Help me.',
#  'Help me.',
#  'Help us.',
#  'Help us.',
#  'Hire me.',
#  'Hire me.',
#  'Hire me.',
#  'Hire me.',
#  'Hold it!',
#  'Hold it!',
#  'Hold it!',
#  'Hold it!',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hold up.',
#  'Hold up.',
#  'How sad!',
#  'Hug Tom.',
#  'I agree.',
#  'I cried.',
#  'I dozed.',
#  'I dozed.',
#  'I drive.',
#  'I drove.',
#  'I fired.',
#  'I froze.',
#  'I froze.',
#  'I smoke.',
#  'I snore.',
#  'I stink.',
#  'I stood.',
#  'I stood.',
#  'I swore.',
#  'I swore.',
#  'I tried.',
#  'I tried.',
#  'I tried.',
#  'I waved.',
#  "I'll go.",
#  "I'm Tom.",
#  "I'm fat.",
#  "I'm fat.",
#  "I'm fit.",
#  "I'm hit!",
#  "I'm hit!",
#  "I'm ill.",
#  "I'm mad.",
#  "I'm mad.",
#  "I'm mad.",
#  "I'm sad.",
#  "I'm sad.",
#  "I'm sad.",
#  "I'm shy.",
#  "I'm wet.",
#  "I'm wet.",
#  "It's me!",
#  'Join me.',
#  'Join us.',
#  'Join us.',
#  'Keep it.',
#  'Keep it.',
#  'Kick it.',
#  'Kick it.',
#  'Kill it.',
#  'Kill it.',
#  'Kill it.',
#  'Kill it.',
#  'Kiss me.',
#  'Kiss me.',
#  'Lie low.',
#  'Lie low.',
#  'Lock it.',
#  'Lock it.',
#  'Lock it.',
#  'Lock it.',
#  'Look up.',
#  'Look up.',
#  'Me, too.',
#  'Me, too.',
#  'Move on.',
#  'Move on.',
#  'Open it.',
#  'Open it.',
#  'Open it.',
#  'Open it.',
#  'Open up.',
#  'Open up.',
#  'Pair up.',
#  'Perfect!',
#  'Perfect!',
#  'Perfect!',
#  'Pull it.',
#  'Pull it.',
#  'Push it.',
#  'Push it.',
#  'Push it.',
#  'Push it.',
#  'Push it.',
#  'See you!',
#  'See you!',
#  'See you!',
#  'See you!',
#  'See you.',
#  'See you.',
#  'Show me.',
#  'Show me.',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Shut up!',
#  'Sign up.',
#  'Sign up.',
#  'Skip it.',
#  'Skip it.',
#  'So long.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Take it.',
#  'Tell me.',
#  'Tell me.',
#  'Tom won.',
#  'Wake up!',
#  'Wake up!',
#  'Wake up!',
#  'Wake up.',
#  'Wake up.',
#  'Wash up.',
#  'Wash up.',
#  'We care.',
#  'We know.',
#  'We know.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'We lost.',
#  'Welcome.',
#  'Welcome.',
#  'Who ran?',
#  'Who won?',
#  'Who won?',
#  'You run.',
#  'You win.',
#  'Aim high.',
#  'Aim high.',
#  'Am I fat?',
#  'Am I fat?',
#  'Ask them.',
#  'Ask them.',
#  'Back off!',
#  'Back off!',
#  'Back off!',
#  'Back off.',
#  'Back off.',
#  'Back off.',
#  'Back off.',
#  'Back off.',
#  'Be a man.',
#  'Be a man.',
#  'Be brave.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be brief.',
#  'Be quiet.',
#  'Be still.',
#  'Be still.',
#  'Be still.',
#  'Buzz off.',
#  'Call Tom.',
#  'Call Tom.',
#  'Can I go?',
#  'Cheer up!',
#  'Cheer up.',
#  'Cool off!',
#  'Cover me.',
#  'Cuff him.',
#  'Drive on.',
#  'Drive on.',
#  'Drive on.',
#  'Drive on.',
#  'Find Tom.',
#  'Find Tom.',
#  'Fix this.',
#  'Fix this.',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away!',
#  'Get away.',
#  'Get away.',
#  'Get down!',
#  'Get down!',
#  'Get down!',
#  'Get down!',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get down.',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost!',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get lost.',
#  'Get real!',
#  'Get real!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead!',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Good job!',
#  'Good job!',
#  'Good job!',
#  'Good job!',
#  'Grab Tom.',
#  'Grab Tom.',
#  'Grab him.',
#  'Grab him.',
#  'Grab him.',
#  'Have fun.',
#  'Have fun.',
#  'Have fun.',
#  'Have fun.',
#  'He spoke.',
#  'He spoke.',
#  'He spoke.',
#  'He tries.',
#  "He's wet.",
#  'Help Tom.',
#  'Help Tom.',
#  'Help Tom.',
#  'Hi, guys.',
#  'Hit back.',
#  'Hit back.',
#  'How cute!',
#  'How cute!',
#  'How cute!',
#  'How deep?',
#  'How nice!',
#  'How nice!',
#  'How nice!',
#  'How nice!',
#  'How nice!',
#  'How rude!',
#  'How rude!',
#  'How wise!',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'Hurry up.',
#  'I am Tom.',
#  'I cursed.',
#  'I did OK.',
#  'I did OK.',
#  'I did it.',
#  'I did it.',
#  'I failed.',
#  'I forgot.',
#  'I get it.',
#  'I goofed.',
#  'I goofed.',
#  'I goofed.',
#  'I got it.',
#  'I got it.',
#  'I helped.',
#  'I jumped.',
#  'I looked.',
#  'I moaned.',
#  'I nodded.',
#  'I obeyed.',
#  'I phoned.',
#  'I phoned.',
#  'I refuse.',
#  'I refuse.',
#  'I rested.',
#  'I rested.',
#  'I saw it.',
#  'I saw it.',
#  'I sighed.',
#  'I smiled.',
#  'I stayed.',
#  'I stayed.',
#  'I talked.',
#  'I use it.',
#  'I use it.',
#  'I use it.',
#  "I'll pay.",
#  "I'll pay.",
#  "I'll try.",
#  "I'll try.",
#  "I'm back.",
#  "I'm back.",
#  "I'm bald.",
#  "I'm busy.",
#  "I'm busy.",
#  "I'm calm.",
#  "I'm cold.",
#  "I'm cool.",
#  "I'm cool.",
#  "I'm deaf.",
#  "I'm deaf.",
#  "I'm done.",
#  "I'm fair.",
#  "I'm fair.",
#  "I'm fair.",
#  "I'm fast.",
#  "I'm fine.",
#  "I'm fine.",
#  "I'm fine.",
#  "I'm free!",
#  "I'm free.",
#  "I'm free.",
#  "I'm full.",
#  "I'm full.",
#  "I'm game.",
#  "I'm game.",
#  "I'm glad.",
#  "I'm good.",
#  "I'm good.",
#  "I'm home.",
#  "I'm late.",
#  "I'm lazy.",
#  "I'm lazy.",
#  "I'm lazy.",
#  "I'm lazy.",
#  "I'm lost.",
#  "I'm lost.",
#  "I'm okay.",
#  "I'm okay.",
#  "I'm rich.",
#  "I'm safe.",
#  "I'm sick.",
#  "I'm sure.",
#  "I'm sure.",
#  "I'm sure.",
#  "I'm sure.",
#  "I'm tall.",
#  "I'm thin.",
#  "I'm tidy.",
#  "I'm tidy.",
#  "I'm ugly.",
#  "I'm ugly.",
#  "I'm ugly.",
#  "I'm weak.",
#  "I'm well.",
#  "I'm well.",
#  "I've won.",
#  "I've won.",
#  'It helps.',
#  'It hurts.',
#  'It works.',
#  'It works.',
#  "It's Tom.",
#  "It's fun.",
#  "It's fun.",
#  "It's his.",
#  "It's his.",
#  "It's hot.",
#  "It's new.",
#  "It's new.",
#  "It's odd.",
#  "It's red.",
#  "It's sad.",
#  'Keep out!',
#  'Keep out.',
#  'Kill Tom.',
#  'Kill Tom.',
#  'Kiss Tom.',
#  'Leave it.',
#  'Leave it.',
#  'Leave it.',
#  'Leave it.',
#  'Leave it.',
#  'Leave me.',
#  'Leave us.',
#  'Leave us.',
#  "Let's go!",
#  "Let's go!",
#  "Let's go!",
#  "Let's go.",
#  "Let's go.",
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Look out!',
#  'Marry me.',
#  'Marry me.',
#  'May I go?',
#  'May I go?',
#  'May I go?',
#  'Nice try.',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Nonsense!',
#  'Now stop!',
#  'Now stop!',
#  'Prove it.',
#  'Prove it.',
#  'Run away.',
#  'Run away.',
#  'Run away.',
#  'Run away.',
#  'Save Tom.',
#  'Save Tom.',
#  'Say what?',
#  'She came.',
#  'She died.',
#  'She left.',
#  'She runs.',
#  'Sit down!',
#  'Sit down!',
#  'Sit down!',
#  'Sit down.',
#  'Sit down.',
#  'Sit here.',
#  'Sit here.',
#  'Speak up!',
#  'Speak up!',
#  'Speak up!',
#  'Speed up.',
#  'Speed up.',
#  'Stand up.',
#  'Stop Tom.',
#  'Stop Tom.',
#  'Take Tom.',
#  'Taste it.',
#  'Taste it.',
#  'Taste it.',
#  'Taste it.',
#  'Tell Tom.',
#  'Tell Tom.',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'Terrific!',
#  'They won.',
#  'They won.',
#  'They won.',
#  'They won.',
#  'Tom came.',
#  'Tom died.',
#  'Tom knew.',
#  'Tom left.',
#  'Tom left.',
#  'Tom lied.',
#  'Tom lies.',
#  'Tom lost.',
#  'Tom paid.',
#  'Tom paid.',
#  'Tom went.',
#  "Tom's up.",
#  'Too late.',
#  'Touch it.',
#  'Touch it.',
#  'Touch it.',
#  'Touch it.',
#  'Trust me!',
#  'Trust me.',
#  'Trust me.',
#  'Trust me.',
#  'Trust me.',
#  'Try some.',
#  'Try some.',
#  'Try some.',
#  'Try this.',
#  'Try this.',
#  'Try this.',
#  'Use this.',
#  'Use this.',
#  'Use this.',
#  'Use this.',
#  'Warn Tom.',
#  'Warn Tom.',
#  'Watch me.',
#  'Watch me.',
#  'Watch us.',
#  'Watch us.',
#  'We agree.',
#  "We'll go.",
#  "We're OK.",
#  'What for?',
#  'What for?',
#  'What fun!',
#  'What fun!',
#  'Who am I?',
#  'Who came?',
#  'Who died?',
#  'Who fell?',
#  'Who lost?',
#  'Who paid?',
#  'Who paid?',
#  'Who quit?',
#  "Who's he?",
#  'Write me.',
#  'Write me.',
#  'You lost.',
#  'You lost.',
#  'You lost.',
#  'After you.',
#  'After you.',
#  'After you.',
#  'After you.',
#  'Aim. Fire!',
#  'Am I cute?',
#  'Am I late?',
#  'Answer me.',
#  'Be honest.',
#  'Be honest.',
#  'Be honest.',
#  'Be seated.',
#  'Be seated.',
#  'Be seated.',
#  'Be strong.',
#  'Birds fly.',
#  'Bless you.',
#  'Call home!',
#  'Calm down!',
#  'Calm down!',
#  'Calm down!',
#  'Calm down.',
#  'Calm down.',
#  'Calm down.',
#  'Can we go?',
#  'Can we go?',
#  'Can we go?',
#  'Catch Tom.',
#  'Catch Tom.',
#  'Catch him.',
#  'Catch him.',
#  'Catch him.',
#  'Chill out.',
#  'Chill out.',
#  'Choose me.',
#  'Come back.',
#  'Come back.',
#  'Come here.',
#  'Come here.',
#  'Come over.',
#  'Come over.',
#  'Come over.',
#  'Come over.',
#  'Come over.',
#  'Come soon.',
#  'Come soon.',
#  'Cool down.',
#  'Did I win?',
#  'Did I win?',
#  'Did I win?',
#  'Do it now.',
#  'Dogs bark.',
#  'Dogs bark.',
#  "Don't ask.",
#  "Don't cry.",
#  "Don't die.",
#  "Don't die.",
#  "Don't lie.",
#  "Don't lie.",
#  "Don't run.",
#  "Don't run.",
#  'Excuse me.',
#  'Excuse me.',
#  'Excuse me.',
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Fantastic!',
#  'Fantastic!',
#  'Fantastic!',
#  ...]

# %%
len(fra_texts)
# Out:
# 10000

# %%
max_eng_words = max([len(words) for words in eng_texts])
max_fra_words = max([len(words) for words in fra_texts])
print(f"{max_eng_words} :: {max_fra_words}")
# Out:
# 14 :: 59

# %% [markdown]
# ### tokenizer and pad_sequences

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
eng_tokenizer = Tokenizer(filters = ' ', lower = True)
eng_tokenizer.fit_on_texts(eng_texts)
encoder_input_data = eng_tokenizer.texts_to_sequences(eng_texts)

# %%
fra_tokenizer = Tokenizer(filters = ' ', lower = True)
fra_tokenizer.fit_on_texts(fra_texts)
decoder_input_data = fra_tokenizer.texts_to_sequences(fra_texts)

# %%
encoder_input_data = pad_sequences(encoder_input_data, maxlen = max_eng_words, padding = 'pre')

# %%
decoder_input_data = pad_sequences(decoder_input_data, maxlen = max_fra_words, padding = 'pre')

# %%
encoder_input_data.shape
# Out:
# (10000, 14)

# %%
decoder_input_data.shape
# Out:
# (10000, 59)

# %%
decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[:, 1:]

# %%
decoder_target_data.shape
# Out:
# (10000, 59)

# %%
decoder_input_data
# Out:
# array([[   0,    0,    0, ...,    0,   92,    2],
#        [   0,    0,    0, ...,    0,    0,  991],
#        [   0,    0,    0, ...,  145,  334,    2],
#        ...,
#        [   0,    0,    0, ...,   20, 5804,  380],
#        [   0,    0,    0, ...,   20, 5805,  380],
#        [   0,    0,    0, ..., 2286,  893,  456]])

# %%
decoder_target_data
# Out:
# array([[   0,    0,    0, ...,   92,    2,    0],
#        [   0,    0,    0, ...,    0,  991,    0],
#        [   0,    0,    0, ...,  334,    2,    0],
#        ...,
#        [   0,    0,    0, ..., 5804,  380,    0],
#        [   0,    0,    0, ..., 5805,  380,    0],
#        [   0,    0,    0, ...,  893,  456,    0]])

# %%
eng_vocab = len(eng_tokenizer.word_index) + 1
fra_vocab = len(fra_tokenizer.word_index) + 1
print(f"{eng_vocab} :: {fra_vocab}")
# Out:
# 2707 :: 5806

# %% [markdown]
# ### building the encoders/decoders

# %%
from tensorflow.keras.layers import Input, Embedding, LSTM

# %%
latent_dim = 256

# %%
encoder_inputs = Input(shape = (max_eng_words, ))
encoder_emb = Embedding(eng_vocab, latent_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_emb)

# %%
decoder_inputs = Input(shape = (max_fra_words, ))
decoder_emb_layer = Embedding(fra_vocab, latent_dim)
decoder_emb = decoder_emb_layer(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)

# %% [markdown]
# ### building the Attention model

# %%
from tensorflow.keras.layers import Layer, Dense, Concatenate
from tensorflow.keras.models import Model

# %%
class BahdanauAttention(Layer) : 
    def __init__(self, units) : 
        super(BahdanauAttention, self).__init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, query, vlaues) : 
        query_with_time_axis = tensorflow.expand_dims(query, 1)
        score = self.V(tensorflow.nn.tanh(self.W1(vlaues)) + self.W2(query_with_time_axis))
        attention_weights = tensorflow.nn.softmax(score, axis = 1)
        context_vector = attention_weights * score
        context_vector = tensorflow.reduce_sum(context_vector, axis = 1)

        return context_vector, attention_weights

# %%
attention = BahdanauAttention(latent_dim)
all_outputs = []
decoder_state_h, decoder_state_c = state_h, state_c
for t in range(max_fra_words) : 
    context_vector, _ = attention(decoder_state_h, decoder_state_c)
    X = tensorflow.expand_dims(decoder_emb[:, t], 1)
    X = Concatenate(axis = -1)([context_vector[:, None, :], X])
    outputs, decoder_state_h, decoder_state_c = decoder_lstm(X, initial_state = [decoder_state_h, decoder_state_c])
    outputs = Dense(fra_vocab, activation = 'softmax')(outputs)

    all_outputs.append(outputs)

decoder_outputs = tensorflow.concat(all_outputs, axis = 1)

# %%
model = Model()

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 14)]         0           []
#
#  embedding_2 (Embedding)        (None, 14, 256)      692992      ['input_3[0][0]']
#
#  input_4 (InputLayer)           [(None, 59)]         0           []
#
#  lstm_2 (LSTM)                  [(None, 14, 256),    525312      ['embedding_2[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_3 (Embedding)        (None, 59, 256)      1486336     ['input_4[0][0]']
#
#  bahdanau_attention_17 (Bahdana  ((None, 1),         131841      ['lstm_2[0][1]',
#  uAttention)                     (None, None, 1))                 'lstm_2[0][2]',
#                                                                   'lstm_3[59][1]',
#                                                                   'lstm_3[59][2]',
#                                                                   'lstm_3[60][1]',
#                                                                   'lstm_3[60][2]',
#                                                                   'lstm_3[61][1]',
#                                                                   'lstm_3[61][2]',
#                                                                   'lstm_3[62][1]',
#                                                                   'lstm_3[62][2]',
#                                                                   'lstm_3[63][1]',
#                                                                   'lstm_3[63][2]',
#                                                                   'lstm_3[64][1]',
#                                                                   'lstm_3[64][2]',
#                                                                   'lstm_3[65][1]',
#                                                                   'lstm_3[65][2]',
#                                                                   'lstm_3[66][1]',
#                                                                   'lstm_3[66][2]',
#                                                                   'lstm_3[67][1]',
#                                                                   'lstm_3[67][2]',
#                                                                   'lstm_3[68][1]',
#                                                                   'lstm_3[68][2]',
#                                                                   'lstm_3[69][1]',
#                                                                   'lstm_3[69][2]',
#                                                                   'lstm_3[70][1]',
#                                                                   'lstm_3[70][2]',
#                                                                   'lstm_3[71][1]',
#                                                                   'lstm_3[71][2]',
#                                                                   'lstm_3[72][1]',
#                                                                   'lstm_3[72][2]',
#                                                                   'lstm_3[73][1]',
#                                                                   'lstm_3[73][2]',
#                                                                   'lstm_3[74][1]',
#                                                                   'lstm_3[74][2]',
#                                                                   'lstm_3[75][1]',
#                                                                   'lstm_3[75][2]',
#                                                                   'lstm_3[76][1]',
#                                                                   'lstm_3[76][2]',
#                                                                   'lstm_3[77][1]',
#                                                                   'lstm_3[77][2]',
#                                                                   'lstm_3[78][1]',
#                                                                   'lstm_3[78][2]',
#                                                                   'lstm_3[79][1]',
#                                                                   'lstm_3[79][2]',
#                                                                   'lstm_3[80][1]',
#                                                                   'lstm_3[80][2]',
#                                                                   'lstm_3[81][1]',
#                                                                   'lstm_3[81][2]',
#                                                                   'lstm_3[82][1]',
#                                                                   'lstm_3[82][2]',
#                                                                   'lstm_3[83][1]',
#                                                                   'lstm_3[83][2]',
#                                                                   'lstm_3[84][1]',
#                                                                   'lstm_3[84][2]',
#                                                                   'lstm_3[85][1]',
#                                                                   'lstm_3[85][2]',
#                                                                   'lstm_3[86][1]',
#                                                                   'lstm_3[86][2]',
#                                                                   'lstm_3[87][1]',
#                                                                   'lstm_3[87][2]',
#                                                                   'lstm_3[88][1]',
#                                                                   'lstm_3[88][2]',
#                                                                   'lstm_3[89][1]',
#                                                                   'lstm_3[89][2]',
#                                                                   'lstm_3[90][1]',
#                                                                   'lstm_3[90][2]',
#                                                                   'lstm_3[91][1]',
#                                                                   'lstm_3[91][2]',
#                                                                   'lstm_3[92][1]',
#                                                                   'lstm_3[92][2]',
#                                                                   'lstm_3[93][1]',
#                                                                   'lstm_3[93][2]',
#                                                                   'lstm_3[94][1]',
#                                                                   'lstm_3[94][2]',
#                                                                   'lstm_3[95][1]',
#                                                                   'lstm_3[95][2]',
#                                                                   'lstm_3[96][1]',
#                                                                   'lstm_3[96][2]',
#                                                                   'lstm_3[97][1]',
#                                                                   'lstm_3[97][2]',
#                                                                   'lstm_3[98][1]',
#                                                                   'lstm_3[98][2]',
#                                                                   'lstm_3[99][1]',
#                                                                   'lstm_3[99][2]',
#                                                                   'lstm_3[100][1]',
#                                                                   'lstm_3[100][2]',
#                                                                   'lstm_3[101][1]',
#                                                                   'lstm_3[101][2]',
#                                                                   'lstm_3[102][1]',
#                                                                   'lstm_3[102][2]',
#                                                                   'lstm_3[103][1]',
#                                                                   'lstm_3[103][2]',
#                                                                   'lstm_3[104][1]',
#                                                                   'lstm_3[104][2]',
#                                                                   'lstm_3[105][1]',
#                                                                   'lstm_3[105][2]',
#                                                                   'lstm_3[106][1]',
#                                                                   'lstm_3[106][2]',
#                                                                   'lstm_3[107][1]',
#                                                                   'lstm_3[107][2]',
#                                                                   'lstm_3[108][1]',
#                                                                   'lstm_3[108][2]',
#                                                                   'lstm_3[109][1]',
#                                                                   'lstm_3[109][2]',
#                                                                   'lstm_3[110][1]',
#                                                                   'lstm_3[110][2]',
#                                                                   'lstm_3[111][1]',
#                                                                   'lstm_3[111][2]',
#                                                                   'lstm_3[112][1]',
#                                                                   'lstm_3[112][2]',
#                                                                   'lstm_3[113][1]',
#                                                                   'lstm_3[113][2]',
#                                                                   'lstm_3[114][1]',
#                                                                   'lstm_3[114][2]',
#                                                                   'lstm_3[115][1]',
#                                                                   'lstm_3[115][2]',
#                                                                   'lstm_3[116][1]',
#                                                                   'lstm_3[116][2]']
#
#  tf.__operators__.getitem_118 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_119 (  (None, 1, 1)        0           ['bahdanau_attention_17[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_59 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_118[0]
#                                                                  [0]']
#
#  concatenate_59 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_119[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_59[0][0]']
#
#  lstm_3 (LSTM)                  [(None, 1, 256),     526336      ['concatenate_59[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]',
#                                                                   'concatenate_60[0][0]',
#                                                                   'lstm_3[59][1]',
#                                                                   'lstm_3[59][2]',
#                                                                   'concatenate_61[0][0]',
#                                                                   'lstm_3[60][1]',
#                                                                   'lstm_3[60][2]',
#                                                                   'concatenate_62[0][0]',
#                                                                   'lstm_3[61][1]',
#                                                                   'lstm_3[61][2]',
#                                                                   'concatenate_63[0][0]',
#                                                                   'lstm_3[62][1]',
#                                                                   'lstm_3[62][2]',
#                                                                   'concatenate_64[0][0]',
#                                                                   'lstm_3[63][1]',
#                                                                   'lstm_3[63][2]',
#                                                                   'concatenate_65[0][0]',
#                                                                   'lstm_3[64][1]',
#                                                                   'lstm_3[64][2]',
#                                                                   'concatenate_66[0][0]',
#                                                                   'lstm_3[65][1]',
#                                                                   'lstm_3[65][2]',
#                                                                   'concatenate_67[0][0]',
#                                                                   'lstm_3[66][1]',
#                                                                   'lstm_3[66][2]',
#                                                                   'concatenate_68[0][0]',
#                                                                   'lstm_3[67][1]',
#                                                                   'lstm_3[67][2]',
#                                                                   'concatenate_69[0][0]',
#                                                                   'lstm_3[68][1]',
#                                                                   'lstm_3[68][2]',
#                                                                   'concatenate_70[0][0]',
#                                                                   'lstm_3[69][1]',
#                                                                   'lstm_3[69][2]',
#                                                                   'concatenate_71[0][0]',
#                                                                   'lstm_3[70][1]',
#                                                                   'lstm_3[70][2]',
#                                                                   'concatenate_72[0][0]',
#                                                                   'lstm_3[71][1]',
#                                                                   'lstm_3[71][2]',
#                                                                   'concatenate_73[0][0]',
#                                                                   'lstm_3[72][1]',
#                                                                   'lstm_3[72][2]',
#                                                                   'concatenate_74[0][0]',
#                                                                   'lstm_3[73][1]',
#                                                                   'lstm_3[73][2]',
#                                                                   'concatenate_75[0][0]',
#                                                                   'lstm_3[74][1]',
#                                                                   'lstm_3[74][2]',
#                                                                   'concatenate_76[0][0]',
#                                                                   'lstm_3[75][1]',
#                                                                   'lstm_3[75][2]',
#                                                                   'concatenate_77[0][0]',
#                                                                   'lstm_3[76][1]',
#                                                                   'lstm_3[76][2]',
#                                                                   'concatenate_78[0][0]',
#                                                                   'lstm_3[77][1]',
#                                                                   'lstm_3[77][2]',
#                                                                   'concatenate_79[0][0]',
#                                                                   'lstm_3[78][1]',
#                                                                   'lstm_3[78][2]',
#                                                                   'concatenate_80[0][0]',
#                                                                   'lstm_3[79][1]',
#                                                                   'lstm_3[79][2]',
#                                                                   'concatenate_81[0][0]',
#                                                                   'lstm_3[80][1]',
#                                                                   'lstm_3[80][2]',
#                                                                   'concatenate_82[0][0]',
#                                                                   'lstm_3[81][1]',
#                                                                   'lstm_3[81][2]',
#                                                                   'concatenate_83[0][0]',
#                                                                   'lstm_3[82][1]',
#                                                                   'lstm_3[82][2]',
#                                                                   'concatenate_84[0][0]',
#                                                                   'lstm_3[83][1]',
#                                                                   'lstm_3[83][2]',
#                                                                   'concatenate_85[0][0]',
#                                                                   'lstm_3[84][1]',
#                                                                   'lstm_3[84][2]',
#                                                                   'concatenate_86[0][0]',
#                                                                   'lstm_3[85][1]',
#                                                                   'lstm_3[85][2]',
#                                                                   'concatenate_87[0][0]',
#                                                                   'lstm_3[86][1]',
#                                                                   'lstm_3[86][2]',
#                                                                   'concatenate_88[0][0]',
#                                                                   'lstm_3[87][1]',
#                                                                   'lstm_3[87][2]',
#                                                                   'concatenate_89[0][0]',
#                                                                   'lstm_3[88][1]',
#                                                                   'lstm_3[88][2]',
#                                                                   'concatenate_90[0][0]',
#                                                                   'lstm_3[89][1]',
#                                                                   'lstm_3[89][2]',
#                                                                   'concatenate_91[0][0]',
#                                                                   'lstm_3[90][1]',
#                                                                   'lstm_3[90][2]',
#                                                                   'concatenate_92[0][0]',
#                                                                   'lstm_3[91][1]',
#                                                                   'lstm_3[91][2]',
#                                                                   'concatenate_93[0][0]',
#                                                                   'lstm_3[92][1]',
#                                                                   'lstm_3[92][2]',
#                                                                   'concatenate_94[0][0]',
#                                                                   'lstm_3[93][1]',
#                                                                   'lstm_3[93][2]',
#                                                                   'concatenate_95[0][0]',
#                                                                   'lstm_3[94][1]',
#                                                                   'lstm_3[94][2]',
#                                                                   'concatenate_96[0][0]',
#                                                                   'lstm_3[95][1]',
#                                                                   'lstm_3[95][2]',
#                                                                   'concatenate_97[0][0]',
#                                                                   'lstm_3[96][1]',
#                                                                   'lstm_3[96][2]',
#                                                                   'concatenate_98[0][0]',
#                                                                   'lstm_3[97][1]',
#                                                                   'lstm_3[97][2]',
#                                                                   'concatenate_99[0][0]',
#                                                                   'lstm_3[98][1]',
#                                                                   'lstm_3[98][2]',
#                                                                   'concatenate_100[0][0]',
#                                                                   'lstm_3[99][1]',
#                                                                   'lstm_3[99][2]',
#                                                                   'concatenate_101[0][0]',
#                                                                   'lstm_3[100][1]',
#                                                                   'lstm_3[100][2]',
#                                                                   'concatenate_102[0][0]',
#                                                                   'lstm_3[101][1]',
#                                                                   'lstm_3[101][2]',
#                                                                   'concatenate_103[0][0]',
#                                                                   'lstm_3[102][1]',
#                                                                   'lstm_3[102][2]',
#                                                                   'concatenate_104[0][0]',
#                                                                   'lstm_3[103][1]',
#                                                                   'lstm_3[103][2]',
#                                                                   'concatenate_105[0][0]',
#                                                                   'lstm_3[104][1]',
#                                                                   'lstm_3[104][2]',
#                                                                   'concatenate_106[0][0]',
#                                                                   'lstm_3[105][1]',
#                                                                   'lstm_3[105][2]',
#                                                                   'concatenate_107[0][0]',
#                                                                   'lstm_3[106][1]',
#                                                                   'lstm_3[106][2]',
#                                                                   'concatenate_108[0][0]',
#                                                                   'lstm_3[107][1]',
#                                                                   'lstm_3[107][2]',
#                                                                   'concatenate_109[0][0]',
#                                                                   'lstm_3[108][1]',
#                                                                   'lstm_3[108][2]',
#                                                                   'concatenate_110[0][0]',
#                                                                   'lstm_3[109][1]',
#                                                                   'lstm_3[109][2]',
#                                                                   'concatenate_111[0][0]',
#                                                                   'lstm_3[110][1]',
#                                                                   'lstm_3[110][2]',
#                                                                   'concatenate_112[0][0]',
#                                                                   'lstm_3[111][1]',
#                                                                   'lstm_3[111][2]',
#                                                                   'concatenate_113[0][0]',
#                                                                   'lstm_3[112][1]',
#                                                                   'lstm_3[112][2]',
#                                                                   'concatenate_114[0][0]',
#                                                                   'lstm_3[113][1]',
#                                                                   'lstm_3[113][2]',
#                                                                   'concatenate_115[0][0]',
#                                                                   'lstm_3[114][1]',
#                                                                   'lstm_3[114][2]',
#                                                                   'concatenate_116[0][0]',
#                                                                   'lstm_3[115][1]',
#                                                                   'lstm_3[115][2]',
#                                                                   'concatenate_117[0][0]',
#                                                                   'lstm_3[116][1]',
#                                                                   'lstm_3[116][2]']
#
#  tf.__operators__.getitem_120 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_121 (  (None, 1, 1)        0           ['bahdanau_attention_17[1][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_60 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_120[0]
#                                                                  [0]']
#
#  concatenate_60 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_121[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_60[0][0]']
#
#  tf.__operators__.getitem_122 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_123 (  (None, 1, 1)        0           ['bahdanau_attention_17[2][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_61 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_122[0]
#                                                                  [0]']
#
#  concatenate_61 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_123[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_61[0][0]']
#
#  tf.__operators__.getitem_124 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_125 (  (None, 1, 1)        0           ['bahdanau_attention_17[3][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_62 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_124[0]
#                                                                  [0]']
#
#  concatenate_62 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_125[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_62[0][0]']
#
#  tf.__operators__.getitem_126 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_127 (  (None, 1, 1)        0           ['bahdanau_attention_17[4][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_63 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_126[0]
#                                                                  [0]']
#
#  concatenate_63 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_127[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_63[0][0]']
#
#  tf.__operators__.getitem_128 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_129 (  (None, 1, 1)        0           ['bahdanau_attention_17[5][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_64 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_128[0]
#                                                                  [0]']
#
#  concatenate_64 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_129[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_64[0][0]']
#
#  tf.__operators__.getitem_130 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_131 (  (None, 1, 1)        0           ['bahdanau_attention_17[6][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_65 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_130[0]
#                                                                  [0]']
#
#  concatenate_65 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_131[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_65[0][0]']
#
#  tf.__operators__.getitem_132 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_133 (  (None, 1, 1)        0           ['bahdanau_attention_17[7][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_66 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_132[0]
#                                                                  [0]']
#
#  concatenate_66 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_133[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_66[0][0]']
#
#  tf.__operators__.getitem_134 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_135 (  (None, 1, 1)        0           ['bahdanau_attention_17[8][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_67 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_134[0]
#                                                                  [0]']
#
#  concatenate_67 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_135[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_67[0][0]']
#
#  tf.__operators__.getitem_136 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_137 (  (None, 1, 1)        0           ['bahdanau_attention_17[9][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_68 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_136[0]
#                                                                  [0]']
#
#  concatenate_68 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_137[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_68[0][0]']
#
#  tf.__operators__.getitem_138 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_139 (  (None, 1, 1)        0           ['bahdanau_attention_17[10][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_69 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_138[0]
#                                                                  [0]']
#
#  concatenate_69 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_139[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_69[0][0]']
#
#  tf.__operators__.getitem_140 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_141 (  (None, 1, 1)        0           ['bahdanau_attention_17[11][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_70 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_140[0]
#                                                                  [0]']
#
#  concatenate_70 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_141[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_70[0][0]']
#
#  tf.__operators__.getitem_142 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_143 (  (None, 1, 1)        0           ['bahdanau_attention_17[12][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_71 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_142[0]
#                                                                  [0]']
#
#  concatenate_71 (Concatenate)   (None, 1, 257)       0           ['tf.__operators__.getitem_143[0]
#                                                                  [0]',
#                                                                   'tf.expand_dims_71[0][0]']
#
#  tf.__operators__.getitem_144 (  (None, 256)         0           ['embedding_3[0][0]']
#  SlicingOpLambda)
#
# ...
#  dense_123 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[69][0]']
#
#  dense_124 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[70][0]']
#
#  dense_125 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[71][0]']
#
#  dense_126 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[72][0]']
#
#  dense_127 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[73][0]']
#
#  dense_128 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[74][0]']
#
#  dense_129 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[75][0]']
#
#  dense_130 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[76][0]']
#
#  dense_131 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[77][0]']
#
#  dense_132 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[78][0]']
#
#  dense_133 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[79][0]']
#
#  dense_134 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[80][0]']
#
#  dense_135 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[81][0]']
#
#  dense_136 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[82][0]']
#
#  dense_137 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[83][0]']
#
#  dense_138 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[84][0]']
#
#  dense_139 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[85][0]']
#
#  dense_140 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[86][0]']
#
#  dense_141 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[87][0]']
#
#  dense_142 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[88][0]']
#
#  dense_143 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[89][0]']
#
#  dense_144 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[90][0]']
#
#  dense_145 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[91][0]']
#
#  dense_146 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[92][0]']
#
#  dense_147 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[93][0]']
#
#  dense_148 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[94][0]']
#
#  dense_149 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[95][0]']
#
#  dense_150 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[96][0]']
#
#  dense_151 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[97][0]']
#
#  dense_152 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[98][0]']
#
#  dense_153 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[99][0]']
#
#  dense_154 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[100][0]']
#
#  dense_155 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[101][0]']
#
#  dense_156 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[102][0]']
#
#  dense_157 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[103][0]']
#
#  dense_158 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[104][0]']
#
#  dense_159 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[105][0]']
#
#  dense_160 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[106][0]']
#
#  dense_161 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[107][0]']
#
#  dense_162 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[108][0]']
#
#  dense_163 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[109][0]']
#
#  dense_164 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[110][0]']
#
#  dense_165 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[111][0]']
#
#  dense_166 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[112][0]']
#
#  dense_167 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[113][0]']
#
#  dense_168 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[114][0]']
#
#  dense_169 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[115][0]']
#
#  dense_170 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[116][0]']
#
#  dense_171 (Dense)              (None, 1, 5806)      1492142     ['lstm_3[117][0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 59, 5806)     0           ['dense_113[0][0]',
#                                                                   'dense_114[0][0]',
#                                                                   'dense_115[0][0]',
#                                                                   'dense_116[0][0]',
#                                                                   'dense_117[0][0]',
#                                                                   'dense_118[0][0]',
#                                                                   'dense_119[0][0]',
#                                                                   'dense_120[0][0]',
#                                                                   'dense_121[0][0]',
#                                                                   'dense_122[0][0]',
#                                                                   'dense_123[0][0]',
#                                                                   'dense_124[0][0]',
#                                                                   'dense_125[0][0]',
#                                                                   'dense_126[0][0]',
#                                                                   'dense_127[0][0]',
#                                                                   'dense_128[0][0]',
#                                                                   'dense_129[0][0]',
#                                                                   'dense_130[0][0]',
#                                                                   'dense_131[0][0]',
#                                                                   'dense_132[0][0]',
#                                                                   'dense_133[0][0]',
#                                                                   'dense_134[0][0]',
#                                                                   'dense_135[0][0]',
#                                                                   'dense_136[0][0]',
#                                                                   'dense_137[0][0]',
#                                                                   'dense_138[0][0]',
#                                                                   'dense_139[0][0]',
#                                                                   'dense_140[0][0]',
#                                                                   'dense_141[0][0]',
#                                                                   'dense_142[0][0]',
#                                                                   'dense_143[0][0]',
#                                                                   'dense_144[0][0]',
#                                                                   'dense_145[0][0]',
#                                                                   'dense_146[0][0]',
#                                                                   'dense_147[0][0]',
#                                                                   'dense_148[0][0]',
#                                                                   'dense_149[0][0]',
#                                                                   'dense_150[0][0]',
#                                                                   'dense_151[0][0]',
#                                                                   'dense_152[0][0]',
#                                                                   'dense_153[0][0]',
#                                                                   'dense_154[0][0]',
#                                                                   'dense_155[0][0]',
#                                                                   'dense_156[0][0]',
#                                                                   'dense_157[0][0]',
#                                                                   'dense_158[0][0]',
#                                                                   'dense_159[0][0]',
#                                                                   'dense_160[0][0]',
#                                                                   'dense_161[0][0]',
#                                                                   'dense_162[0][0]',
#                                                                   'dense_163[0][0]',
#                                                                   'dense_164[0][0]',
#                                                                   'dense_165[0][0]',
#                                                                   'dense_166[0][0]',
#                                                                   'dense_167[0][0]',
#                                                                   'dense_168[0][0]',
#                                                                   'dense_169[0][0]',
#                                                                   'dense_170[0][0]',
#                                                                   'dense_171[0][0]']
#
# ==================================================================================================
# Total params: 91,399,195
# Trainable params: 91,399,195
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(
    [encoder_input_data, decoder_input_data],
    np.expand_dims(decoder_target_data, -1),
    batch_size = 64,
    epochs = 3,
    validation_split = 0.2
)
# Out:
# Epoch 1/3
# 125/125 [==============================] - 304s 2s/step - loss: 1.4138 - accuracy: 0.9135 - val_loss: 0.4290 - val_accuracy: 0.9420
# Epoch 2/3
# 125/125 [==============================] - 197s 2s/step - loss: 0.3507 - accuracy: 0.9495 - val_loss: 0.4421 - val_accuracy: 0.9420
# Epoch 3/3
# 125/125 [==============================] - 199s 2s/step - loss: 0.3494 - accuracy: 0.9495 - val_loss: 0.4503 - val_accuracy: 0.9420
