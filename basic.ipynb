# %% [markdown]
# ## Attention models : 1

# %% [markdown]
# ### 1. Load and prepare the dataset

# %%
import pandas as pd
import numpy as np

# %%
eng_texts, fra_texts = [], []
num_samples = 10000
path = 'fra.txt'

# %%
with open(path, 'r', encoding = 'UTF-8') as f :
    lines = f.read().split('\n')

    for line in lines[:num_samples] : 

        eng_text, fra_text = line.split('\t')[:2]
        fra_text = '\t' + fra_text + '\n'

        eng_texts.append(eng_text)
        fra_texts.append(fra_text)

# %%
len(eng_texts)
# Out:
# 10000

# %%
len(fra_texts)
# Out:
# 10000

# %%
max_eng_len = max([len(word) for word in eng_texts])
max_fra_len = max([len(word) for word in fra_texts])

# %%
print(f"{max_eng_len} :: {max_fra_len}")
# Out:
# 14 :: 59

# %% [markdown]
# ### 2. Tokenization and pad_sequences

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence  import pad_sequences

# %%
eng_tokenizer = Tokenizer(filters = '', lower = True)
eng_tokenizer.fit_on_texts(eng_texts)
eng_sequences = eng_tokenizer.texts_to_sequences(eng_texts)

# %%
fra_tokenizer = Tokenizer(filters = '', lower = True)
fra_tokenizer.fit_on_texts(fra_texts)
fra_sequences = fra_tokenizer.texts_to_sequences(fra_texts)

# %%
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1
print(f"{eng_vocab_size} :: {fra_vocab_size}")
# Out:
# 2707 :: 5806

# %%
encoder_input_data = pad_sequences(eng_sequences, maxlen = max_eng_len, padding = 'pre')
decoder_input_data = pad_sequences(fra_sequences, maxlen = max_fra_len, padding = 'pre')

decoder_target_data = np.zeros_like(decoder_input_data)
decoder_target_data[:, :-1] = decoder_input_data[:, 1:]

# %%
encoder_input_data.shape
# Out:
# (10000, 14)

# %%
decoder_input_data.shape
# Out:
# (10000, 59)

# %%
decoder_target_data.shape
# Out:
# (10000, 59)

# %% [markdown]
# ### 3. define the bahdanau attention layer

# %%
from tensorflow.keras.layers import Layer, Dense

# %%
class BahdanauAttention(Layer) : 
    def __init__(self, units) : 
        super(BahdanauAttention, self).__init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, query, values) : 
        quer_with_time_axis = tensorflow.expand_dims(query, 1)
        score = self.V(tensorflow.nn.tanh(self.W1(values) + self.W2(quer_with_time_axis)))
        attention_weights = tensorflow.nn.softmax(score, axis = 1)
        context_vector = attention_weights * values
        context_vector = tensorflow.reduce_sum(context_vector, axis = 1)

        return context_vector, attention_weights

# %% [markdown]
# ### 4. Building the encoder/decoder with the attention

# %%
from tensorflow.keras.layers import Input, Embedding, LSTM, Concatenate, Dense
from tensorflow.keras.models import Model

# %%
latent_dim = 256

# %%
encoder_inputs = Input(shape = (max_eng_len, ))
encoder_emb = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_emb)

# %%
decoder_inputs = Input(shape = (max_fra_len))
decoder_emb_layer = Embedding(fra_vocab_size, latent_dim)
decoder_emb = decoder_emb_layer(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_state = True, return_sequences = True)

# %%
attention = BahdanauAttention(latent_dim)
all_outputs = []
decoder_state_h, decoder_state_c = state_h, state_c
for t in range(max_fra_len) : 
    context_vector, _ = attention(decoder_state_h, decoder_state_c)
    X = tensorflow.expand_dims(decoder_emb[:, t], 1)
    X = Concatenate(axis = -1)([context_vector[:, None, :], X])
    output, decoder_state_h, decoder_state_c = decoder_lstm(X, initial_state = [decoder_state_h, decoder_state_c])
    output = Dense(fra_vocab_size, activation = 'softmax')(output)
    all_outputs.append(output)

decoder_outputs = tensorflow.concat(all_outputs, axis = 1)

# %%
model = Model()

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  embedding (Embedding)          (None, 14, 256)      692992      ['input_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 59)]         0           []
#
#  lstm (LSTM)                    [(None, 14, 256),    525312      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_1 (Embedding)        (None, 59, 256)      1486336     ['input_2[0][0]']
#
#  bahdanau_attention (BahdanauAt  ((None, 256),       131841      ['lstm[0][1]',
#  tention)                        (None, None, 1))                 'lstm[0][2]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[0][2]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[1][2]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[2][2]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[3][2]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[4][2]',
#                                                                   'lstm_1[5][1]',
#                                                                   'lstm_1[5][2]',
#                                                                   'lstm_1[6][1]',
#                                                                   'lstm_1[6][2]',
#                                                                   'lstm_1[7][1]',
#                                                                   'lstm_1[7][2]',
#                                                                   'lstm_1[8][1]',
#                                                                   'lstm_1[8][2]',
#                                                                   'lstm_1[9][1]',
#                                                                   'lstm_1[9][2]',
#                                                                   'lstm_1[10][1]',
#                                                                   'lstm_1[10][2]',
#                                                                   'lstm_1[11][1]',
#                                                                   'lstm_1[11][2]',
#                                                                   'lstm_1[12][1]',
#                                                                   'lstm_1[12][2]',
#                                                                   'lstm_1[13][1]',
#                                                                   'lstm_1[13][2]',
#                                                                   'lstm_1[14][1]',
#                                                                   'lstm_1[14][2]',
#                                                                   'lstm_1[15][1]',
#                                                                   'lstm_1[15][2]',
#                                                                   'lstm_1[16][1]',
#                                                                   'lstm_1[16][2]',
#                                                                   'lstm_1[17][1]',
#                                                                   'lstm_1[17][2]',
#                                                                   'lstm_1[18][1]',
#                                                                   'lstm_1[18][2]',
#                                                                   'lstm_1[19][1]',
#                                                                   'lstm_1[19][2]',
#                                                                   'lstm_1[20][1]',
#                                                                   'lstm_1[20][2]',
#                                                                   'lstm_1[21][1]',
#                                                                   'lstm_1[21][2]',
#                                                                   'lstm_1[22][1]',
#                                                                   'lstm_1[22][2]',
#                                                                   'lstm_1[23][1]',
#                                                                   'lstm_1[23][2]',
#                                                                   'lstm_1[24][1]',
#                                                                   'lstm_1[24][2]',
#                                                                   'lstm_1[25][1]',
#                                                                   'lstm_1[25][2]',
#                                                                   'lstm_1[26][1]',
#                                                                   'lstm_1[26][2]',
#                                                                   'lstm_1[27][1]',
#                                                                   'lstm_1[27][2]',
#                                                                   'lstm_1[28][1]',
#                                                                   'lstm_1[28][2]',
#                                                                   'lstm_1[29][1]',
#                                                                   'lstm_1[29][2]',
#                                                                   'lstm_1[30][1]',
#                                                                   'lstm_1[30][2]',
#                                                                   'lstm_1[31][1]',
#                                                                   'lstm_1[31][2]',
#                                                                   'lstm_1[32][1]',
#                                                                   'lstm_1[32][2]',
#                                                                   'lstm_1[33][1]',
#                                                                   'lstm_1[33][2]',
#                                                                   'lstm_1[34][1]',
#                                                                   'lstm_1[34][2]',
#                                                                   'lstm_1[35][1]',
#                                                                   'lstm_1[35][2]',
#                                                                   'lstm_1[36][1]',
#                                                                   'lstm_1[36][2]',
#                                                                   'lstm_1[37][1]',
#                                                                   'lstm_1[37][2]',
#                                                                   'lstm_1[38][1]',
#                                                                   'lstm_1[38][2]',
#                                                                   'lstm_1[39][1]',
#                                                                   'lstm_1[39][2]',
#                                                                   'lstm_1[40][1]',
#                                                                   'lstm_1[40][2]',
#                                                                   'lstm_1[41][1]',
#                                                                   'lstm_1[41][2]',
#                                                                   'lstm_1[42][1]',
#                                                                   'lstm_1[42][2]',
#                                                                   'lstm_1[43][1]',
#                                                                   'lstm_1[43][2]',
#                                                                   'lstm_1[44][1]',
#                                                                   'lstm_1[44][2]',
#                                                                   'lstm_1[45][1]',
#                                                                   'lstm_1[45][2]',
#                                                                   'lstm_1[46][1]',
#                                                                   'lstm_1[46][2]',
#                                                                   'lstm_1[47][1]',
#                                                                   'lstm_1[47][2]',
#                                                                   'lstm_1[48][1]',
#                                                                   'lstm_1[48][2]',
#                                                                   'lstm_1[49][1]',
#                                                                   'lstm_1[49][2]',
#                                                                   'lstm_1[50][1]',
#                                                                   'lstm_1[50][2]',
#                                                                   'lstm_1[51][1]',
#                                                                   'lstm_1[51][2]',
#                                                                   'lstm_1[52][1]',
#                                                                   'lstm_1[52][2]',
#                                                                   'lstm_1[53][1]',
#                                                                   'lstm_1[53][2]',
#                                                                   'lstm_1[54][1]',
#                                                                   'lstm_1[54][2]',
#                                                                   'lstm_1[55][1]',
#                                                                   'lstm_1[55][2]',
#                                                                   'lstm_1[56][1]',
#                                                                   'lstm_1[56][2]',
#                                                                   'lstm_1[57][1]',
#                                                                   'lstm_1[57][2]']
#
#  tf.__operators__.getitem (Slic  (None, 256)         0           ['embedding_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 1, 256)      0           ['bahdanau_attention[0][0]']
#  icingOpLambda)
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256)       0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  concatenate (Concatenate)      (None, 1, 512)       0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims[0][0]']
#
#  lstm_1 (LSTM)                  [(None, 1, 256),     787456      ['concatenate[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[0][2]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[1][2]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[2][2]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[3][2]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[4][2]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'lstm_1[5][1]',
#                                                                   'lstm_1[5][2]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'lstm_1[6][1]',
#                                                                   'lstm_1[6][2]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'lstm_1[7][1]',
#                                                                   'lstm_1[7][2]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'lstm_1[8][1]',
#                                                                   'lstm_1[8][2]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'lstm_1[9][1]',
#                                                                   'lstm_1[9][2]',
#                                                                   'concatenate_11[0][0]',
#                                                                   'lstm_1[10][1]',
#                                                                   'lstm_1[10][2]',
#                                                                   'concatenate_12[0][0]',
#                                                                   'lstm_1[11][1]',
#                                                                   'lstm_1[11][2]',
#                                                                   'concatenate_13[0][0]',
#                                                                   'lstm_1[12][1]',
#                                                                   'lstm_1[12][2]',
#                                                                   'concatenate_14[0][0]',
#                                                                   'lstm_1[13][1]',
#                                                                   'lstm_1[13][2]',
#                                                                   'concatenate_15[0][0]',
#                                                                   'lstm_1[14][1]',
#                                                                   'lstm_1[14][2]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'lstm_1[15][1]',
#                                                                   'lstm_1[15][2]',
#                                                                   'concatenate_17[0][0]',
#                                                                   'lstm_1[16][1]',
#                                                                   'lstm_1[16][2]',
#                                                                   'concatenate_18[0][0]',
#                                                                   'lstm_1[17][1]',
#                                                                   'lstm_1[17][2]',
#                                                                   'concatenate_19[0][0]',
#                                                                   'lstm_1[18][1]',
#                                                                   'lstm_1[18][2]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'lstm_1[19][1]',
#                                                                   'lstm_1[19][2]',
#                                                                   'concatenate_21[0][0]',
#                                                                   'lstm_1[20][1]',
#                                                                   'lstm_1[20][2]',
#                                                                   'concatenate_22[0][0]',
#                                                                   'lstm_1[21][1]',
#                                                                   'lstm_1[21][2]',
#                                                                   'concatenate_23[0][0]',
#                                                                   'lstm_1[22][1]',
#                                                                   'lstm_1[22][2]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'lstm_1[23][1]',
#                                                                   'lstm_1[23][2]',
#                                                                   'concatenate_25[0][0]',
#                                                                   'lstm_1[24][1]',
#                                                                   'lstm_1[24][2]',
#                                                                   'concatenate_26[0][0]',
#                                                                   'lstm_1[25][1]',
#                                                                   'lstm_1[25][2]',
#                                                                   'concatenate_27[0][0]',
#                                                                   'lstm_1[26][1]',
#                                                                   'lstm_1[26][2]',
#                                                                   'concatenate_28[0][0]',
#                                                                   'lstm_1[27][1]',
#                                                                   'lstm_1[27][2]',
#                                                                   'concatenate_29[0][0]',
#                                                                   'lstm_1[28][1]',
#                                                                   'lstm_1[28][2]',
#                                                                   'concatenate_30[0][0]',
#                                                                   'lstm_1[29][1]',
#                                                                   'lstm_1[29][2]',
#                                                                   'concatenate_31[0][0]',
#                                                                   'lstm_1[30][1]',
#                                                                   'lstm_1[30][2]',
#                                                                   'concatenate_32[0][0]',
#                                                                   'lstm_1[31][1]',
#                                                                   'lstm_1[31][2]',
#                                                                   'concatenate_33[0][0]',
#                                                                   'lstm_1[32][1]',
#                                                                   'lstm_1[32][2]',
#                                                                   'concatenate_34[0][0]',
#                                                                   'lstm_1[33][1]',
#                                                                   'lstm_1[33][2]',
#                                                                   'concatenate_35[0][0]',
#                                                                   'lstm_1[34][1]',
#                                                                   'lstm_1[34][2]',
#                                                                   'concatenate_36[0][0]',
#                                                                   'lstm_1[35][1]',
#                                                                   'lstm_1[35][2]',
#                                                                   'concatenate_37[0][0]',
#                                                                   'lstm_1[36][1]',
#                                                                   'lstm_1[36][2]',
#                                                                   'concatenate_38[0][0]',
#                                                                   'lstm_1[37][1]',
#                                                                   'lstm_1[37][2]',
#                                                                   'concatenate_39[0][0]',
#                                                                   'lstm_1[38][1]',
#                                                                   'lstm_1[38][2]',
#                                                                   'concatenate_40[0][0]',
#                                                                   'lstm_1[39][1]',
#                                                                   'lstm_1[39][2]',
#                                                                   'concatenate_41[0][0]',
#                                                                   'lstm_1[40][1]',
#                                                                   'lstm_1[40][2]',
#                                                                   'concatenate_42[0][0]',
#                                                                   'lstm_1[41][1]',
#                                                                   'lstm_1[41][2]',
#                                                                   'concatenate_43[0][0]',
#                                                                   'lstm_1[42][1]',
#                                                                   'lstm_1[42][2]',
#                                                                   'concatenate_44[0][0]',
#                                                                   'lstm_1[43][1]',
#                                                                   'lstm_1[43][2]',
#                                                                   'concatenate_45[0][0]',
#                                                                   'lstm_1[44][1]',
#                                                                   'lstm_1[44][2]',
#                                                                   'concatenate_46[0][0]',
#                                                                   'lstm_1[45][1]',
#                                                                   'lstm_1[45][2]',
#                                                                   'concatenate_47[0][0]',
#                                                                   'lstm_1[46][1]',
#                                                                   'lstm_1[46][2]',
#                                                                   'concatenate_48[0][0]',
#                                                                   'lstm_1[47][1]',
#                                                                   'lstm_1[47][2]',
#                                                                   'concatenate_49[0][0]',
#                                                                   'lstm_1[48][1]',
#                                                                   'lstm_1[48][2]',
#                                                                   'concatenate_50[0][0]',
#                                                                   'lstm_1[49][1]',
#                                                                   'lstm_1[49][2]',
#                                                                   'concatenate_51[0][0]',
#                                                                   'lstm_1[50][1]',
#                                                                   'lstm_1[50][2]',
#                                                                   'concatenate_52[0][0]',
#                                                                   'lstm_1[51][1]',
#                                                                   'lstm_1[51][2]',
#                                                                   'concatenate_53[0][0]',
#                                                                   'lstm_1[52][1]',
#                                                                   'lstm_1[52][2]',
#                                                                   'concatenate_54[0][0]',
#                                                                   'lstm_1[53][1]',
#                                                                   'lstm_1[53][2]',
#                                                                   'concatenate_55[0][0]',
#                                                                   'lstm_1[54][1]',
#                                                                   'lstm_1[54][2]',
#                                                                   'concatenate_56[0][0]',
#                                                                   'lstm_1[55][1]',
#                                                                   'lstm_1[55][2]',
#                                                                   'concatenate_57[0][0]',
#                                                                   'lstm_1[56][1]',
#                                                                   'lstm_1[56][2]',
#                                                                   'concatenate_58[0][0]',
#                                                                   'lstm_1[57][1]',
#                                                                   'lstm_1[57][2]']
#
#  tf.__operators__.getitem_2 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None, 1, 256)      0           ['bahdanau_attention[1][0]']
#  icingOpLambda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  concatenate_1 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_1[0][0]']
#
#  tf.__operators__.getitem_4 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  (None, 1, 256)      0           ['bahdanau_attention[2][0]']
#  icingOpLambda)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  concatenate_2 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_2[0][0]']
#
#  tf.__operators__.getitem_6 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, 1, 256)      0           ['bahdanau_attention[3][0]']
#  icingOpLambda)
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  concatenate_3 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_7[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_3[0][0]']
#
#  tf.__operators__.getitem_8 (Sl  (None, 256)         0           ['embedding_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_9 (Sl  (None, 1, 256)      0           ['bahdanau_attention[4][0]']
#  icingOpLambda)
#
#  tf.expand_dims_4 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  concatenate_4 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_9[0][0
#                                                                  ]',
#                                                                   'tf.expand_dims_4[0][0]']
#
#  tf.__operators__.getitem_10 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None, 1, 256)      0           ['bahdanau_attention[5][0]']
#  licingOpLambda)
#
#  tf.expand_dims_5 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  concatenate_5 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_11[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_5[0][0]']
#
#  tf.__operators__.getitem_12 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  (None, 1, 256)      0           ['bahdanau_attention[6][0]']
#  licingOpLambda)
#
#  tf.expand_dims_6 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  concatenate_6 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_13[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_6[0][0]']
#
#  tf.__operators__.getitem_14 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_15 (S  (None, 1, 256)      0           ['bahdanau_attention[7][0]']
#  licingOpLambda)
#
#  tf.expand_dims_7 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_14[0][
#                                                                  0]']
#
#  concatenate_7 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_15[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_7[0][0]']
#
#  tf.__operators__.getitem_16 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_17 (S  (None, 1, 256)      0           ['bahdanau_attention[8][0]']
#  licingOpLambda)
#
#  tf.expand_dims_8 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_16[0][
#                                                                  0]']
#
#  concatenate_8 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_17[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_8[0][0]']
#
#  tf.__operators__.getitem_18 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_19 (S  (None, 1, 256)      0           ['bahdanau_attention[9][0]']
#  licingOpLambda)
#
#  tf.expand_dims_9 (TFOpLambda)  (None, 1, 256)       0           ['tf.__operators__.getitem_18[0][
#                                                                  0]']
#
#  concatenate_9 (Concatenate)    (None, 1, 512)       0           ['tf.__operators__.getitem_19[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_9[0][0]']
#
#  tf.__operators__.getitem_20 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_21 (S  (None, 1, 256)      0           ['bahdanau_attention[10][0]']
#  licingOpLambda)
#
#  tf.expand_dims_10 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_20[0][
#                                                                  0]']
#
#  concatenate_10 (Concatenate)   (None, 1, 512)       0           ['tf.__operators__.getitem_21[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_10[0][0]']
#
#  tf.__operators__.getitem_22 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_23 (S  (None, 1, 256)      0           ['bahdanau_attention[11][0]']
#  licingOpLambda)
#
#  tf.expand_dims_11 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_22[0][
#                                                                  0]']
#
#  concatenate_11 (Concatenate)   (None, 1, 512)       0           ['tf.__operators__.getitem_23[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_11[0][0]']
#
#  tf.__operators__.getitem_24 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_25 (S  (None, 1, 256)      0           ['bahdanau_attention[12][0]']
#  licingOpLambda)
#
#  tf.expand_dims_12 (TFOpLambda)  (None, 1, 256)      0           ['tf.__operators__.getitem_24[0][
#                                                                  0]']
#
#  concatenate_12 (Concatenate)   (None, 1, 512)       0           ['tf.__operators__.getitem_25[0][
#                                                                  0]',
#                                                                   'tf.expand_dims_12[0][0]']
#
#  tf.__operators__.getitem_26 (S  (None, 256)         0           ['embedding_1[0][0]']
#  licingOpLambda)
#
# ...
#  dense_13 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[10][0]']
#
#  dense_14 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[11][0]']
#
#  dense_15 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[12][0]']
#
#  dense_16 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[13][0]']
#
#  dense_17 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[14][0]']
#
#  dense_18 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[15][0]']
#
#  dense_19 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[16][0]']
#
#  dense_20 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[17][0]']
#
#  dense_21 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[18][0]']
#
#  dense_22 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[19][0]']
#
#  dense_23 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[20][0]']
#
#  dense_24 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[21][0]']
#
#  dense_25 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[22][0]']
#
#  dense_26 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[23][0]']
#
#  dense_27 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[24][0]']
#
#  dense_28 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[25][0]']
#
#  dense_29 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[26][0]']
#
#  dense_30 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[27][0]']
#
#  dense_31 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[28][0]']
#
#  dense_32 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[29][0]']
#
#  dense_33 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[30][0]']
#
#  dense_34 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[31][0]']
#
#  dense_35 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[32][0]']
#
#  dense_36 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[33][0]']
#
#  dense_37 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[34][0]']
#
#  dense_38 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[35][0]']
#
#  dense_39 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[36][0]']
#
#  dense_40 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[37][0]']
#
#  dense_41 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[38][0]']
#
#  dense_42 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[39][0]']
#
#  dense_43 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[40][0]']
#
#  dense_44 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[41][0]']
#
#  dense_45 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[42][0]']
#
#  dense_46 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[43][0]']
#
#  dense_47 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[44][0]']
#
#  dense_48 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[45][0]']
#
#  dense_49 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[46][0]']
#
#  dense_50 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[47][0]']
#
#  dense_51 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[48][0]']
#
#  dense_52 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[49][0]']
#
#  dense_53 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[50][0]']
#
#  dense_54 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[51][0]']
#
#  dense_55 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[52][0]']
#
#  dense_56 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[53][0]']
#
#  dense_57 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[54][0]']
#
#  dense_58 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[55][0]']
#
#  dense_59 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[56][0]']
#
#  dense_60 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[57][0]']
#
#  dense_61 (Dense)               (None, 1, 5806)      1492142     ['lstm_1[58][0]']
#
#  tf.concat (TFOpLambda)         (None, 59, 5806)     0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]',
#                                                                   'dense_5[0][0]',
#                                                                   'dense_6[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_8[0][0]',
#                                                                   'dense_9[0][0]',
#                                                                   'dense_10[0][0]',
#                                                                   'dense_11[0][0]',
#                                                                   'dense_12[0][0]',
#                                                                   'dense_13[0][0]',
#                                                                   'dense_14[0][0]',
#                                                                   'dense_15[0][0]',
#                                                                   'dense_16[0][0]',
#                                                                   'dense_17[0][0]',
#                                                                   'dense_18[0][0]',
#                                                                   'dense_19[0][0]',
#                                                                   'dense_20[0][0]',
#                                                                   'dense_21[0][0]',
#                                                                   'dense_22[0][0]',
#                                                                   'dense_23[0][0]',
#                                                                   'dense_24[0][0]',
#                                                                   'dense_25[0][0]',
#                                                                   'dense_26[0][0]',
#                                                                   'dense_27[0][0]',
#                                                                   'dense_28[0][0]',
#                                                                   'dense_29[0][0]',
#                                                                   'dense_30[0][0]',
#                                                                   'dense_31[0][0]',
#                                                                   'dense_32[0][0]',
#                                                                   'dense_33[0][0]',
#                                                                   'dense_34[0][0]',
#                                                                   'dense_35[0][0]',
#                                                                   'dense_36[0][0]',
#                                                                   'dense_37[0][0]',
#                                                                   'dense_38[0][0]',
#                                                                   'dense_39[0][0]',
#                                                                   'dense_40[0][0]',
#                                                                   'dense_41[0][0]',
#                                                                   'dense_42[0][0]',
#                                                                   'dense_43[0][0]',
#                                                                   'dense_44[0][0]',
#                                                                   'dense_45[0][0]',
#                                                                   'dense_46[0][0]',
#                                                                   'dense_47[0][0]',
#                                                                   'dense_48[0][0]',
#                                                                   'dense_49[0][0]',
#                                                                   'dense_50[0][0]',
#                                                                   'dense_51[0][0]',
#                                                                   'dense_52[0][0]',
#                                                                   'dense_53[0][0]',
#                                                                   'dense_54[0][0]',
#                                                                   'dense_55[0][0]',
#                                                                   'dense_56[0][0]',
#                                                                   'dense_57[0][0]',
#                                                                   'dense_58[0][0]',
#                                                                   'dense_59[0][0]',
#                                                                   'dense_60[0][0]',
#                                                                   'dense_61[0][0]']
#
# ==================================================================================================
# Total params: 91,660,315
# Trainable params: 91,660,315
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(
    [encoder_input_data, decoder_input_data], 
    np.expand_dims(decoder_target_data, -1),
    batch_size = 64,
    epochs = 5,
    validation_split = 0.2
)
# Out:
# Epoch 1/5
# 125/125 [==============================] - 223s 2s/step - loss: 0.3583 - accuracy: 0.9495 - val_loss: 0.4346 - val_accuracy: 0.9420
# Epoch 2/5
# 125/125 [==============================] - 200s 2s/step - loss: 0.3488 - accuracy: 0.9495 - val_loss: 0.4436 - val_accuracy: 0.9420
# Epoch 3/5
# 125/125 [==============================] - 201s 2s/step - loss: 0.3480 - accuracy: 0.9495 - val_loss: 0.4481 - val_accuracy: 0.9420
# Epoch 4/5
# 125/125 [==============================] - 200s 2s/step - loss: 0.3480 - accuracy: 0.9495 - val_loss: 0.4517 - val_accuracy: 0.9420
# Epoch 5/5
# 125/125 [==============================] - 201s 2s/step - loss: 0.3473 - accuracy: 0.9495 - val_loss: 0.4551 - val_accuracy: 0.9420
